# %% [markdown]
# # Slicing
#
# In this notebook I will divide each scan in slices along the X axis. These slices will server as units of our data for modelling.

# %% [markdown]
# File configuration

# %%
# Adjust the frac parameter for loess smoothing
# to control the degree of smoothing applied to the scan data.
diff_dir = "../scandata/difference loess frac=0.20"

# %% [markdown]
# Libraries used:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import os

# %% [markdown]
# Let's load the pointclouds.

# %%
npy_files = [filename for filename in os.listdir(diff_dir) if filename.endswith(".npy")]
difference_point_clouds = [np.load(os.path.join(diff_dir, npy_file)) for npy_file in npy_files]

num_of_clouds = len(difference_point_clouds)
total_rows = 0

print(f"Loaded {num_of_clouds} difference point clouds.")

for i in range(num_of_clouds):
    print(f"Difference point cloud {npy_files[i]} shape: {difference_point_clouds[i].shape}")
    total_rows += difference_point_clouds[i].shape[0]
print(f"Total number of rows: {total_rows}")
# Out:
# Loaded 5 difference point clouds.
# Difference point cloud 221111_144114__binary_onlylines114378to117271 loess frac=0.2_difference.npy shape: (5543532, 3)
# Difference point cloud 221111_144114__binary_onlylines145900to148050 loess frac=0.2_difference.npy shape: (3786525, 3)
# Difference point cloud 221111_144114__binary_onlylines25660to28100 loess frac=0.2_difference.npy shape: (3535680, 3)
# Difference point cloud 221111_144114__binary_onlylines47178to50517 loess frac=0.2_difference.npy shape: (3414927, 3)
# Difference point cloud 221111_144114__binary_onlylines86841to90142 loess frac=0.2_difference.npy shape: (4718054, 3)
# Total number of rows: 20998718

# %%
# Function to slice point clouds by x-coordinate
def slice_pointcloud_by_x(point_cloud, slice_width=10):
    # Ensure shape is (N, 3)
    if point_cloud.shape[0] == 3 and point_cloud.shape[1] != 3:
        point_cloud = point_cloud.T
    x_coords = point_cloud[:, 0].astype(int)
    min_x = x_coords.min()
    max_x = x_coords.max()
    slices = []
    starts = []
    for start_x in range(min_x, max_x + 1, slice_width):
        end_x = start_x + slice_width
        mask = (x_coords >= start_x) & (x_coords < end_x)
        slice_points = point_cloud[mask]
        if slice_points.shape[0] > 0:
            slices.append(slice_points)
            starts.append(start_x)
    return slices, starts

# %% [markdown]
# Creating slices each 10 units wide.

# %%
all_slices = []
for idx, pc in enumerate(difference_point_clouds):
    slices, starts = slice_pointcloud_by_x(pc, slice_width=10)
    print(f"Point cloud {idx}: {len(slices)} slices")
    for i, start_x in enumerate(starts):
        print(f"  Slice {i}: starts at X={start_x}, points={slices[i].shape[0]}")
    all_slices.append(slices)
# Out:
# Point cloud 0: 290 slices
#   Slice 0: starts at X=0, points=19875
#   Slice 1: starts at X=10, points=20483
#   Slice 2: starts at X=20, points=20329
#   Slice 3: starts at X=30, points=20297
#   Slice 4: starts at X=40, points=20249
#   Slice 5: starts at X=50, points=20265
#   Slice 6: starts at X=60, points=20289
#   Slice 7: starts at X=70, points=20466
#   Slice 8: starts at X=80, points=20389
#   Slice 9: starts at X=90, points=20311
#   Slice 10: starts at X=100, points=20354
#   Slice 11: starts at X=110, points=20359
#   Slice 12: starts at X=120, points=20266
#   Slice 13: starts at X=130, points=20364
#   Slice 14: starts at X=140, points=20436
#   Slice 15: starts at X=150, points=20320
#   Slice 16: starts at X=160, points=20386
#   Slice 17: starts at X=170, points=20445
#   Slice 18: starts at X=180, points=20346
#   Slice 19: starts at X=190, points=20353
#   Slice 20: starts at X=200, points=20367
#   Slice 21: starts at X=210, points=20329
#   Slice 22: starts at X=220, points=20360
#   Slice 23: starts at X=230, points=20254
#   Slice 24: starts at X=240, points=20206
#   Slice 25: starts at X=250, points=20242
#   Slice 26: starts at X=260, points=20214
#   Slice 27: starts at X=270, points=20333
#   Slice 28: starts at X=280, points=20464
#   Slice 29: starts at X=290, points=20354
#   Slice 30: starts at X=300, points=20427
#   Slice 31: starts at X=310, points=20353
#   Slice 32: starts at X=320, points=20372
#   Slice 33: starts at X=330, points=20265
#   Slice 34: starts at X=340, points=20253
#   Slice 35: starts at X=350, points=20297
#   Slice 36: starts at X=360, points=20090
#   Slice 37: starts at X=370, points=19880
#   Slice 38: starts at X=380, points=19821
#   Slice 39: starts at X=390, points=20221
#   Slice 40: starts at X=400, points=20175
#   Slice 41: starts at X=410, points=20197
#   Slice 42: starts at X=420, points=20222
#   Slice 43: starts at X=430, points=20232
#   Slice 44: starts at X=440, points=20182
#   Slice 45: starts at X=450, points=20114
#   Slice 46: starts at X=460, points=20143
#   Slice 47: starts at X=470, points=20248
#   Slice 48: starts at X=480, points=20128
#   Slice 49: starts at X=490, points=20070
#   Slice 50: starts at X=500, points=20168
#   Slice 51: starts at X=510, points=20009
#   Slice 52: starts at X=520, points=20009
#   Slice 53: starts at X=530, points=19996
#   Slice 54: starts at X=540, points=19978
#   Slice 55: starts at X=550, points=19970
#   Slice 56: starts at X=560, points=19930
#   Slice 57: starts at X=570, points=19945
#   Slice 58: starts at X=580, points=20012
#   Slice 59: starts at X=590, points=20069
#   Slice 60: starts at X=600, points=20047
#   Slice 61: starts at X=610, points=20062
#   Slice 62: starts at X=620, points=20076
#   Slice 63: starts at X=630, points=20052
#   Slice 64: starts at X=640, points=20161
#   Slice 65: starts at X=650, points=19915
#   Slice 66: starts at X=660, points=19781
#   Slice 67: starts at X=670, points=19853
#   Slice 68: starts at X=680, points=19795
#   Slice 69: starts at X=690, points=19673
#   Slice 70: starts at X=700, points=19650
#   Slice 71: starts at X=710, points=19747
#   Slice 72: starts at X=720, points=19900
#   Slice 73: starts at X=730, points=19859
#   Slice 74: starts at X=740, points=19923
#   Slice 75: starts at X=750, points=19781
#   Slice 76: starts at X=760, points=19864
#   Slice 77: starts at X=770, points=19873
#   Slice 78: starts at X=780, points=19878
#   Slice 79: starts at X=790, points=19794
#   Slice 80: starts at X=800, points=19699
#   Slice 81: starts at X=810, points=19604
#   Slice 82: starts at X=820, points=19652
#   Slice 83: starts at X=830, points=19608
#   Slice 84: starts at X=840, points=19680
#   Slice 85: starts at X=850, points=19756
#   Slice 86: starts at X=860, points=19631
#   Slice 87: starts at X=870, points=19511
#   Slice 88: starts at X=880, points=19499
#   Slice 89: starts at X=890, points=19713
#   Slice 90: starts at X=900, points=19677
#   Slice 91: starts at X=910, points=19582
#   Slice 92: starts at X=920, points=19653
#   Slice 93: starts at X=930, points=19646
#   Slice 94: starts at X=940, points=19514
#   Slice 95: starts at X=950, points=19601
#   Slice 96: starts at X=960, points=19636
#   Slice 97: starts at X=970, points=19401
#   Slice 98: starts at X=980, points=19439
#   Slice 99: starts at X=990, points=19438
#   Slice 100: starts at X=1000, points=19377
#   Slice 101: starts at X=1010, points=19469
#   Slice 102: starts at X=1020, points=19539
#   Slice 103: starts at X=1030, points=19441
#   Slice 104: starts at X=1040, points=19505
#   Slice 105: starts at X=1050, points=19481
#   Slice 106: starts at X=1060, points=19447
#   Slice 107: starts at X=1070, points=19496
#   Slice 108: starts at X=1080, points=19438
#   Slice 109: starts at X=1090, points=19386
#   Slice 110: starts at X=1100, points=19417
#   Slice 111: starts at X=1110, points=19460
#   Slice 112: starts at X=1120, points=19439
#   Slice 113: starts at X=1130, points=19253
#   Slice 114: starts at X=1140, points=19236
#   Slice 115: starts at X=1150, points=19282
#   Slice 116: starts at X=1160, points=19393
#   Slice 117: starts at X=1170, points=19409
#   Slice 118: starts at X=1180, points=19295
#   Slice 119: starts at X=1190, points=19231
#   Slice 120: starts at X=1200, points=19136
#   Slice 121: starts at X=1210, points=19270
#   Slice 122: starts at X=1220, points=19320
#   Slice 123: starts at X=1230, points=19256
#   Slice 124: starts at X=1240, points=19106
#   Slice 125: starts at X=1250, points=18954
#   Slice 126: starts at X=1260, points=19194
#   Slice 127: starts at X=1270, points=19200
#   Slice 128: starts at X=1280, points=19078
#   Slice 129: starts at X=1290, points=19158
#   Slice 130: starts at X=1300, points=19021
#   Slice 131: starts at X=1310, points=18870
#   Slice 132: starts at X=1320, points=18992
#   Slice 133: starts at X=1330, points=19103
#   Slice 134: starts at X=1340, points=19032
#   Slice 135: starts at X=1350, points=19054
#   Slice 136: starts at X=1360, points=19007
#   Slice 137: starts at X=1370, points=19028
#   Slice 138: starts at X=1380, points=19063
#   Slice 139: starts at X=1390, points=18976
#   Slice 140: starts at X=1400, points=18987
#   Slice 141: starts at X=1410, points=19049
#   Slice 142: starts at X=1420, points=18969
#   Slice 143: starts at X=1430, points=18851
#   Slice 144: starts at X=1440, points=18953
#   Slice 145: starts at X=1450, points=18984
#   Slice 146: starts at X=1460, points=18913
#   Slice 147: starts at X=1470, points=18872
#   Slice 148: starts at X=1480, points=18906
#   Slice 149: starts at X=1490, points=18937
#   Slice 150: starts at X=1500, points=18805
#   Slice 151: starts at X=1510, points=18826
#   Slice 152: starts at X=1520, points=18736
#   Slice 153: starts at X=1530, points=18668
#   Slice 154: starts at X=1540, points=18654
#   Slice 155: starts at X=1550, points=18801
#   Slice 156: starts at X=1560, points=18785
#   Slice 157: starts at X=1570, points=18621
#   Slice 158: starts at X=1580, points=18569
#   Slice 159: starts at X=1590, points=18627
#   Slice 160: starts at X=1600, points=18604
#   Slice 161: starts at X=1610, points=18619
#   Slice 162: starts at X=1620, points=18550
#   Slice 163: starts at X=1630, points=18466
#   Slice 164: starts at X=1640, points=18481
#   Slice 165: starts at X=1650, points=18340
#   Slice 166: starts at X=1660, points=18326
#   Slice 167: starts at X=1670, points=18276
#   Slice 168: starts at X=1680, points=18484
#   Slice 169: starts at X=1690, points=18500
#   Slice 170: starts at X=1700, points=18475
#   Slice 171: starts at X=1710, points=18501
#   Slice 172: starts at X=1720, points=18517
#   Slice 173: starts at X=1730, points=18185
#   Slice 174: starts at X=1740, points=18256
#   Slice 175: starts at X=1750, points=18334
#   Slice 176: starts at X=1760, points=18421
#   Slice 177: starts at X=1770, points=18296
#   Slice 178: starts at X=1780, points=18381
#   Slice 179: starts at X=1790, points=18409
#   Slice 180: starts at X=1800, points=18309
#   Slice 181: starts at X=1810, points=18341
#   Slice 182: starts at X=1820, points=18308
#   Slice 183: starts at X=1830, points=18374
#   Slice 184: starts at X=1840, points=18375
#   Slice 185: starts at X=1850, points=18380
#   Slice 186: starts at X=1860, points=18418
#   Slice 187: starts at X=1870, points=18418
#   Slice 188: starts at X=1880, points=18465
#   Slice 189: starts at X=1890, points=18403
#   Slice 190: starts at X=1900, points=18434
#   Slice 191: starts at X=1910, points=18460
#   Slice 192: starts at X=1920, points=18408
#   Slice 193: starts at X=1930, points=18385
#   Slice 194: starts at X=1940, points=18421
#   Slice 195: starts at X=1950, points=18459
#   Slice 196: starts at X=1960, points=18393
#   Slice 197: starts at X=1970, points=18465
#   Slice 198: starts at X=1980, points=18551
#   Slice 199: starts at X=1990, points=18538
#   Slice 200: starts at X=2000, points=18503
#   Slice 201: starts at X=2010, points=18427
#   Slice 202: starts at X=2020, points=18524
#   Slice 203: starts at X=2030, points=18501
#   Slice 204: starts at X=2040, points=18539
#   Slice 205: starts at X=2050, points=18467
#   Slice 206: starts at X=2060, points=18416
#   Slice 207: starts at X=2070, points=18210
#   Slice 208: starts at X=2080, points=18244
#   Slice 209: starts at X=2090, points=18331
#   Slice 210: starts at X=2100, points=18208
#   Slice 211: starts at X=2110, points=18450
#   Slice 212: starts at X=2120, points=18520
#   Slice 213: starts at X=2130, points=18504
#   Slice 214: starts at X=2140, points=18403
#   Slice 215: starts at X=2150, points=18450
#   Slice 216: starts at X=2160, points=18502
#   Slice 217: starts at X=2170, points=18566
#   Slice 218: starts at X=2180, points=18593
#   Slice 219: starts at X=2190, points=18577
#   Slice 220: starts at X=2200, points=18707
#   Slice 221: starts at X=2210, points=18460
#   Slice 222: starts at X=2220, points=18492
#   Slice 223: starts at X=2230, points=18520
#   Slice 224: starts at X=2240, points=18482
#   Slice 225: starts at X=2250, points=18517
#   Slice 226: starts at X=2260, points=18519
#   Slice 227: starts at X=2270, points=18490
#   Slice 228: starts at X=2280, points=18471
#   Slice 229: starts at X=2290, points=18306
#   Slice 230: starts at X=2300, points=18379
#   Slice 231: starts at X=2310, points=18323
#   Slice 232: starts at X=2320, points=18524
#   Slice 233: starts at X=2330, points=18607
#   Slice 234: starts at X=2340, points=18725
#   Slice 235: starts at X=2350, points=18797
#   Slice 236: starts at X=2360, points=18633
#   Slice 237: starts at X=2370, points=18754
#   Slice 238: starts at X=2380, points=18768
#   Slice 239: starts at X=2390, points=18749
#   Slice 240: starts at X=2400, points=18760
#   Slice 241: starts at X=2410, points=18738
#   Slice 242: starts at X=2420, points=18867
#   Slice 243: starts at X=2430, points=18894
#   Slice 244: starts at X=2440, points=18822
#   Slice 245: starts at X=2450, points=18853
#   Slice 246: starts at X=2460, points=18866
#   Slice 247: starts at X=2470, points=18704
#   Slice 248: starts at X=2480, points=18450
#   Slice 249: starts at X=2490, points=18569
#   Slice 250: starts at X=2500, points=18655
#   Slice 251: starts at X=2510, points=18715
#   Slice 252: starts at X=2520, points=18815
#   Slice 253: starts at X=2530, points=18745
#   Slice 254: starts at X=2540, points=18719
#   Slice 255: starts at X=2550, points=18701
#   Slice 256: starts at X=2560, points=18615
#   Slice 257: starts at X=2570, points=18830
#   Slice 258: starts at X=2580, points=18808
#   Slice 259: starts at X=2590, points=18653
#   Slice 260: starts at X=2600, points=18791
#   Slice 261: starts at X=2610, points=18758
#   Slice 262: starts at X=2620, points=18684
#   Slice 263: starts at X=2630, points=18776
#   Slice 264: starts at X=2640, points=18750
#   Slice 265: starts at X=2650, points=18711
#   Slice 266: starts at X=2660, points=18637
#   Slice 267: starts at X=2670, points=18710
#   Slice 268: starts at X=2680, points=18727
#   Slice 269: starts at X=2690, points=18687
#   Slice 270: starts at X=2700, points=18603
#   Slice 271: starts at X=2710, points=18624
#   Slice 272: starts at X=2720, points=18651
#   Slice 273: starts at X=2730, points=18610
#   Slice 274: starts at X=2740, points=18545
#   Slice 275: starts at X=2750, points=18572
#   Slice 276: starts at X=2760, points=18612
#   Slice 277: starts at X=2770, points=18519
#   Slice 278: starts at X=2780, points=18488
#   Slice 279: starts at X=2790, points=18638
#   Slice 280: starts at X=2800, points=18578
#   Slice 281: starts at X=2810, points=18400
#   Slice 282: starts at X=2820, points=18343
#   Slice 283: starts at X=2830, points=18191
#   Slice 284: starts at X=2840, points=18196
#   Slice 285: starts at X=2850, points=18261
#   Slice 286: starts at X=2860, points=18667
#   Slice 287: starts at X=2870, points=18730
#   Slice 288: starts at X=2880, points=16853
#   Slice 289: starts at X=2890, points=5127
# Point cloud 1: 216 slices
#   Slice 0: starts at X=0, points=10877
#   Slice 1: starts at X=10, points=10646
#   Slice 2: starts at X=20, points=10682
#   Slice 3: starts at X=30, points=10647
#   Slice 4: starts at X=40, points=10239
#   Slice 5: starts at X=50, points=10177
#   Slice 6: starts at X=60, points=10168
#   Slice 7: starts at X=70, points=10305
#   Slice 8: starts at X=80, points=10435
#   Slice 9: starts at X=90, points=10611
#   Slice 10: starts at X=100, points=11283
#   Slice 11: starts at X=110, points=15275
#   Slice 12: starts at X=120, points=17017
#   Slice 13: starts at X=130, points=17219
#   Slice 14: starts at X=140, points=17090
#   Slice 15: starts at X=150, points=17229
#   Slice 16: starts at X=160, points=17401
#   Slice 17: starts at X=170, points=17435
#   Slice 18: starts at X=180, points=17514
#   Slice 19: starts at X=190, points=17560
#   Slice 20: starts at X=200, points=17411
#   Slice 21: starts at X=210, points=17538
#   Slice 22: starts at X=220, points=17597
#   Slice 23: starts at X=230, points=17466
#   Slice 24: starts at X=240, points=17502
#   Slice 25: starts at X=250, points=17604
#   Slice 26: starts at X=260, points=17522
#   Slice 27: starts at X=270, points=17477
#   Slice 28: starts at X=280, points=17652
#   Slice 29: starts at X=290, points=17639
#   Slice 30: starts at X=300, points=17568
#   Slice 31: starts at X=310, points=17631
#   Slice 32: starts at X=320, points=17694
#   Slice 33: starts at X=330, points=17723
#   Slice 34: starts at X=340, points=17696
#   Slice 35: starts at X=350, points=17492
#   Slice 36: starts at X=360, points=17755
#   Slice 37: starts at X=370, points=17491
#   Slice 38: starts at X=380, points=17614
#   Slice 39: starts at X=390, points=17636
#   Slice 40: starts at X=400, points=17720
#   Slice 41: starts at X=410, points=17745
#   Slice 42: starts at X=420, points=17717
#   Slice 43: starts at X=430, points=17751
#   Slice 44: starts at X=440, points=17706
#   Slice 45: starts at X=450, points=17552
#   Slice 46: starts at X=460, points=17747
#   Slice 47: starts at X=470, points=17728
#   Slice 48: starts at X=480, points=17685
#   Slice 49: starts at X=490, points=17692
#   Slice 50: starts at X=500, points=17805
#   Slice 51: starts at X=510, points=17723
#   Slice 52: starts at X=520, points=17805
#   Slice 53: starts at X=530, points=17787
#   Slice 54: starts at X=540, points=17589
#   Slice 55: starts at X=550, points=17633
#   Slice 56: starts at X=560, points=17651
#   Slice 57: starts at X=570, points=17726
#   Slice 58: starts at X=580, points=17836
#   Slice 59: starts at X=590, points=17848
#   Slice 60: starts at X=600, points=17912
#   Slice 61: starts at X=610, points=17778
#   Slice 62: starts at X=620, points=17910
#   Slice 63: starts at X=630, points=18001
#   Slice 64: starts at X=640, points=17823
#   Slice 65: starts at X=650, points=17850
#   Slice 66: starts at X=660, points=17970
#   Slice 67: starts at X=670, points=17912
#   Slice 68: starts at X=680, points=18061
#   Slice 69: starts at X=690, points=18012
#   Slice 70: starts at X=700, points=17800
#   Slice 71: starts at X=710, points=17931
#   Slice 72: starts at X=720, points=17949
#   Slice 73: starts at X=730, points=17840
#   Slice 74: starts at X=740, points=17772
#   Slice 75: starts at X=750, points=17917
#   Slice 76: starts at X=760, points=18085
#   Slice 77: starts at X=770, points=18010
#   Slice 78: starts at X=780, points=17809
#   Slice 79: starts at X=790, points=17662
#   Slice 80: starts at X=800, points=17974
#   Slice 81: starts at X=810, points=18052
#   Slice 82: starts at X=820, points=17985
#   Slice 83: starts at X=830, points=18030
#   Slice 84: starts at X=840, points=18184
#   Slice 85: starts at X=850, points=18242
#   Slice 86: starts at X=860, points=18047
#   Slice 87: starts at X=870, points=18184
#   Slice 88: starts at X=880, points=18305
#   Slice 89: starts at X=890, points=18259
#   Slice 90: starts at X=900, points=18235
#   Slice 91: starts at X=910, points=18383
#   Slice 92: starts at X=920, points=18241
#   Slice 93: starts at X=930, points=18279
#   Slice 94: starts at X=940, points=18393
#   Slice 95: starts at X=950, points=18249
#   Slice 96: starts at X=960, points=18295
#   Slice 97: starts at X=970, points=18309
#   Slice 98: starts at X=980, points=18387
#   Slice 99: starts at X=990, points=18253
#   Slice 100: starts at X=1000, points=18119
#   Slice 101: starts at X=1010, points=18334
#   Slice 102: starts at X=1020, points=18369
#   Slice 103: starts at X=1030, points=18335
#   Slice 104: starts at X=1040, points=18328
#   Slice 105: starts at X=1050, points=18193
#   Slice 106: starts at X=1060, points=18357
#   Slice 107: starts at X=1070, points=18461
#   Slice 108: starts at X=1080, points=18424
#   Slice 109: starts at X=1090, points=18391
#   Slice 110: starts at X=1100, points=18450
#   Slice 111: starts at X=1110, points=18295
#   Slice 112: starts at X=1120, points=18290
#   Slice 113: starts at X=1130, points=18394
#   Slice 114: starts at X=1140, points=18413
#   Slice 115: starts at X=1150, points=18292
#   Slice 116: starts at X=1160, points=18233
#   Slice 117: starts at X=1170, points=18433
#   Slice 118: starts at X=1180, points=18462
#   Slice 119: starts at X=1190, points=18340
#   Slice 120: starts at X=1200, points=18385
#   Slice 121: starts at X=1210, points=18360
#   Slice 122: starts at X=1220, points=18259
#   Slice 123: starts at X=1230, points=18366
#   Slice 124: starts at X=1240, points=18423
#   Slice 125: starts at X=1250, points=18318
#   Slice 126: starts at X=1260, points=18358
#   Slice 127: starts at X=1270, points=18345
#   Slice 128: starts at X=1280, points=18227
#   Slice 129: starts at X=1290, points=18350
#   Slice 130: starts at X=1300, points=18158
#   Slice 131: starts at X=1310, points=18409
#   Slice 132: starts at X=1320, points=18403
#   Slice 133: starts at X=1330, points=18349
#   Slice 134: starts at X=1340, points=18416
#   Slice 135: starts at X=1350, points=18432
#   Slice 136: starts at X=1360, points=18282
#   Slice 137: starts at X=1370, points=18168
#   Slice 138: starts at X=1380, points=18279
#   Slice 139: starts at X=1390, points=18237
#   Slice 140: starts at X=1400, points=18270
#   Slice 141: starts at X=1410, points=18345
#   Slice 142: starts at X=1420, points=18202
#   Slice 143: starts at X=1430, points=18196
#   Slice 144: starts at X=1440, points=18345
#   Slice 145: starts at X=1450, points=18531
#   Slice 146: starts at X=1460, points=18432
#   Slice 147: starts at X=1470, points=18482
#   Slice 148: starts at X=1480, points=18527
#   Slice 149: starts at X=1490, points=18645
#   Slice 150: starts at X=1500, points=18484
#   Slice 151: starts at X=1510, points=18475
#   Slice 152: starts at X=1520, points=18430
#   Slice 153: starts at X=1530, points=18444
#   Slice 154: starts at X=1540, points=18464
#   Slice 155: starts at X=1550, points=18098
#   Slice 156: starts at X=1560, points=18042
#   Slice 157: starts at X=1570, points=18288
#   Slice 158: starts at X=1580, points=18128
#   Slice 159: starts at X=1590, points=18475
#   Slice 160: starts at X=1600, points=18372
#   Slice 161: starts at X=1610, points=18362
#   Slice 162: starts at X=1620, points=18248
#   Slice 163: starts at X=1630, points=18214
#   Slice 164: starts at X=1640, points=18266
#   Slice 165: starts at X=1650, points=18361
#   Slice 166: starts at X=1660, points=18422
#   Slice 167: starts at X=1670, points=18308
#   Slice 168: starts at X=1680, points=18334
#   Slice 169: starts at X=1690, points=18361
#   Slice 170: starts at X=1700, points=18477
#   Slice 171: starts at X=1710, points=18484
#   Slice 172: starts at X=1720, points=18421
#   Slice 173: starts at X=1730, points=18573
#   Slice 174: starts at X=1740, points=18634
#   Slice 175: starts at X=1750, points=18477
#   Slice 176: starts at X=1760, points=18525
#   Slice 177: starts at X=1770, points=18590
#   Slice 178: starts at X=1780, points=18414
#   Slice 179: starts at X=1790, points=18447
#   Slice 180: starts at X=1800, points=18460
#   Slice 181: starts at X=1810, points=18011
#   Slice 182: starts at X=1820, points=18394
#   Slice 183: starts at X=1830, points=18603
#   Slice 184: starts at X=1840, points=18573
#   Slice 185: starts at X=1850, points=18584
#   Slice 186: starts at X=1860, points=18473
#   Slice 187: starts at X=1870, points=18635
#   Slice 188: starts at X=1880, points=18595
#   Slice 189: starts at X=1890, points=18586
#   Slice 190: starts at X=1900, points=18607
#   Slice 191: starts at X=1910, points=18660
#   Slice 192: starts at X=1920, points=18675
#   Slice 193: starts at X=1930, points=18581
#   Slice 194: starts at X=1940, points=18652
#   Slice 195: starts at X=1950, points=18689
#   Slice 196: starts at X=1960, points=18626
#   Slice 197: starts at X=1970, points=18722
#   Slice 198: starts at X=1980, points=18769
#   Slice 199: starts at X=1990, points=18631
#   Slice 200: starts at X=2000, points=18780
#   Slice 201: starts at X=2010, points=18852
#   Slice 202: starts at X=2020, points=18862
#   Slice 203: starts at X=2030, points=18606
#   Slice 204: starts at X=2040, points=18650
#   Slice 205: starts at X=2050, points=18855
#   Slice 206: starts at X=2060, points=18791
#   Slice 207: starts at X=2070, points=15495
#   Slice 208: starts at X=2080, points=14587
#   Slice 209: starts at X=2090, points=14591
#   Slice 210: starts at X=2100, points=14604
#   Slice 211: starts at X=2110, points=13984
#   Slice 212: starts at X=2120, points=13735
#   Slice 213: starts at X=2130, points=14269
#   Slice 214: starts at X=2140, points=13733
#   Slice 215: starts at X=2150, points=1321
# Point cloud 2: 245 slices
#   Slice 0: starts at X=0, points=11481
#   Slice 1: starts at X=10, points=12586
#   Slice 2: starts at X=20, points=12336
#   Slice 3: starts at X=30, points=12307
#   Slice 4: starts at X=40, points=12169
#   Slice 5: starts at X=50, points=12517
#   Slice 6: starts at X=60, points=12593
#   Slice 7: starts at X=70, points=12709
#   Slice 8: starts at X=80, points=12757
#   Slice 9: starts at X=90, points=12715
#   Slice 10: starts at X=100, points=12697
#   Slice 11: starts at X=110, points=12738
#   Slice 12: starts at X=120, points=12813
#   Slice 13: starts at X=130, points=12803
#   Slice 14: starts at X=140, points=12872
#   Slice 15: starts at X=150, points=12887
#   Slice 16: starts at X=160, points=12908
#   Slice 17: starts at X=170, points=12904
#   Slice 18: starts at X=180, points=12910
#   Slice 19: starts at X=190, points=12961
#   Slice 20: starts at X=200, points=12998
#   Slice 21: starts at X=210, points=13011
#   Slice 22: starts at X=220, points=13005
#   Slice 23: starts at X=230, points=13033
#   Slice 24: starts at X=240, points=13083
#   Slice 25: starts at X=250, points=13107
#   Slice 26: starts at X=260, points=13099
#   Slice 27: starts at X=270, points=12963
#   Slice 28: starts at X=280, points=12938
#   Slice 29: starts at X=290, points=13003
#   Slice 30: starts at X=300, points=13209
#   Slice 31: starts at X=310, points=13220
#   Slice 32: starts at X=320, points=13244
#   Slice 33: starts at X=330, points=13238
#   Slice 34: starts at X=340, points=13275
#   Slice 35: starts at X=350, points=13309
#   Slice 36: starts at X=360, points=13283
#   Slice 37: starts at X=370, points=13356
#   Slice 38: starts at X=380, points=13086
#   Slice 39: starts at X=390, points=13171
#   Slice 40: starts at X=400, points=13244
#   Slice 41: starts at X=410, points=13416
#   Slice 42: starts at X=420, points=13394
#   Slice 43: starts at X=430, points=13431
#   Slice 44: starts at X=440, points=13469
#   Slice 45: starts at X=450, points=13425
#   Slice 46: starts at X=460, points=13438
#   Slice 47: starts at X=470, points=13489
#   Slice 48: starts at X=480, points=13516
#   Slice 49: starts at X=490, points=13467
#   Slice 50: starts at X=500, points=13353
#   Slice 51: starts at X=510, points=13374
#   Slice 52: starts at X=520, points=13414
#   Slice 53: starts at X=530, points=13483
#   Slice 54: starts at X=540, points=13356
#   Slice 55: starts at X=550, points=13384
#   Slice 56: starts at X=560, points=13625
#   Slice 57: starts at X=570, points=13602
#   Slice 58: starts at X=580, points=13612
#   Slice 59: starts at X=590, points=13634
#   Slice 60: starts at X=600, points=13629
#   Slice 61: starts at X=610, points=13608
#   Slice 62: starts at X=620, points=13634
#   Slice 63: starts at X=630, points=13671
#   Slice 64: starts at X=640, points=13687
#   Slice 65: starts at X=650, points=13645
#   Slice 66: starts at X=660, points=13730
#   Slice 67: starts at X=670, points=13722
#   Slice 68: starts at X=680, points=13732
#   Slice 69: starts at X=690, points=13747
#   Slice 70: starts at X=700, points=13718
#   Slice 71: starts at X=710, points=13752
#   Slice 72: starts at X=720, points=13756
#   Slice 73: starts at X=730, points=13763
#   Slice 74: starts at X=740, points=13762
#   Slice 75: starts at X=750, points=13786
#   Slice 76: starts at X=760, points=13807
#   Slice 77: starts at X=770, points=13578
#   Slice 78: starts at X=780, points=13577
#   Slice 79: starts at X=790, points=13775
#   Slice 80: starts at X=800, points=13835
#   Slice 81: starts at X=810, points=13825
#   Slice 82: starts at X=820, points=13848
#   Slice 83: starts at X=830, points=13856
#   Slice 84: starts at X=840, points=13696
#   Slice 85: starts at X=850, points=13692
#   Slice 86: starts at X=860, points=13854
#   Slice 87: starts at X=870, points=13880
#   Slice 88: starts at X=880, points=13933
#   Slice 89: starts at X=890, points=13945
#   Slice 90: starts at X=900, points=13937
#   Slice 91: starts at X=910, points=13948
#   Slice 92: starts at X=920, points=14001
#   Slice 93: starts at X=930, points=13998
#   Slice 94: starts at X=940, points=13844
#   Slice 95: starts at X=950, points=12426
#   Slice 96: starts at X=960, points=13844
#   Slice 97: starts at X=970, points=14041
#   Slice 98: starts at X=980, points=14017
#   Slice 99: starts at X=990, points=14023
#   Slice 100: starts at X=1000, points=14061
#   Slice 101: starts at X=1010, points=14080
#   Slice 102: starts at X=1020, points=14063
#   Slice 103: starts at X=1030, points=14063
#   Slice 104: starts at X=1040, points=14093
#   Slice 105: starts at X=1050, points=14131
#   Slice 106: starts at X=1060, points=14130
#   Slice 107: starts at X=1070, points=14116
#   Slice 108: starts at X=1080, points=14136
#   Slice 109: starts at X=1090, points=14170
#   Slice 110: starts at X=1100, points=14212
#   Slice 111: starts at X=1110, points=14099
#   Slice 112: starts at X=1120, points=14093
#   Slice 113: starts at X=1130, points=14119
#   Slice 114: starts at X=1140, points=14284
#   Slice 115: starts at X=1150, points=14257
#   Slice 116: starts at X=1160, points=14097
#   Slice 117: starts at X=1170, points=14148
#   Slice 118: starts at X=1180, points=14311
#   Slice 119: starts at X=1190, points=14327
#   Slice 120: starts at X=1200, points=14395
#   Slice 121: starts at X=1210, points=14436
#   Slice 122: starts at X=1220, points=14284
#   Slice 123: starts at X=1230, points=14266
#   Slice 124: starts at X=1240, points=14301
#   Slice 125: starts at X=1250, points=14501
#   Slice 126: starts at X=1260, points=14496
#   Slice 127: starts at X=1270, points=14518
#   Slice 128: starts at X=1280, points=14404
#   Slice 129: starts at X=1290, points=14437
#   Slice 130: starts at X=1300, points=14400
#   Slice 131: starts at X=1310, points=14592
#   Slice 132: starts at X=1320, points=14559
#   Slice 133: starts at X=1330, points=14641
#   Slice 134: starts at X=1340, points=14665
#   Slice 135: starts at X=1350, points=14618
#   Slice 136: starts at X=1360, points=14681
#   Slice 137: starts at X=1370, points=14721
#   Slice 138: starts at X=1380, points=14685
#   Slice 139: starts at X=1390, points=14724
#   Slice 140: starts at X=1400, points=14695
#   Slice 141: starts at X=1410, points=14763
#   Slice 142: starts at X=1420, points=14814
#   Slice 143: starts at X=1430, points=14673
#   Slice 144: starts at X=1440, points=14630
#   Slice 145: starts at X=1450, points=14683
#   Slice 146: starts at X=1460, points=14850
#   Slice 147: starts at X=1470, points=14871
#   Slice 148: starts at X=1480, points=14874
#   Slice 149: starts at X=1490, points=14845
#   Slice 150: starts at X=1500, points=14861
#   Slice 151: starts at X=1510, points=14940
#   Slice 152: starts at X=1520, points=14958
#   Slice 153: starts at X=1530, points=14901
#   Slice 154: starts at X=1540, points=14960
#   Slice 155: starts at X=1550, points=14857
#   Slice 156: starts at X=1560, points=14815
#   Slice 157: starts at X=1570, points=14857
#   Slice 158: starts at X=1580, points=15041
#   Slice 159: starts at X=1590, points=15062
#   Slice 160: starts at X=1600, points=15040
#   Slice 161: starts at X=1610, points=15031
#   Slice 162: starts at X=1620, points=14969
#   Slice 163: starts at X=1630, points=14849
#   Slice 164: starts at X=1640, points=15129
#   Slice 165: starts at X=1650, points=15224
#   Slice 166: starts at X=1660, points=15229
#   Slice 167: starts at X=1670, points=15177
#   Slice 168: starts at X=1680, points=15235
#   Slice 169: starts at X=1690, points=15266
#   Slice 170: starts at X=1700, points=15310
#   Slice 171: starts at X=1710, points=15288
#   Slice 172: starts at X=1720, points=15313
#   Slice 173: starts at X=1730, points=15356
#   Slice 174: starts at X=1740, points=15286
#   Slice 175: starts at X=1750, points=15190
#   Slice 176: starts at X=1760, points=15142
#   Slice 177: starts at X=1770, points=15138
#   Slice 178: starts at X=1780, points=15335
#   Slice 179: starts at X=1790, points=15039
#   Slice 180: starts at X=1800, points=15328
#   Slice 181: starts at X=1810, points=15470
#   Slice 182: starts at X=1820, points=15599
#   Slice 183: starts at X=1830, points=15596
#   Slice 184: starts at X=1840, points=15595
#   Slice 185: starts at X=1850, points=15645
#   Slice 186: starts at X=1860, points=15645
#   Slice 187: starts at X=1870, points=15607
#   Slice 188: starts at X=1880, points=15713
#   Slice 189: starts at X=1890, points=15677
#   Slice 190: starts at X=1900, points=15726
#   Slice 191: starts at X=1910, points=15768
#   Slice 192: starts at X=1920, points=15779
#   Slice 193: starts at X=1930, points=15793
#   Slice 194: starts at X=1940, points=15818
#   Slice 195: starts at X=1950, points=15799
#   Slice 196: starts at X=1960, points=15832
#   Slice 197: starts at X=1970, points=15929
#   Slice 198: starts at X=1980, points=15886
#   Slice 199: starts at X=1990, points=15977
#   Slice 200: starts at X=2000, points=15974
#   Slice 201: starts at X=2010, points=15909
#   Slice 202: starts at X=2020, points=15998
#   Slice 203: starts at X=2030, points=15899
#   Slice 204: starts at X=2040, points=15989
#   Slice 205: starts at X=2050, points=15970
#   Slice 206: starts at X=2060, points=15975
#   Slice 207: starts at X=2070, points=16072
#   Slice 208: starts at X=2080, points=15969
#   Slice 209: starts at X=2090, points=15617
#   Slice 210: starts at X=2100, points=15511
#   Slice 211: starts at X=2110, points=15431
#   Slice 212: starts at X=2120, points=15953
#   Slice 213: starts at X=2130, points=16010
#   Slice 214: starts at X=2140, points=16060
#   Slice 215: starts at X=2150, points=16079
#   Slice 216: starts at X=2160, points=16119
#   Slice 217: starts at X=2170, points=16003
#   Slice 218: starts at X=2180, points=16193
#   Slice 219: starts at X=2190, points=16233
#   Slice 220: starts at X=2200, points=16204
#   Slice 221: starts at X=2210, points=16286
#   Slice 222: starts at X=2220, points=16228
#   Slice 223: starts at X=2230, points=16169
#   Slice 224: starts at X=2240, points=16168
#   Slice 225: starts at X=2250, points=16190
#   Slice 226: starts at X=2260, points=16311
#   Slice 227: starts at X=2270, points=16306
#   Slice 228: starts at X=2280, points=16423
#   Slice 229: starts at X=2290, points=16412
#   Slice 230: starts at X=2300, points=16355
#   Slice 231: starts at X=2310, points=16488
#   Slice 232: starts at X=2320, points=16395
#   Slice 233: starts at X=2330, points=16455
#   Slice 234: starts at X=2340, points=16470
#   Slice 235: starts at X=2350, points=16488
#   Slice 236: starts at X=2360, points=16459
#   Slice 237: starts at X=2370, points=16477
#   Slice 238: starts at X=2380, points=16379
#   Slice 239: starts at X=2390, points=16249
#   Slice 240: starts at X=2400, points=16300
#   Slice 241: starts at X=2410, points=16355
#   Slice 242: starts at X=2420, points=16407
#   Slice 243: starts at X=2430, points=16359
#   Slice 244: starts at X=2440, points=1449
# Point cloud 3: 334 slices
#   Slice 0: starts at X=0, points=13742
#   Slice 1: starts at X=10, points=13507
#   Slice 2: starts at X=20, points=13538
#   Slice 3: starts at X=30, points=13276
#   Slice 4: starts at X=40, points=13432
#   Slice 5: starts at X=50, points=13421
#   Slice 6: starts at X=60, points=13465
#   Slice 7: starts at X=70, points=13592
#   Slice 8: starts at X=80, points=13558
#   Slice 9: starts at X=90, points=13560
#   Slice 10: starts at X=100, points=13522
#   Slice 11: starts at X=110, points=13511
#   Slice 12: starts at X=120, points=13525
#   Slice 13: starts at X=130, points=13489
#   Slice 14: starts at X=140, points=13469
#   Slice 15: starts at X=150, points=13441
#   Slice 16: starts at X=160, points=13462
#   Slice 17: starts at X=170, points=13421
#   Slice 18: starts at X=180, points=13395
#   Slice 19: starts at X=190, points=13414
#   Slice 20: starts at X=200, points=13380
#   Slice 21: starts at X=210, points=13353
#   Slice 22: starts at X=220, points=13337
#   Slice 23: starts at X=230, points=13350
#   Slice 24: starts at X=240, points=13323
#   Slice 25: starts at X=250, points=13255
#   Slice 26: starts at X=260, points=13254
#   Slice 27: starts at X=270, points=13293
#   Slice 28: starts at X=280, points=13187
#   Slice 29: starts at X=290, points=13162
#   Slice 30: starts at X=300, points=13203
#   Slice 31: starts at X=310, points=13188
#   Slice 32: starts at X=320, points=13122
#   Slice 33: starts at X=330, points=13105
#   Slice 34: starts at X=340, points=13120
#   Slice 35: starts at X=350, points=13094
#   Slice 36: starts at X=360, points=13022
#   Slice 37: starts at X=370, points=12989
#   Slice 38: starts at X=380, points=12933
#   Slice 39: starts at X=390, points=12910
#   Slice 40: starts at X=400, points=12917
#   Slice 41: starts at X=410, points=12868
#   Slice 42: starts at X=420, points=12856
#   Slice 43: starts at X=430, points=12862
#   Slice 44: starts at X=440, points=12850
#   Slice 45: starts at X=450, points=12652
#   Slice 46: starts at X=460, points=12262
#   Slice 47: starts at X=470, points=12185
#   Slice 48: starts at X=480, points=12148
#   Slice 49: starts at X=490, points=12611
#   Slice 50: starts at X=500, points=12717
#   Slice 51: starts at X=510, points=12745
#   Slice 52: starts at X=520, points=12694
#   Slice 53: starts at X=530, points=12660
#   Slice 54: starts at X=540, points=12651
#   Slice 55: starts at X=550, points=12655
#   Slice 56: starts at X=560, points=12610
#   Slice 57: starts at X=570, points=12572
#   Slice 58: starts at X=580, points=12580
#   Slice 59: starts at X=590, points=12559
#   Slice 60: starts at X=600, points=12516
#   Slice 61: starts at X=610, points=12523
#   Slice 62: starts at X=620, points=12500
#   Slice 63: starts at X=630, points=12443
#   Slice 64: starts at X=640, points=12443
#   Slice 65: starts at X=650, points=12430
#   Slice 66: starts at X=660, points=12412
#   Slice 67: starts at X=670, points=12395
#   Slice 68: starts at X=680, points=12386
#   Slice 69: starts at X=690, points=12347
#   Slice 70: starts at X=700, points=12314
#   Slice 71: starts at X=710, points=12285
#   Slice 72: starts at X=720, points=12236
#   Slice 73: starts at X=730, points=12276
#   Slice 74: starts at X=740, points=12222
#   Slice 75: starts at X=750, points=12202
#   Slice 76: starts at X=760, points=12212
#   Slice 77: starts at X=770, points=12178
#   Slice 78: starts at X=780, points=12168
#   Slice 79: starts at X=790, points=12174
#   Slice 80: starts at X=800, points=12133
#   Slice 81: starts at X=810, points=12100
#   Slice 82: starts at X=820, points=12097
#   Slice 83: starts at X=830, points=12075
#   Slice 84: starts at X=840, points=12052
#   Slice 85: starts at X=850, points=12010
#   Slice 86: starts at X=860, points=11823
#   Slice 87: starts at X=870, points=11603
#   Slice 88: starts at X=880, points=11636
#   Slice 89: starts at X=890, points=11711
#   Slice 90: starts at X=900, points=11696
#   Slice 91: starts at X=910, points=11648
#   Slice 92: starts at X=920, points=11536
#   Slice 93: starts at X=930, points=11522
#   Slice 94: starts at X=940, points=11461
#   Slice 95: starts at X=950, points=11762
#   Slice 96: starts at X=960, points=11779
#   Slice 97: starts at X=970, points=11739
#   Slice 98: starts at X=980, points=11726
#   Slice 99: starts at X=990, points=11696
#   Slice 100: starts at X=1000, points=11650
#   Slice 101: starts at X=1010, points=11649
#   Slice 102: starts at X=1020, points=11658
#   Slice 103: starts at X=1030, points=11628
#   Slice 104: starts at X=1040, points=11602
#   Slice 105: starts at X=1050, points=11561
#   Slice 106: starts at X=1060, points=11526
#   Slice 107: starts at X=1070, points=11511
#   Slice 108: starts at X=1080, points=11502
#   Slice 109: starts at X=1090, points=11473
#   Slice 110: starts at X=1100, points=11435
#   Slice 111: starts at X=1110, points=11191
#   Slice 112: starts at X=1120, points=11255
#   Slice 113: starts at X=1130, points=11150
#   Slice 114: starts at X=1140, points=11321
#   Slice 115: starts at X=1150, points=11380
#   Slice 116: starts at X=1160, points=11378
#   Slice 117: starts at X=1170, points=11297
#   Slice 118: starts at X=1180, points=11106
#   Slice 119: starts at X=1190, points=11076
#   Slice 120: starts at X=1200, points=11029
#   Slice 121: starts at X=1210, points=11186
#   Slice 122: starts at X=1220, points=11197
#   Slice 123: starts at X=1230, points=11225
#   Slice 124: starts at X=1240, points=11195
#   Slice 125: starts at X=1250, points=11174
#   Slice 126: starts at X=1260, points=11155
#   Slice 127: starts at X=1270, points=11147
#   Slice 128: starts at X=1280, points=11051
#   Slice 129: starts at X=1290, points=11105
#   Slice 130: starts at X=1300, points=11086
#   Slice 131: starts at X=1310, points=11092
#   Slice 132: starts at X=1320, points=11062
#   Slice 133: starts at X=1330, points=11022
#   Slice 134: starts at X=1340, points=10963
#   Slice 135: starts at X=1350, points=10791
#   Slice 136: starts at X=1360, points=10789
#   Slice 137: starts at X=1370, points=10742
#   Slice 138: starts at X=1380, points=10931
#   Slice 139: starts at X=1390, points=10872
#   Slice 140: starts at X=1400, points=10858
#   Slice 141: starts at X=1410, points=10813
#   Slice 142: starts at X=1420, points=10778
#   Slice 143: starts at X=1430, points=10825
#   Slice 144: starts at X=1440, points=10840
#   Slice 145: starts at X=1450, points=10748
#   Slice 146: starts at X=1460, points=10722
#   Slice 147: starts at X=1470, points=10817
#   Slice 148: starts at X=1480, points=10765
#   Slice 149: starts at X=1490, points=10663
#   Slice 150: starts at X=1500, points=10719
#   Slice 151: starts at X=1510, points=10726
#   Slice 152: starts at X=1520, points=10643
#   Slice 153: starts at X=1530, points=10661
#   Slice 154: starts at X=1540, points=10657
#   Slice 155: starts at X=1550, points=10631
#   Slice 156: starts at X=1560, points=10415
#   Slice 157: starts at X=1570, points=10419
#   Slice 158: starts at X=1580, points=10458
#   Slice 159: starts at X=1590, points=10450
#   Slice 160: starts at X=1600, points=10526
#   Slice 161: starts at X=1610, points=10544
#   Slice 162: starts at X=1620, points=10574
#   Slice 163: starts at X=1630, points=10522
#   Slice 164: starts at X=1640, points=10472
#   Slice 165: starts at X=1650, points=10228
#   Slice 166: starts at X=1660, points=10290
#   Slice 167: starts at X=1670, points=10246
#   Slice 168: starts at X=1680, points=10309
#   Slice 169: starts at X=1690, points=10420
#   Slice 170: starts at X=1700, points=10441
#   Slice 171: starts at X=1710, points=10388
#   Slice 172: starts at X=1720, points=10310
#   Slice 173: starts at X=1730, points=10341
#   Slice 174: starts at X=1740, points=10316
#   Slice 175: starts at X=1750, points=10042
#   Slice 176: starts at X=1760, points=10021
#   Slice 177: starts at X=1770, points=10053
#   Slice 178: starts at X=1780, points=10231
#   Slice 179: starts at X=1790, points=10194
#   Slice 180: starts at X=1800, points=10227
#   Slice 181: starts at X=1810, points=10243
#   Slice 182: starts at X=1820, points=10177
#   Slice 183: starts at X=1830, points=9981
#   Slice 184: starts at X=1840, points=10011
#   Slice 185: starts at X=1850, points=10012
#   Slice 186: starts at X=1860, points=10072
#   Slice 187: starts at X=1870, points=10068
#   Slice 188: starts at X=1880, points=10024
#   Slice 189: starts at X=1890, points=10022
#   Slice 190: starts at X=1900, points=10009
#   Slice 191: starts at X=1910, points=9977
#   Slice 192: starts at X=1920, points=9997
#   Slice 193: starts at X=1930, points=9978
#   Slice 194: starts at X=1940, points=9961
#   Slice 195: starts at X=1950, points=9966
#   Slice 196: starts at X=1960, points=9940
#   Slice 197: starts at X=1970, points=9877
#   Slice 198: starts at X=1980, points=9891
#   Slice 199: starts at X=1990, points=9882
#   Slice 200: starts at X=2000, points=9831
#   Slice 201: starts at X=2010, points=9779
#   Slice 202: starts at X=2020, points=9804
#   Slice 203: starts at X=2030, points=9691
#   Slice 204: starts at X=2040, points=9501
#   Slice 205: starts at X=2050, points=9535
#   Slice 206: starts at X=2060, points=9519
#   Slice 207: starts at X=2070, points=9675
#   Slice 208: starts at X=2080, points=9635
#   Slice 209: starts at X=2090, points=9613
#   Slice 210: starts at X=2100, points=9638
#   Slice 211: starts at X=2110, points=9590
#   Slice 212: starts at X=2120, points=9554
#   Slice 213: starts at X=2130, points=9527
#   Slice 214: starts at X=2140, points=9538
#   Slice 215: starts at X=2150, points=9489
#   Slice 216: starts at X=2160, points=9435
#   Slice 217: starts at X=2170, points=9296
#   Slice 218: starts at X=2180, points=9231
#   Slice 219: starts at X=2190, points=9160
#   Slice 220: starts at X=2200, points=9335
#   Slice 221: starts at X=2210, points=9346
#   Slice 222: starts at X=2220, points=9306
#   Slice 223: starts at X=2230, points=9264
#   Slice 224: starts at X=2240, points=9108
#   Slice 225: starts at X=2250, points=9000
#   Slice 226: starts at X=2260, points=8947
#   Slice 227: starts at X=2270, points=9152
#   Slice 228: starts at X=2280, points=9113
#   Slice 229: starts at X=2290, points=9114
#   Slice 230: starts at X=2300, points=9078
#   Slice 231: starts at X=2310, points=9002
#   Slice 232: starts at X=2320, points=8993
#   Slice 233: starts at X=2330, points=8964
#   Slice 234: starts at X=2340, points=8883
#   Slice 235: starts at X=2350, points=8902
#   Slice 236: starts at X=2360, points=8870
#   Slice 237: starts at X=2370, points=8822
#   Slice 238: starts at X=2380, points=8814
#   Slice 239: starts at X=2390, points=8804
#   Slice 240: starts at X=2400, points=8777
#   Slice 241: starts at X=2410, points=8744
#   Slice 242: starts at X=2420, points=8679
#   Slice 243: starts at X=2430, points=8588
#   Slice 244: starts at X=2440, points=8595
#   Slice 245: starts at X=2450, points=8584
#   Slice 246: starts at X=2460, points=8541
#   Slice 247: starts at X=2470, points=8514
#   Slice 248: starts at X=2480, points=8487
#   Slice 249: starts at X=2490, points=8424
#   Slice 250: starts at X=2500, points=8464
#   Slice 251: starts at X=2510, points=8230
#   Slice 252: starts at X=2520, points=8180
#   Slice 253: starts at X=2530, points=8095
#   Slice 254: starts at X=2540, points=8291
#   Slice 255: starts at X=2550, points=8259
#   Slice 256: starts at X=2560, points=8290
#   Slice 257: starts at X=2570, points=8259
#   Slice 258: starts at X=2580, points=8174
#   Slice 259: starts at X=2590, points=8174
#   Slice 260: starts at X=2600, points=8189
#   Slice 261: starts at X=2610, points=8121
#   Slice 262: starts at X=2620, points=8115
#   Slice 263: starts at X=2630, points=8082
#   Slice 264: starts at X=2640, points=8060
#   Slice 265: starts at X=2650, points=8069
#   Slice 266: starts at X=2660, points=7971
#   Slice 267: starts at X=2670, points=7982
#   Slice 268: starts at X=2680, points=7979
#   Slice 269: starts at X=2690, points=7914
#   Slice 270: starts at X=2700, points=7898
#   Slice 271: starts at X=2710, points=7870
#   Slice 272: starts at X=2720, points=7608
#   Slice 273: starts at X=2730, points=7603
#   Slice 274: starts at X=2740, points=7550
#   Slice 275: starts at X=2750, points=7528
#   Slice 276: starts at X=2760, points=7745
#   Slice 277: starts at X=2770, points=7733
#   Slice 278: starts at X=2780, points=7738
#   Slice 279: starts at X=2790, points=7744
#   Slice 280: starts at X=2800, points=7659
#   Slice 281: starts at X=2810, points=7641
#   Slice 282: starts at X=2820, points=7717
#   Slice 283: starts at X=2830, points=7638
#   Slice 284: starts at X=2840, points=7647
#   Slice 285: starts at X=2850, points=7543
#   Slice 286: starts at X=2860, points=7455
#   Slice 287: starts at X=2870, points=7543
#   Slice 288: starts at X=2880, points=7329
#   Slice 289: starts at X=2890, points=7242
#   Slice 290: starts at X=2900, points=7171
#   Slice 291: starts at X=2910, points=7349
#   Slice 292: starts at X=2920, points=7387
#   Slice 293: starts at X=2930, points=7362
#   Slice 294: starts at X=2940, points=7333
#   Slice 295: starts at X=2950, points=7348
#   Slice 296: starts at X=2960, points=7330
#   Slice 297: starts at X=2970, points=7292
#   Slice 298: starts at X=2980, points=7295
#   Slice 299: starts at X=2990, points=7298
#   Slice 300: starts at X=3000, points=7263
#   Slice 301: starts at X=3010, points=7276
#   Slice 302: starts at X=3020, points=7290
#   Slice 303: starts at X=3030, points=7268
#   Slice 304: starts at X=3040, points=7239
#   Slice 305: starts at X=3050, points=7254
#   Slice 306: starts at X=3060, points=7257
#   Slice 307: starts at X=3070, points=7246
#   Slice 308: starts at X=3080, points=7190
#   Slice 309: starts at X=3090, points=7196
#   Slice 310: starts at X=3100, points=7242
#   Slice 311: starts at X=3110, points=7188
#   Slice 312: starts at X=3120, points=7203
#   Slice 313: starts at X=3130, points=7228
#   Slice 314: starts at X=3140, points=7143
#   Slice 315: starts at X=3150, points=7134
#   Slice 316: starts at X=3160, points=7194
#   Slice 317: starts at X=3170, points=7162
#   Slice 318: starts at X=3180, points=7117
#   Slice 319: starts at X=3190, points=7137
#   Slice 320: starts at X=3200, points=7129
#   Slice 321: starts at X=3210, points=7076
#   Slice 322: starts at X=3220, points=7077
#   Slice 323: starts at X=3230, points=7031
#   Slice 324: starts at X=3240, points=7010
#   Slice 325: starts at X=3250, points=6971
#   Slice 326: starts at X=3260, points=6526
#   Slice 327: starts at X=3270, points=6584
#   Slice 328: starts at X=3280, points=6537
#   Slice 329: starts at X=3290, points=6604
#   Slice 330: starts at X=3300, points=6907
#   Slice 331: starts at X=3310, points=5948
#   Slice 332: starts at X=3320, points=2626
#   Slice 333: starts at X=3330, points=2394
# Point cloud 4: 331 slices
#   Slice 0: starts at X=0, points=10483
#   Slice 1: starts at X=10, points=13183
#   Slice 2: starts at X=20, points=13361
#   Slice 3: starts at X=30, points=13025
#   Slice 4: starts at X=40, points=13094
#   Slice 5: starts at X=50, points=13261
#   Slice 6: starts at X=60, points=13459
#   Slice 7: starts at X=70, points=13717
#   Slice 8: starts at X=80, points=13638
#   Slice 9: starts at X=90, points=13558
#   Slice 10: starts at X=100, points=13560
#   Slice 11: starts at X=110, points=13513
#   Slice 12: starts at X=120, points=13374
#   Slice 13: starts at X=130, points=13382
#   Slice 14: starts at X=140, points=13419
#   Slice 15: starts at X=150, points=13290
#   Slice 16: starts at X=160, points=13176
#   Slice 17: starts at X=170, points=13216
#   Slice 18: starts at X=180, points=13193
#   Slice 19: starts at X=190, points=13066
#   Slice 20: starts at X=200, points=13008
#   Slice 21: starts at X=210, points=13008
#   Slice 22: starts at X=220, points=12960
#   Slice 23: starts at X=230, points=12810
#   Slice 24: starts at X=240, points=12763
#   Slice 25: starts at X=250, points=12716
#   Slice 26: starts at X=260, points=12598
#   Slice 27: starts at X=270, points=12574
#   Slice 28: starts at X=280, points=12536
#   Slice 29: starts at X=290, points=12424
#   Slice 30: starts at X=300, points=12398
#   Slice 31: starts at X=310, points=12283
#   Slice 32: starts at X=320, points=12072
#   Slice 33: starts at X=330, points=12062
#   Slice 34: starts at X=340, points=12001
#   Slice 35: starts at X=350, points=11958
#   Slice 36: starts at X=360, points=11980
#   Slice 37: starts at X=370, points=11985
#   Slice 38: starts at X=380, points=11936
#   Slice 39: starts at X=390, points=11940
#   Slice 40: starts at X=400, points=11856
#   Slice 41: starts at X=410, points=11762
#   Slice 42: starts at X=420, points=11789
#   Slice 43: starts at X=430, points=11732
#   Slice 44: starts at X=440, points=11605
#   Slice 45: starts at X=450, points=11624
#   Slice 46: starts at X=460, points=11359
#   Slice 47: starts at X=470, points=11337
#   Slice 48: starts at X=480, points=11535
#   Slice 49: starts at X=490, points=11432
#   Slice 50: starts at X=500, points=11399
#   Slice 51: starts at X=510, points=11417
#   Slice 52: starts at X=520, points=11368
#   Slice 53: starts at X=530, points=11338
#   Slice 54: starts at X=540, points=11276
#   Slice 55: starts at X=550, points=11272
#   Slice 56: starts at X=560, points=11300
#   Slice 57: starts at X=570, points=11182
#   Slice 58: starts at X=580, points=11255
#   Slice 59: starts at X=590, points=11190
#   Slice 60: starts at X=600, points=11067
#   Slice 61: starts at X=610, points=11117
#   Slice 62: starts at X=620, points=11176
#   Slice 63: starts at X=630, points=10951
#   Slice 64: starts at X=640, points=10894
#   Slice 65: starts at X=650, points=10823
#   Slice 66: starts at X=660, points=10694
#   Slice 67: starts at X=670, points=10834
#   Slice 68: starts at X=680, points=10836
#   Slice 69: starts at X=690, points=10969
#   Slice 70: starts at X=700, points=11000
#   Slice 71: starts at X=710, points=11028
#   Slice 72: starts at X=720, points=10914
#   Slice 73: starts at X=730, points=10934
#   Slice 74: starts at X=740, points=10980
#   Slice 75: starts at X=750, points=10902
#   Slice 76: starts at X=760, points=10987
#   Slice 77: starts at X=770, points=10979
#   Slice 78: starts at X=780, points=10923
#   Slice 79: starts at X=790, points=10925
#   Slice 80: starts at X=800, points=10975
#   Slice 81: starts at X=810, points=10936
#   Slice 82: starts at X=820, points=10952
#   Slice 83: starts at X=830, points=11040
#   Slice 84: starts at X=840, points=11024
#   Slice 85: starts at X=850, points=10947
#   Slice 86: starts at X=860, points=11031
#   Slice 87: starts at X=870, points=11110
#   Slice 88: starts at X=880, points=11052
#   Slice 89: starts at X=890, points=11062
#   Slice 90: starts at X=900, points=11147
#   Slice 91: starts at X=910, points=11137
#   Slice 92: starts at X=920, points=11146
#   Slice 93: starts at X=930, points=11214
#   Slice 94: starts at X=940, points=11260
#   Slice 95: starts at X=950, points=11099
#   Slice 96: starts at X=960, points=11149
#   Slice 97: starts at X=970, points=11192
#   Slice 98: starts at X=980, points=11202
#   Slice 99: starts at X=990, points=11385
#   Slice 100: starts at X=1000, points=11427
#   Slice 101: starts at X=1010, points=11462
#   Slice 102: starts at X=1020, points=11500
#   Slice 103: starts at X=1030, points=11432
#   Slice 104: starts at X=1040, points=11467
#   Slice 105: starts at X=1050, points=11501
#   Slice 106: starts at X=1060, points=11647
#   Slice 107: starts at X=1070, points=11697
#   Slice 108: starts at X=1080, points=11732
#   Slice 109: starts at X=1090, points=11780
#   Slice 110: starts at X=1100, points=11826
#   Slice 111: starts at X=1110, points=11860
#   Slice 112: starts at X=1120, points=11906
#   Slice 113: starts at X=1130, points=11987
#   Slice 114: starts at X=1140, points=12020
#   Slice 115: starts at X=1150, points=12034
#   Slice 116: starts at X=1160, points=12154
#   Slice 117: starts at X=1170, points=12224
#   Slice 118: starts at X=1180, points=12115
#   Slice 119: starts at X=1190, points=12034
#   Slice 120: starts at X=1200, points=12190
#   Slice 121: starts at X=1210, points=12268
#   Slice 122: starts at X=1220, points=12410
#   Slice 123: starts at X=1230, points=12490
#   Slice 124: starts at X=1240, points=12632
#   Slice 125: starts at X=1250, points=12742
#   Slice 126: starts at X=1260, points=12902
#   Slice 127: starts at X=1270, points=12847
#   Slice 128: starts at X=1280, points=12886
#   Slice 129: starts at X=1290, points=13058
#   Slice 130: starts at X=1300, points=13122
#   Slice 131: starts at X=1310, points=13067
#   Slice 132: starts at X=1320, points=13163
#   Slice 133: starts at X=1330, points=13281
#   Slice 134: starts at X=1340, points=13324
#   Slice 135: starts at X=1350, points=13356
#   Slice 136: starts at X=1360, points=13428
#   Slice 137: starts at X=1370, points=13538
#   Slice 138: starts at X=1380, points=13615
#   Slice 139: starts at X=1390, points=13640
#   Slice 140: starts at X=1400, points=13656
#   Slice 141: starts at X=1410, points=13485
#   Slice 142: starts at X=1420, points=13570
#   Slice 143: starts at X=1430, points=13519
#   Slice 144: starts at X=1440, points=13834
#   Slice 145: starts at X=1450, points=14013
#   Slice 146: starts at X=1460, points=14032
#   Slice 147: starts at X=1470, points=14082
#   Slice 148: starts at X=1480, points=14045
#   Slice 149: starts at X=1490, points=14030
#   Slice 150: starts at X=1500, points=14037
#   Slice 151: starts at X=1510, points=14238
#   Slice 152: starts at X=1520, points=14261
#   Slice 153: starts at X=1530, points=14257
#   Slice 154: starts at X=1540, points=14278
#   Slice 155: starts at X=1550, points=14381
#   Slice 156: starts at X=1560, points=14395
#   Slice 157: starts at X=1570, points=14384
#   Slice 158: starts at X=1580, points=14567
#   Slice 159: starts at X=1590, points=14350
#   Slice 160: starts at X=1600, points=14416
#   Slice 161: starts at X=1610, points=14498
#   Slice 162: starts at X=1620, points=14731
#   Slice 163: starts at X=1630, points=14687
#   Slice 164: starts at X=1640, points=14807
#   Slice 165: starts at X=1650, points=14826
#   Slice 166: starts at X=1660, points=14774
#   Slice 167: starts at X=1670, points=14885
#   Slice 168: starts at X=1680, points=14775
#   Slice 169: starts at X=1690, points=14729
#   Slice 170: starts at X=1700, points=14791
#   Slice 171: starts at X=1710, points=14926
#   Slice 172: starts at X=1720, points=14942
#   Slice 173: starts at X=1730, points=15141
#   Slice 174: starts at X=1740, points=15175
#   Slice 175: starts at X=1750, points=14993
#   Slice 176: starts at X=1760, points=15125
#   Slice 177: starts at X=1770, points=15084
#   Slice 178: starts at X=1780, points=15072
#   Slice 179: starts at X=1790, points=15156
#   Slice 180: starts at X=1800, points=15218
#   Slice 181: starts at X=1810, points=15338
#   Slice 182: starts at X=1820, points=15381
#   Slice 183: starts at X=1830, points=15375
#   Slice 184: starts at X=1840, points=15342
#   Slice 185: starts at X=1850, points=15418
#   Slice 186: starts at X=1860, points=15438
#   Slice 187: starts at X=1870, points=15407
#   Slice 188: starts at X=1880, points=15504
#   Slice 189: starts at X=1890, points=15532
#   Slice 190: starts at X=1900, points=15473
#   Slice 191: starts at X=1910, points=15303
#   Slice 192: starts at X=1920, points=15350
#   Slice 193: starts at X=1930, points=15266
#   Slice 194: starts at X=1940, points=15541
#   Slice 195: starts at X=1950, points=15603
#   Slice 196: starts at X=1960, points=15579
#   Slice 197: starts at X=1970, points=15672
#   Slice 198: starts at X=1980, points=15725
#   Slice 199: starts at X=1990, points=15704
#   Slice 200: starts at X=2000, points=15577
#   Slice 201: starts at X=2010, points=15618
#   Slice 202: starts at X=2020, points=15619
#   Slice 203: starts at X=2030, points=15560
#   Slice 204: starts at X=2040, points=15714
#   Slice 205: starts at X=2050, points=15743
#   Slice 206: starts at X=2060, points=15738
#   Slice 207: starts at X=2070, points=15675
#   Slice 208: starts at X=2080, points=15795
#   Slice 209: starts at X=2090, points=15796
#   Slice 210: starts at X=2100, points=15656
#   Slice 211: starts at X=2110, points=15762
#   Slice 212: starts at X=2120, points=15752
#   Slice 213: starts at X=2130, points=15750
#   Slice 214: starts at X=2140, points=15970
#   Slice 215: starts at X=2150, points=15951
#   Slice 216: starts at X=2160, points=15941
#   Slice 217: starts at X=2170, points=15908
#   Slice 218: starts at X=2180, points=15963
#   Slice 219: starts at X=2190, points=15930
#   Slice 220: starts at X=2200, points=15734
#   Slice 221: starts at X=2210, points=15884
#   Slice 222: starts at X=2220, points=15931
#   Slice 223: starts at X=2230, points=15997
#   Slice 224: starts at X=2240, points=16180
#   Slice 225: starts at X=2250, points=16145
#   Slice 226: starts at X=2260, points=16185
#   Slice 227: starts at X=2270, points=16291
#   Slice 228: starts at X=2280, points=16259
#   Slice 229: starts at X=2290, points=16311
#   Slice 230: starts at X=2300, points=16408
#   Slice 231: starts at X=2310, points=16364
#   Slice 232: starts at X=2320, points=16222
#   Slice 233: starts at X=2330, points=16360
#   Slice 234: starts at X=2340, points=16338
#   Slice 235: starts at X=2350, points=16263
#   Slice 236: starts at X=2360, points=16171
#   Slice 237: starts at X=2370, points=16273
#   Slice 238: starts at X=2380, points=16272
#   Slice 239: starts at X=2390, points=16237
#   Slice 240: starts at X=2400, points=16300
#   Slice 241: starts at X=2410, points=16162
#   Slice 242: starts at X=2420, points=16048
#   Slice 243: starts at X=2430, points=16052
#   Slice 244: starts at X=2440, points=15978
#   Slice 245: starts at X=2450, points=16087
#   Slice 246: starts at X=2460, points=16288
#   Slice 247: starts at X=2470, points=16236
#   Slice 248: starts at X=2480, points=16102
#   Slice 249: starts at X=2490, points=16189
#   Slice 250: starts at X=2500, points=16196
#   Slice 251: starts at X=2510, points=16450
#   Slice 252: starts at X=2520, points=16386
#   Slice 253: starts at X=2530, points=16402
#   Slice 254: starts at X=2540, points=16204
#   Slice 255: starts at X=2550, points=16192
#   Slice 256: starts at X=2560, points=16297
#   Slice 257: starts at X=2570, points=16291
#   Slice 258: starts at X=2580, points=16318
#   Slice 259: starts at X=2590, points=16436
#   Slice 260: starts at X=2600, points=16491
#   Slice 261: starts at X=2610, points=16354
#   Slice 262: starts at X=2620, points=16516
#   Slice 263: starts at X=2630, points=16501
#   Slice 264: starts at X=2640, points=16435
#   Slice 265: starts at X=2650, points=16596
#   Slice 266: starts at X=2660, points=16617
#   Slice 267: starts at X=2670, points=16465
#   Slice 268: starts at X=2680, points=16660
#   Slice 269: starts at X=2690, points=16681
#   Slice 270: starts at X=2700, points=16612
#   Slice 271: starts at X=2710, points=16678
#   Slice 272: starts at X=2720, points=16663
#   Slice 273: starts at X=2730, points=16782
#   Slice 274: starts at X=2740, points=16876
#   Slice 275: starts at X=2750, points=16792
#   Slice 276: starts at X=2760, points=16848
#   Slice 277: starts at X=2770, points=16854
#   Slice 278: starts at X=2780, points=16812
#   Slice 279: starts at X=2790, points=16853
#   Slice 280: starts at X=2800, points=16008
#   Slice 281: starts at X=2810, points=16831
#   Slice 282: starts at X=2820, points=16722
#   Slice 283: starts at X=2830, points=16856
#   Slice 284: starts at X=2840, points=16881
#   Slice 285: starts at X=2850, points=16794
#   Slice 286: starts at X=2860, points=16849
#   Slice 287: starts at X=2870, points=16799
#   Slice 288: starts at X=2880, points=16424
#   Slice 289: starts at X=2890, points=16403
#   Slice 290: starts at X=2900, points=16311
#   Slice 291: starts at X=2910, points=16667
#   Slice 292: starts at X=2920, points=16918
#   Slice 293: starts at X=2930, points=16989
#   Slice 294: starts at X=2940, points=16834
#   Slice 295: starts at X=2950, points=17016
#   Slice 296: starts at X=2960, points=16973
#   Slice 297: starts at X=2970, points=17006
#   Slice 298: starts at X=2980, points=17129
#   Slice 299: starts at X=2990, points=16997
#   Slice 300: starts at X=3000, points=16883
#   Slice 301: starts at X=3010, points=17009
#   Slice 302: starts at X=3020, points=17112
#   Slice 303: starts at X=3030, points=17059
#   Slice 304: starts at X=3040, points=17205
#   Slice 305: starts at X=3050, points=17211
#   Slice 306: starts at X=3060, points=17064
#   Slice 307: starts at X=3070, points=17141
#   Slice 308: starts at X=3080, points=17033
#   Slice 309: starts at X=3090, points=17148
#   Slice 310: starts at X=3100, points=17180
#   Slice 311: starts at X=3110, points=17257
#   Slice 312: starts at X=3120, points=17374
#   Slice 313: starts at X=3130, points=17418
#   Slice 314: starts at X=3140, points=17386
#   Slice 315: starts at X=3150, points=17356
#   Slice 316: starts at X=3160, points=17424
#   Slice 317: starts at X=3170, points=17535
#   Slice 318: starts at X=3180, points=17550
#   Slice 319: starts at X=3190, points=17549
#   Slice 320: starts at X=3200, points=17624
#   Slice 321: starts at X=3210, points=17562
#   Slice 322: starts at X=3220, points=17566
#   Slice 323: starts at X=3230, points=17448
#   Slice 324: starts at X=3240, points=17422
#   Slice 325: starts at X=3250, points=17516
#   Slice 326: starts at X=3260, points=17637
#   Slice 327: starts at X=3270, points=17821
#   Slice 328: starts at X=3280, points=17054
#   Slice 329: starts at X=3290, points=14587
#   Slice 330: starts at X=3300, points=2692

# %% [markdown]
# The slices are of uneven size. I will pad them with 0's to make them the same size.

# %%
# Find the maximum number of points in any slice across all clouds
max_points = 0
for cloud_slices in all_slices:
    for s in cloud_slices:
        if s.shape[0] > max_points:
            max_points = s.shape[0]

# Pad each slice with zeros to have the same number of points (along axis 0)
padded_slices = []
for cloud_idx, cloud_slices in enumerate(all_slices):
    padded_cloud = []
    for slice_idx, s in enumerate(cloud_slices):
        n_points = s.shape[0]
        if n_points < max_points:
            # Pad with zeros
            pad_width = ((0, max_points - n_points), (0, 0))
            s_padded = np.pad(s, pad_width, mode='constant', constant_values=0)
        else:
            s_padded = s
        padded_cloud.append(s_padded)
    padded_slices.append(padded_cloud)

print(f"All slices are now padded to {max_points} points each.")
# Out:
# All slices are now padded to 20483 points each.

# %% [markdown]
# # Saving the slices

# %%
# Create output directory for slices
slices_dir = diff_dir.replace("difference", "slices")
os.makedirs(slices_dir, exist_ok=True)

# Save all slices of each point cloud into a single .npy file
for cloud_idx, (cloud_slices, fname) in enumerate(zip(padded_slices, npy_files)):
    base_name = os.path.splitext(fname)[0]
    # Stack slices into a 3D array: (num_slices, max_points, 3)
    stacked = np.stack(cloud_slices, axis=0)
    outname = f"{base_name}_slices.npy"
    outpath = os.path.join(slices_dir, outname)
    np.save(outpath, stacked)
    print(f"Saved: {outpath}")
# Out:
# Saved: ../scandata/slices loess frac=0.20/221111_144114__binary_onlylines114378to117271 loess frac=0.2_difference_slices.npy
# Saved: ../scandata/slices loess frac=0.20/221111_144114__binary_onlylines145900to148050 loess frac=0.2_difference_slices.npy
# Saved: ../scandata/slices loess frac=0.20/221111_144114__binary_onlylines25660to28100 loess frac=0.2_difference_slices.npy
# Saved: ../scandata/slices loess frac=0.20/221111_144114__binary_onlylines47178to50517 loess frac=0.2_difference_slices.npy
# Saved: ../scandata/slices loess frac=0.20/221111_144114__binary_onlylines86841to90142 loess frac=0.2_difference_slices.npy

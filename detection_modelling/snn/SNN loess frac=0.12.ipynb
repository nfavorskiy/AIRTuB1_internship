# %% [markdown]
# # Sequential Neural Network
# In this notebook I will train a Sequential Neural Network for detection of erosion.

# %%
# Adjust the frac parameter for loess smoothing
# to control the degree of smoothing applied to the scan data.
labeled_dir = "../../scandata/slices loess frac=0.12_labeled"

masks_path = "../stratified_k-fold_masks.npy"

DetectionNotClassification = True  # Set to True to replace all non-zero labels with 1

# %% [markdown]
# Libraries used:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.metrics import AUC

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, roc_auc_score
)

from sklearn.preprocessing import StandardScaler

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# Use GPU if available
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
print("TensorFlow version:", tf.__version__)
# Out:
# 2025-08-18 18:02:19.100330: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-18 18:02:19.111547: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755540139.124041   74076 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755540139.128043   74076 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755540139.139012   74076 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755540139.139037   74076 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755540139.139038   74076 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755540139.139039   74076 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-18 18:02:19.143267: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Num GPUs Available: 1
# TensorFlow version: 2.19.0

# %%
all_masks = np.load(masks_path, allow_pickle=True)

# List all labeled files
labeled_files = [f for f in os.listdir(labeled_dir) if f.endswith("_slices_labeled.npy")]
selected_files = labeled_files  # Use all files by default

# %%
# Load features (X) and labels (y) for each file
all_X = []
all_y = []
for labeled_file in selected_files:
    data = np.load(os.path.join(labeled_dir, labeled_file), allow_pickle=True).item()
    slices = data["slices"]  # shape: (num_slices, max_points, 3)
    labels = data["labels"]  # shape: (num_slices,)

    X = slices[:, :, 2]  # shape: (num_slices, max_points)
    if DetectionNotClassification:
        y = (labels != 0).astype(int)
    else:
        y = labels  # keep original labels for multiclass
    all_X.append(X)
    all_y.append(y)

# %%
# Cross-validation using stratified k-Fold masks
n_folds = len(all_masks[0])
results = []

for file_idx, (X, y, masks) in enumerate(zip(all_X, all_y, all_masks)):
    file_results = []
    n_classes = len(np.unique(y))
    for fold_idx, val_mask in enumerate(masks):
        train_mask = ~val_mask
        X_train, y_train = X[train_mask], y[train_mask]
        X_val, y_val = X[val_mask], y[val_mask]

        # Scale using only the training data to prevent data leakage
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train)
        X_val_scaled = scaler.transform(X_val)

        # One-hot encode labels for keras if multiclass
        if len(np.unique(y_train)) > 2:
            # Create mapping from original labels to consecutive indices
            unique_labels = sorted(np.unique(y_train))
            label_to_idx = {label: idx for idx, label in enumerate(unique_labels)}
            idx_to_label = {idx: label for label, idx in label_to_idx.items()}
            
            # Map labels to consecutive indices
            y_train_mapped = np.array([label_to_idx[label] for label in y_train])
            y_val_mapped = np.array([label_to_idx[label] for label in y_val])
            
            n_classes = len(unique_labels)
            y_train_cat = keras.utils.to_categorical(y_train_mapped, num_classes=n_classes)
            y_val_cat = keras.utils.to_categorical(y_val_mapped, num_classes=n_classes)
            loss_fn = "categorical_crossentropy"
            activation = "softmax"
        else:
            y_train_cat = y_train
            y_val_cat = y_val
            n_classes = 2
            loss_fn = "binary_crossentropy"
            activation = "sigmoid"

        # Build model
        model = keras.Sequential()
        model.add(layers.Input(shape=(X_train.shape[1],)))
        model.add(layers.Dense(64, kernel_regularizer=keras.regularizers.l2(0.001)))
        model.add(layers.BatchNormalization())
        model.add(layers.LeakyReLU(negative_slope=0.01))
        model.add(layers.Dropout(0.3)) 
        model.add(layers.Dense(32, kernel_regularizer=keras.regularizers.l2(0.001)))
        model.add(layers.BatchNormalization())
        model.add(layers.LeakyReLU(negative_slope=0.01))
        model.add(layers.Dropout(0.3))  
        model.add(layers.Dense(n_classes if n_classes > 2 else 1, activation=activation))

        model.compile(
            optimizer=keras.optimizers.Adam(learning_rate=1e-3),
            loss=loss_fn,
            metrics=["accuracy", "precision", "recall", AUC(name='auc')]
        )

        # Train model with Early Stopping and Learning Rate Scheduling; store history
        history = model.fit(
            X_train_scaled, y_train_cat,
            epochs=50,
            batch_size=64,
            verbose=1,
            validation_data=(X_val_scaled, y_val_cat),
            callbacks = [
                EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True),
              # ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
            ]
        )

        # Plot learning curves for this fold
        plt.figure(figsize=(12, 4))
        
        # Plot loss
        plt.subplot(1, 2, 1)
        plt.plot(history.history['loss'], label='Training Loss')
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.title(f'Model Loss - File {file_idx}, Fold {fold_idx}')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()
        
        # Plot AUC
        plt.subplot(1, 2, 2)
        plt.plot(history.history['auc'], label='Training AUC')
        plt.plot(history.history['val_auc'], label='Validation AUC')
        plt.title(f'Model AUC - File {file_idx}, Fold {fold_idx}')
        plt.xlabel('Epoch')
        plt.ylabel('AUC')
        plt.legend()
        
        plt.tight_layout()
        plt.show()

        # Predict
        if n_classes > 2:
            y_pred_proba = model.predict(X_val_scaled)
            y_pred_idx = np.argmax(y_pred_proba, axis=1)
            # Map back to original labels
            y_pred_class = np.array([idx_to_label[idx] for idx in y_pred_idx])
        else:
            y_pred_proba = model.predict(X_val_scaled).flatten()
            y_pred_class = (y_pred_proba > 0.5).astype(int)

        # Metrics
        avg = 'weighted'
        try:
            if n_classes > 2:
                roc_auc = roc_auc_score(y_val, y_pred_proba, multi_class='ovr', average='weighted')
            else:
                roc_auc = roc_auc_score(y_val, y_pred_proba)
        except Exception:
            roc_auc = np.nan

        metrics = {
            "accuracy": accuracy_score(y_val, y_pred_class),
            "precision": precision_score(y_val, y_pred_class, average=avg, zero_division=0),
            "recall": recall_score(y_val, y_pred_class, average=avg, zero_division=0),
            "f1": f1_score(y_val, y_pred_class, average=avg, zero_division=0),
            "roc_auc": roc_auc,
            "confusion_matrix": confusion_matrix(y_val, y_pred_class, labels=sorted(np.unique(y))).tolist(),
            "fold": fold_idx,
            "file": selected_files[file_idx],
        }
        file_results.append(metrics)
    results.extend(file_results)
# Out:
# I0000 00:00:1755540149.038043   74076 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5563 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1755540150.637427   74297 service.cc:152] XLA service 0x7970d400db00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1755540150.637453   74297 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# 2025-08-18 18:02:30.686877: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1755540150.837575   74297 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4375 - auc: 0.5938 - loss: 1.0311 - precision: 0.3922 - recall: 0.8000
# I0000 00:00:1755540151.824351   74297 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 597ms/step - accuracy: 0.5826 - auc: 0.7234 - loss: 0.9159 - precision: 0.4733 - recall: 0.8280 - val_accuracy: 0.7069 - val_auc: 0.6911 - val_loss: 2.9741 - val_precision: 0.5769 - val_recall: 0.7143
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.3022 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7241 - val_auc: 0.7568 - val_loss: 1.0300 - val_precision: 0.6087 - val_recall: 0.6667
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9939 - auc: 0.9996 - loss: 0.2770 - precision: 1.0000 - recall: 0.9833 - val_accuracy: 0.7241 - val_auc: 0.7587 - val_loss: 1.0097 - val_precision: 0.6087 - val_recall: 0.6667
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9925 - auc: 0.9993 - loss: 0.2915 - precision: 1.0000 - recall: 0.9802 - val_accuracy: 0.6897 - val_auc: 0.7625 - val_loss: 0.9957 - val_precision: 0.5652 - val_recall: 0.6190
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2607 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.6897 - val_auc: 0.7548 - val_loss: 0.9905 - val_precision: 0.5652 - val_recall: 0.6190
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9983 - auc: 1.0000 - loss: 0.2622 - precision: 0.9953 - recall: 1.0000 - val_accuracy: 0.7241 - val_auc: 0.7561 - val_loss: 0.9840 - val_precision: 0.6190 - val_recall: 0.6190
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9881 - auc: 0.9999 - loss: 0.2630 - precision: 0.9922 - recall: 0.9740 - val_accuracy: 0.7241 - val_auc: 0.7632 - val_loss: 0.9715 - val_precision: 0.6190 - val_recall: 0.6190
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9957 - auc: 0.9999 - loss: 0.2538 - precision: 1.0000 - recall: 0.9885 - val_accuracy: 0.7241 - val_auc: 0.7638 - val_loss: 0.9513 - val_precision: 0.6190 - val_recall: 0.6190
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9983 - auc: 0.9998 - loss: 0.2376 - precision: 1.0000 - recall: 0.9952 - val_accuracy: 0.7241 - val_auc: 0.7709 - val_loss: 0.9302 - val_precision: 0.6190 - val_recall: 0.6190
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9925 - auc: 1.0000 - loss: 0.2421 - precision: 1.0000 - recall: 0.9776 - val_accuracy: 0.7241 - val_auc: 0.7645 - val_loss: 0.9060 - val_precision: 0.6190 - val_recall: 0.6190
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2278 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7241 - val_auc: 0.7728 - val_loss: 0.8887 - val_precision: 0.6190 - val_recall: 0.6190
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2273 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7241 - val_auc: 0.7632 - val_loss: 0.8784 - val_precision: 0.6190 - val_recall: 0.6190
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2226 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7241 - val_auc: 0.7587 - val_loss: 0.8698 - val_precision: 0.6190 - val_recall: 0.6190
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2075 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7241 - val_auc: 0.7561 - val_loss: 0.8667 - val_precision: 0.6190 - val_recall: 0.6190
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2021 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7241 - val_auc: 0.7497 - val_loss: 0.8595 - val_precision: 0.6190 - val_recall: 0.6190
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.1977 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7241 - val_auc: 0.7516 - val_loss: 0.8548 - val_precision: 0.6190 - val_recall: 0.6190
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.1886 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7241 - val_auc: 0.7465 - val_loss: 0.8522 - val_precision: 0.6190 - val_recall: 0.6190
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.1876 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7414 - val_auc: 0.7407 - val_loss: 0.8513 - val_precision: 0.6500 - val_recall: 0.6190
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.1872 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7414 - val_auc: 0.7445 - val_loss: 0.8458 - val_precision: 0.6500 - val_recall: 0.6190
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.1828 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7586 - val_auc: 0.7477 - val_loss: 0.8369 - val_precision: 0.6842 - val_recall: 0.6190
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9957 - auc: 1.0000 - loss: 0.1818 - precision: 1.0000 - recall: 0.9892 - val_accuracy: 0.7586 - val_auc: 0.7542 - val_loss: 0.8242 - val_precision: 0.6842 - val_recall: 0.6190
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9957 - auc: 0.9999 - loss: 0.1783 - precision: 1.0000 - recall: 0.9883 - val_accuracy: 0.7586 - val_auc: 0.7555 - val_loss: 0.8140 - val_precision: 0.6842 - val_recall: 0.6190
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9664 - auc: 0.9971 - loss: 0.4073 - precision: 0.9339 - recall: 0.9810 - val_accuracy: 0.7414 - val_auc: 0.8288 - val_loss: 0.9982 - val_precision: 0.5882 - val_recall: 0.9524
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9841 - auc: 0.9985 - loss: 0.3716 - precision: 0.9629 - recall: 0.9952 - val_accuracy: 0.7241 - val_auc: 0.8340 - val_loss: 0.9552 - val_precision: 0.5758 - val_recall: 0.9048
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9624 - auc: 0.9942 - loss: 0.3774 - precision: 0.9384 - recall: 0.9502 - val_accuracy: 0.7241 - val_auc: 0.8404 - val_loss: 0.9216 - val_precision: 0.5758 - val_recall: 0.9048
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9882 - auc: 1.0000 - loss: 0.3453 - precision: 1.0000 - recall: 0.9681 - val_accuracy: 0.7241 - val_auc: 0.8436 - val_loss: 0.8971 - val_precision: 0.5758 - val_recall: 0.9048
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9957 - auc: 1.0000 - loss: 0.3375 - precision: 0.9877 - recall: 1.0000 - val_accuracy: 0.7241 - val_auc: 0.8449 - val_loss: 0.8758 - val_precision: 0.5758 - val_recall: 0.9048
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9841 - auc: 0.9983 - loss: 0.3378 - precision: 0.9875 - recall: 0.9691 - val_accuracy: 0.7241 - val_auc: 0.8475 - val_loss: 0.8552 - val_precision: 0.5758 - val_recall: 0.9048
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9925 - auc: 1.0000 - loss: 0.3148 - precision: 1.0000 - recall: 0.9802 - val_accuracy: 0.7586 - val_auc: 0.8514 - val_loss: 0.8301 - val_precision: 0.6129 - val_recall: 0.9048
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2984 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7586 - val_auc: 0.8507 - val_loss: 0.8176 - val_precision: 0.6129 - val_recall: 0.9048
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9972 - auc: 1.0000 - loss: 0.2978 - precision: 0.9926 - recall: 1.0000 - val_accuracy: 0.7586 - val_auc: 0.8494 - val_loss: 0.8088 - val_precision: 0.6129 - val_recall: 0.9048
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9983 - auc: 1.0000 - loss: 0.2879 - precision: 1.0000 - recall: 0.9952 - val_accuracy: 0.7759 - val_auc: 0.8494 - val_loss: 0.7986 - val_precision: 0.6333 - val_recall: 0.9048
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9955 - auc: 1.0000 - loss: 0.2865 - precision: 1.0000 - recall: 0.9877 - val_accuracy: 0.7759 - val_auc: 0.8488 - val_loss: 0.7918 - val_precision: 0.6333 - val_recall: 0.9048
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9983 - auc: 1.0000 - loss: 0.2702 - precision: 1.0000 - recall: 0.9952 - val_accuracy: 0.7759 - val_auc: 0.8507 - val_loss: 0.7827 - val_precision: 0.6333 - val_recall: 0.9048
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9972 - auc: 1.0000 - loss: 0.2646 - precision: 1.0000 - recall: 0.9923 - val_accuracy: 0.7759 - val_auc: 0.8507 - val_loss: 0.7668 - val_precision: 0.6333 - val_recall: 0.9048
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9913 - auc: 1.0000 - loss: 0.2626 - precision: 1.0000 - recall: 0.9777 - val_accuracy: 0.7759 - val_auc: 0.8501 - val_loss: 0.7579 - val_precision: 0.6333 - val_recall: 0.9048
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2479 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7931 - val_auc: 0.8488 - val_loss: 0.7490 - val_precision: 0.6552 - val_recall: 0.9048
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2374 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7759 - val_auc: 0.8514 - val_loss: 0.7381 - val_precision: 0.6538 - val_recall: 0.8095
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2345 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7759 - val_auc: 0.8481 - val_loss: 0.7319 - val_precision: 0.6538 - val_recall: 0.8095
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9804 - auc: 0.9988 - loss: 0.3020 - precision: 0.9584 - recall: 0.9772 - val_accuracy: 0.7879 - val_auc: 0.9099 - val_loss: 0.6746 - val_precision: 0.5926 - val_recall: 0.8421
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9852 - auc: 0.9989 - loss: 0.2861 - precision: 0.9662 - recall: 0.9813 - val_accuracy: 0.7879 - val_auc: 0.9071 - val_loss: 0.6526 - val_precision: 0.5926 - val_recall: 0.8421
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9865 - auc: 0.9991 - loss: 0.2780 - precision: 0.9863 - recall: 0.9672 - val_accuracy: 0.8182 - val_auc: 0.8975 - val_loss: 0.6786 - val_precision: 0.6296 - val_recall: 0.8947
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9891 - auc: 0.9997 - loss: 0.2699 - precision: 0.9903 - recall: 0.9723 - val_accuracy: 0.8182 - val_auc: 0.9020 - val_loss: 0.6545 - val_precision: 0.6296 - val_recall: 0.8947
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9893 - auc: 0.9998 - loss: 0.2685 - precision: 0.9956 - recall: 0.9700 - val_accuracy: 0.7879 - val_auc: 0.9099 - val_loss: 0.6225 - val_precision: 0.5862 - val_recall: 0.8947
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9959 - auc: 1.0000 - loss: 0.2570 - precision: 1.0000 - recall: 0.9867 - val_accuracy: 0.7727 - val_auc: 0.9138 - val_loss: 0.5959 - val_precision: 0.5667 - val_recall: 0.8947
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9873 - auc: 0.9985 - loss: 0.2630 - precision: 0.9860 - recall: 0.9697 - val_accuracy: 0.8030 - val_auc: 0.9183 - val_loss: 0.6089 - val_precision: 0.6000 - val_recall: 0.9474
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9832 - auc: 0.9992 - loss: 0.2542 - precision: 0.9563 - recall: 0.9863 - val_accuracy: 0.8333 - val_auc: 0.9127 - val_loss: 0.6446 - val_precision: 0.6333 - val_recall: 1.0000
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9785 - auc: 1.0000 - loss: 0.2587 - precision: 0.9306 - recall: 1.0000 - val_accuracy: 0.8333 - val_auc: 0.9093 - val_loss: 0.6825 - val_precision: 0.6333 - val_recall: 1.0000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 689ms/step - accuracy: 0.5364 - auc: 0.7415 - loss: 1.0065 - precision: 0.3710 - recall: 0.9164 - val_accuracy: 0.7727 - val_auc: 0.9255 - val_loss: 1.1584 - val_precision: 0.5588 - val_recall: 1.0000
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7120 - auc: 0.9055 - loss: 0.7992 - precision: 0.4964 - recall: 0.9836 - val_accuracy: 0.7727 - val_auc: 0.9205 - val_loss: 0.9914 - val_precision: 0.5667 - val_recall: 0.8947
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7632 - auc: 0.9372 - loss: 0.7043 - precision: 0.5438 - recall: 0.9934 - val_accuracy: 0.8485 - val_auc: 0.9339 - val_loss: 0.7482 - val_precision: 0.6667 - val_recall: 0.9474
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7796 - auc: 0.9398 - loss: 0.6713 - precision: 0.5669 - recall: 0.9455 - val_accuracy: 0.8788 - val_auc: 0.9395 - val_loss: 0.6652 - val_precision: 0.7200 - val_recall: 0.9474
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8148 - auc: 0.9434 - loss: 0.6171 - precision: 0.6176 - recall: 0.9389 - val_accuracy: 0.8636 - val_auc: 0.9255 - val_loss: 0.6774 - val_precision: 0.7500 - val_recall: 0.7895
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9892 - auc: 0.9991 - loss: 0.3106 - precision: 0.9672 - recall: 1.0000 - val_accuracy: 0.8788 - val_auc: 0.9518 - val_loss: 0.4823 - val_precision: 0.7391 - val_recall: 0.8947
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9819 - auc: 0.9996 - loss: 0.3101 - precision: 0.9398 - recall: 1.0000 - val_accuracy: 0.9091 - val_auc: 0.9591 - val_loss: 0.4910 - val_precision: 0.8095 - val_recall: 0.8947
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9846 - auc: 0.9942 - loss: 0.2953 - precision: 0.9705 - recall: 0.9764 - val_accuracy: 0.9242 - val_auc: 0.9608 - val_loss: 0.4958 - val_precision: 0.8500 - val_recall: 0.8947
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9953 - auc: 0.9999 - loss: 0.2641 - precision: 0.9838 - recall: 1.0000 - val_accuracy: 0.8788 - val_auc: 0.9558 - val_loss: 0.4890 - val_precision: 0.8235 - val_recall: 0.7368
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step

# %%
# Summarize results
df = pd.DataFrame(results)
print(df.groupby("file")[["accuracy", "precision", "recall", "f1", "roc_auc"]].mean())

# Optional: plot AUC per file
df.groupby("file")["roc_auc"].mean().plot.bar(rot=45, figsize=(10, 5))
plt.title("Sequential Neural Network Cross-Validation Area Under Curve per File (mean over folds)")
plt.ylabel("AUC")
plt.tight_layout()
plt.show()
# Out:
#                                                     accuracy  precision  \
# file
# 221111_144114__binary_onlylines114378to117271 l...  0.789655   0.792951
# 221111_144114__binary_onlylines145900to148050 l...  0.772939   0.802526
# 221111_144114__binary_onlylines25660to28100 loe...  0.836735   0.845405
# 221111_144114__binary_onlylines47178to50517 loe...  0.889055   0.891132
# 221111_144114__binary_onlylines86841to90142 loe...  0.812845   0.830673
#
#                                                       recall        f1  \
# file
# 221111_144114__binary_onlylines114378to117271 l...  0.789655  0.789177
# 221111_144114__binary_onlylines145900to148050 l...  0.772939  0.775296
# 221111_144114__binary_onlylines25660to28100 loe...  0.836735  0.839023
# 221111_144114__binary_onlylines47178to50517 loe...  0.889055  0.888642
# 221111_144114__binary_onlylines86841to90142 loe...  0.812845  0.815155
#
#                                                      roc_auc
# file
# 221111_144114__binary_onlylines114378to117271 l...  0.863835
# 221111_144114__binary_onlylines145900to148050 l...  0.889768
# 221111_144114__binary_onlylines25660to28100 loe...  0.899216
# 221111_144114__binary_onlylines47178to50517 loe...  0.937885
# 221111_144114__binary_onlylines86841to90142 loe...  0.900862
# /tmp/ipykernel_74076/1605691262.py:9: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
# Show confusion matrix for each file (mean over folds)
from sklearn.metrics import ConfusionMatrixDisplay

for file in df["file"].unique():
    cms = [np.array(row) for row in df[df["file"] == file]["confusion_matrix"]]
    # Find the largest shape
    max_dim = max(cm.shape[0] for cm in cms)
    # Pad all confusion matrices to max_dim x max_dim
    padded = []
    for cm in cms:
        pad_width = ((0, max_dim - cm.shape[0]), (0, max_dim - cm.shape[1]))
        padded.append(np.pad(cm, pad_width, mode='constant'))
    mean_cm = np.mean(padded, axis=0)
    display_labels = [str(l) for l in range(max_dim)]
    fig, ax = plt.subplots(figsize=(4, 4))
    disp = ConfusionMatrixDisplay(mean_cm, display_labels=display_labels)
    disp.plot(ax=ax, cmap="Blues", colorbar=False)
    plt.title(f"Mean Confusion Matrix: {file}")
    plt.tight_layout()
    plt.show()

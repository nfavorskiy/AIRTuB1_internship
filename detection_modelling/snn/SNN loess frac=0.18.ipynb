# %% [markdown]
# # Sequential Neural Network
# In this notebook I will train a Sequential Neural Network for detection of erosion.

# %%
# Adjust the frac parameter for loess smoothing
# to control the degree of smoothing applied to the scan data.
labeled_dir = "../../scandata/slices loess frac=0.18_labeled"

masks_path = "../stratified_k-fold_masks.npy"

DetectionNotClassification = True  # Set to True to replace all non-zero labels with 1

# %% [markdown]
# Libraries used:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.metrics import AUC

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, roc_auc_score
)

from sklearn.preprocessing import StandardScaler

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# Use GPU if available
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
print("TensorFlow version:", tf.__version__)
# Out:
# 2025-08-18 18:26:31.188184: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-18 18:26:31.402381: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755541591.470668    1428 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755541591.492820    1428 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755541591.683951    1428 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755541591.683988    1428 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755541591.683990    1428 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755541591.683991    1428 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-18 18:26:31.702123: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Num GPUs Available: 1
# TensorFlow version: 2.19.0

# %%
all_masks = np.load(masks_path, allow_pickle=True)

# List all labeled files
labeled_files = [f for f in os.listdir(labeled_dir) if f.endswith("_slices_labeled.npy")]
selected_files = labeled_files  # Use all files by default

# %%
# Load features (X) and labels (y) for each file
all_X = []
all_y = []
for labeled_file in selected_files:
    data = np.load(os.path.join(labeled_dir, labeled_file), allow_pickle=True).item()
    slices = data["slices"]  # shape: (num_slices, max_points, 3)
    labels = data["labels"]  # shape: (num_slices,)

    X = slices[:, :, 2]  # shape: (num_slices, max_points)
    if DetectionNotClassification:
        y = (labels != 0).astype(int)
    else:
        y = labels  # keep original labels for multiclass
    all_X.append(X)
    all_y.append(y)

# %%
# Cross-validation using stratified k-Fold masks
n_folds = len(all_masks[0])
results = []

for file_idx, (X, y, masks) in enumerate(zip(all_X, all_y, all_masks)):
    file_results = []
    n_classes = len(np.unique(y))
    for fold_idx, val_mask in enumerate(masks):
        train_mask = ~val_mask
        X_train, y_train = X[train_mask], y[train_mask]
        X_val, y_val = X[val_mask], y[val_mask]

        # Scale using only the training data to prevent data leakage
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train)
        X_val_scaled = scaler.transform(X_val)

        # One-hot encode labels for keras if multiclass
        if len(np.unique(y_train)) > 2:
            # Create mapping from original labels to consecutive indices
            unique_labels = sorted(np.unique(y_train))
            label_to_idx = {label: idx for idx, label in enumerate(unique_labels)}
            idx_to_label = {idx: label for label, idx in label_to_idx.items()}
            
            # Map labels to consecutive indices
            y_train_mapped = np.array([label_to_idx[label] for label in y_train])
            y_val_mapped = np.array([label_to_idx[label] for label in y_val])
            
            n_classes = len(unique_labels)
            y_train_cat = keras.utils.to_categorical(y_train_mapped, num_classes=n_classes)
            y_val_cat = keras.utils.to_categorical(y_val_mapped, num_classes=n_classes)
            loss_fn = "categorical_crossentropy"
            activation = "softmax"
        else:
            y_train_cat = y_train
            y_val_cat = y_val
            n_classes = 2
            loss_fn = "binary_crossentropy"
            activation = "sigmoid"

        # Build model
        model = keras.Sequential()
        model.add(layers.Input(shape=(X_train.shape[1],)))
        model.add(layers.Dense(64, kernel_regularizer=keras.regularizers.l2(0.001)))
        model.add(layers.BatchNormalization())
        model.add(layers.LeakyReLU(negative_slope=0.01))
        model.add(layers.Dropout(0.3)) 
        model.add(layers.Dense(32, kernel_regularizer=keras.regularizers.l2(0.001)))
        model.add(layers.BatchNormalization())
        model.add(layers.LeakyReLU(negative_slope=0.01))
        model.add(layers.Dropout(0.3))  
        model.add(layers.Dense(n_classes if n_classes > 2 else 1, activation=activation))

        model.compile(
            optimizer=keras.optimizers.Adam(learning_rate=1e-3),
            loss=loss_fn,
            metrics=["accuracy", "precision", "recall", AUC(name='auc')]
        )

        # Train model with Early Stopping and Learning Rate Scheduling; store history
        history = model.fit(
            X_train_scaled, y_train_cat,
            epochs=50,
            batch_size=64,
            verbose=1,
            validation_data=(X_val_scaled, y_val_cat),
            callbacks = [
                EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True),
              # ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
            ]
        )

        # Plot learning curves for this fold
        plt.figure(figsize=(12, 4))
        
        # Plot loss
        plt.subplot(1, 2, 1)
        plt.plot(history.history['loss'], label='Training Loss')
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.title(f'Model Loss - File {file_idx}, Fold {fold_idx}')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()
        
        # Plot AUC
        plt.subplot(1, 2, 2)
        plt.plot(history.history['auc'], label='Training AUC')
        plt.plot(history.history['val_auc'], label='Validation AUC')
        plt.title(f'Model AUC - File {file_idx}, Fold {fold_idx}')
        plt.xlabel('Epoch')
        plt.ylabel('AUC')
        plt.legend()
        
        plt.tight_layout()
        plt.show()

        # Predict
        if n_classes > 2:
            y_pred_proba = model.predict(X_val_scaled)
            y_pred_idx = np.argmax(y_pred_proba, axis=1)
            # Map back to original labels
            y_pred_class = np.array([idx_to_label[idx] for idx in y_pred_idx])
        else:
            y_pred_proba = model.predict(X_val_scaled).flatten()
            y_pred_class = (y_pred_proba > 0.5).astype(int)

        # Metrics
        avg = 'weighted'
        try:
            if n_classes > 2:
                roc_auc = roc_auc_score(y_val, y_pred_proba, multi_class='ovr', average='weighted')
            else:
                roc_auc = roc_auc_score(y_val, y_pred_proba)
        except Exception:
            roc_auc = np.nan

        metrics = {
            "accuracy": accuracy_score(y_val, y_pred_class),
            "precision": precision_score(y_val, y_pred_class, average=avg, zero_division=0),
            "recall": recall_score(y_val, y_pred_class, average=avg, zero_division=0),
            "f1": f1_score(y_val, y_pred_class, average=avg, zero_division=0),
            "roc_auc": roc_auc,
            "confusion_matrix": confusion_matrix(y_val, y_pred_class, labels=sorted(np.unique(y))).tolist(),
            "fold": fold_idx,
            "file": selected_files[file_idx],
        }
        file_results.append(metrics)
    results.extend(file_results)
# Out:
# I0000 00:00:1755541606.430273    1428 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5563 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1755541608.391504    1735 service.cc:152] XLA service 0x7a9b1400ee50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1755541608.391554    1735 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# 2025-08-18 18:26:48.452280: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1755541608.633234    1735 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 8s 3s/step - accuracy: 0.3906 - auc: 0.3335 - loss: 1.1970 - precision: 0.2432 - recall: 0.4500
# I0000 00:00:1755541609.709845    1735 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 632ms/step - accuracy: 0.5350 - auc: 0.6074 - loss: 0.9678 - precision: 0.4036 - recall: 0.6825 - val_accuracy: 0.6552 - val_auc: 0.7156 - val_loss: 2.6642 - val_precision: 0.5161 - val_recall: 0.7619
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.
- val_precision: 0.6842 - val_recall: 0.6190
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9898 - auc: 1.0000 - loss: 0.3137 - precision: 1.0000 - recall: 0.9726 - val_accuracy: 0.7586 - val_auc: 0.8160 - val_loss: 0.9115 - val_precision: 0.6842 - val_recall: 0.6190
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9955 - auc: 1.0000 - loss: 0.3029 - precision: 1.0000 - recall: 0.9874 - val_accuracy: 0.7586 - val_auc: 0.8192 - val_loss: 0.8902 - val_precision: 0.6842 - val_recall: 0.6190
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9865 - auc: 0.9993 - loss: 0.3091 - precision: 0.9834 - recall: 0.9812 - val_accuracy: 0.7414 - val_auc: 0.8179 - val_loss: 0.8774 - val_precision: 0.6500 - val_recall: 0.6190
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2763 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7414 - val_auc: 0.8211 - val_loss: 0.8743 - val_precision: 0.6500 - val_recall: 0.6190
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9957 - auc: 0.9999 - loss: 0.2613 - precision: 1.0000 - recall: 0.9879 - val_accuracy: 0.7414 - val_auc: 0.8198 - val_loss: 0.8714 - val_precision: 0.6500 - val_recall: 0.6190
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2492 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7414 - val_auc: 0.8166 - val_loss: 0.8724 - val_precision: 0.6500 - val_recall: 0.6190
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9972 - auc: 1.0000 - loss: 0.2601 - precision: 1.0000 - recall: 0.9924 - val_accuracy: 0.7414 - val_auc: 0.8153 - val_loss: 0.8707 - val_precision: 0.6500 - val_recall: 0.6190
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9851 - auc: 0.9989 - loss: 0.2611 - precision: 1.0000 - recall: 0.9620 - val_accuracy: 0.7414 - val_auc: 0.8140 - val_loss: 0.8694 - val_precision: 0.6500 - val_recall: 0.6190
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9925 - auc: 0.9999 - loss: 0.2446 - precision: 1.0000 - recall: 0.9787 - val_accuracy: 0.7414 - val_auc: 0.8121 - val_loss: 0.8534 - val_precision: 0.6500 - val_recall: 0.6190
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2310 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7414 - val_auc: 0.8127 - val_loss: 0.8422 - val_precision: 0.6500 - val_recall: 0.6190
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2291 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7241 - val_auc: 0.8115 - val_loss: 0.8264 - val_precision: 0.6316 - val_recall: 0.5714
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9925 - auc: 1.0000 - loss: 0.2282 - precision: 1.0000 - recall: 0.9782 - val_accuracy: 0.7241 - val_auc: 0.8095 - val_loss: 0.8177 - val_precision: 0.6316 - val_recall: 0.5714
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9983 - auc: 1.0000 - loss: 0.2149 - precision: 1.0000 - recall: 0.9952 - val_accuracy: 0.7241 - val_auc: 0.8082 - val_loss: 0.8172 - val_precision: 0.6316 - val_recall: 0.5714
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2003 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7414 - val_auc: 0.8102 - val_loss: 0.8447 - val_precision: 0.6500 - val_recall: 0.6190
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2024 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7414 - val_auc: 0.8012 - val_loss: 0.8551 - val_precision: 0.6500 - val_recall: 0.6190
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.1981 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7414 - val_auc: 0.8037 - val_loss: 0.8537 - val_precision: 0.6500 - val_recall: 0.6190
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 594ms/step - accuracy: 0.5393 - auc: 0.5897 - loss: 0.9939 - precision: 0.4101 - recall: 0.6191 - val_accuracy: 0.6552 - val_auc: 0.7761 - val_loss: 3.0211 - val_precision: 0.5135 - val_recall: 0.9048
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7677 - auc: 0.8808 - loss: 0.6668 - precision: 0.6375 - recall: 0.8364 - val_accuracy: 0.6724 - val_auc: 0.8076 - val_loss: 2.2423 - val_precision: 0.5263 - val_recall: 0.9524
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9869 - auc: 0.9982 - loss: 0.3196 - precision: 1.0000 - recall: 0.9637 - val_accuracy: 0.7931 - val_auc: 0.8520 - val_loss: 0.7217 - val_precision: 0.6552 - val_recall: 0.9048
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9898 - auc: 0.9989 - loss: 0.3137 - precision: 1.0000 - recall: 0.9721 - val_accuracy: 0.7931 - val_auc: 0.8584 - val_loss: 0.6992 - val_precision: 0.6552 - val_recall: 0.9048
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9898 - auc: 0.9994 - loss: 0.3074 - precision: 1.0000 - recall: 0.9690 - val_accuracy: 0.7931 - val_auc: 0.8565 - val_loss: 0.6767 - val_precision: 0.6552 - val_recall: 0.9048
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9957 - auc: 1.0000 - loss: 0.2822 - precision: 1.0000 - recall: 0.9882 - val_accuracy: 0.7931 - val_auc: 0.8546 - val_loss: 0.6675 - val_precision: 0.6552 - val_recall: 0.9048
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9882 - auc: 0.9998 - loss: 0.2717 - precision: 1.0000 - recall: 0.9697 - val_accuracy: 0.7931 - val_auc: 0.8546 - val_loss: 0.6606 - val_precision: 0.6552 - val_recall: 0.9048
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9972 - auc: 0.9999 - loss: 0.2673 - precision: 1.0000 - recall: 0.9924 - val_accuracy: 0.7759 - val_auc: 0.8501 - val_loss: 0.6545 - val_precision: 0.6429 - val_recall: 0.8571
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9955 - auc: 0.9999 - loss: 0.2494 - precision: 0.9952 - recall: 0.9925 - val_accuracy: 0.7759 - val_auc: 0.8494 - val_loss: 0.6479 - val_precision: 0.6429 - val_recall: 0.8571
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9925 - auc: 1.0000 - loss: 0.2498 - precision: 1.0000 - recall: 0.9823 - val_accuracy: 0.7931 - val_auc: 0.8481 - val_loss: 0.6388 - val_precision: 0.6667 - val_recall: 0.8571
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9925 - auc: 0.9989 - loss: 0.2618 - precision: 0.9767 - recall: 1.0000 - val_accuracy: 0.7759 - val_auc: 0.8430 - val_loss: 0.6307 - val_precision: 0.6538 - val_recall: 0.8095
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2296 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7759 - val_auc: 0.8430 - val_loss: 0.6251 - val_precision: 0.6538 - val_recall: 0.8095
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9983 - auc: 0.9999 - loss: 0.2222 - precision: 1.0000 - recall: 0.9952 - val_accuracy: 0.7586 - val_auc: 0.8481 - val_loss: 0.6157 - val_precision: 0.6400 - val_recall: 0.7619
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2239 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7759 - val_auc: 0.8604 - val_loss: 0.6118 - val_precision: 0.6667 - val_recall: 0.7619
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2038 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7759 - val_auc: 0.8571 - val_loss: 0.6109 - val_precision: 0.6667 - val_recall: 0.7619
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2043 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7414 - val_auc: 0.8507 - val_loss: 0.6115 - val_precision: 0.6250 - val_recall: 0.7143
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2008 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7414 - val_auc: 0.8494 - val_loss: 0.6091 - val_precision: 0.6364 - val_recall: 0.6667
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.1944 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7241 - val_auc: 0.8449 - val_loss: 0.6124 - val_precision: 0.6190 - val_recall: 0.6190
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.1815 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7414 - val_auc: 0.8436 - val_loss: 0.6124 - val_precision: 0.6500 - val_recall: 0.6190
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9983 - auc: 1.0000 - loss: 0.1817 - precision: 1.0000 - recall: 0.9952 - val_accuracy: 0.7586 - val_auc: 0.8559 - val_loss: 0.6024 - val_precision: 0.7059 - val_recall: 0.5714
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9475 - auc: 0.9951 - loss: 0.4188 - precision: 0.8411 - recall: 1.0000 - val_accuracy: 0.8140 - val_auc: 0.8817 - val_loss: 0.7212 - val_precision: 0.6250 - val_recall: 0.8333
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9728 - auc: 0.9985 - loss: 0.3891 - precision: 0.9541 - recall: 0.9541 - val_accuracy: 0.8140 - val_auc: 0.8871 - val_loss: 0.7100 - val_precision: 0.6250 - val_recall: 0.8333
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9942 - auc: 0.9994 - loss: 0.3424 - precision: 0.9904 - recall: 0.9904 - val_accuracy: 0.8140 - val_auc: 0.8898 - val_loss: 0.7086 - val_precision: 0.6250 - val_recall: 0.8333
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9884 - auc: 0.9985 - loss: 0.3399 - precision: 1.0000 - recall: 0.9632 - val_accuracy: 0.8140 - val_auc: 0.8925 - val_loss: 0.7107 - val_precision: 0.6250 - val_recall: 0.8333
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9971 - auc: 1.0000 - loss: 0.3288 - precision: 0.9906 - recall: 1.0000 - val_accuracy: 0.8140 - val_auc: 0.8898 - val_loss: 0.7032 - val_precision: 0.6250 - val_recall: 0.8333
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.3177 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8140 - val_auc: 0.8804 - val_loss: 0.6865 - val_precision: 0.6250 - val_recall: 0.8333
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9952 - auc: 1.0000 - loss: 0.3000 - precision: 0.9846 - recall: 1.0000 - val_accuracy: 0.8605 - val_auc: 0.8750 - val_loss: 0.6703 - val_precision: 0.7143 - val_recall: 0.8333
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2939 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8605 - val_auc: 0.8696 - val_loss: 0.6556 - val_precision: 0.7143 - val_recall: 0.8333
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9913 - auc: 1.0000 - loss: 0.2981 - precision: 1.0000 - recall: 0.9721 - val_accuracy: 0.8605 - val_auc: 0.8683 - val_loss: 0.6448 - val_precision: 0.7143 - val_recall: 0.8333
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.3029 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8605 - val_auc: 0.8616 - val_loss: 0.6301 - val_precision: 0.7143 - val_recall: 0.8333
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9913 - auc: 1.0000 - loss: 0.2666 - precision: 0.9718 - recall: 1.0000 - val_accuracy: 0.8605 - val_auc: 0.8602 - val_loss: 0.6227 - val_precision: 0.7143 - val_recall: 0.8333
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2692 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8605 - val_auc: 0.8629 - val_loss: 0.6132 - val_precision: 0.7143 - val_recall: 0.8333
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9864 - auc: 1.0000 - loss: 0.2637 - precision: 0.9558 - recall: 1.0000 - val_accuracy: 0.8605 - val_auc: 0.8656 - val_loss: 0.5991 - val_precision: 0.7143 - val_recall: 0.8333
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2406 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8605 - val_auc: 0.8656 - val_loss: 0.5891 - val_precision: 0.7143 - val_recall: 0.8333
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2599 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8605 - val_auc: 0.8669 - val_loss: 0.5820 - val_precision: 0.7143 - val_recall: 0.8333
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9913 - auc: 1.0000 - loss: 0.2505 - precision: 0.9723 - recall: 1.0000 - val_accuracy: 0.8605 - val_auc: 0.8669 - val_loss: 0.5738 - val_precision: 0.7143 - val_recall: 0.8333
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2405 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8605 - val_auc: 0.8683 - val_loss: 0.5654 - val_precision: 0.7143 - val_recall: 0.8333
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2355 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8605 - val_auc: 0.8669 - val_loss: 0.5664 - val_precision: 0.7143 - val_recall: 0.8333
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2258 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8605 - val_auc: 0.8602 - val_loss: 0.5603 - val_precision: 0.7143 - val_recall: 0.8333
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2149 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9777 - auc: 0.9980 - loss: 0.2961 - precision: 0.9536 - recall: 0.9747 - val_accuracy: 0.8485 - val_auc: 0.9272 - val_loss: 0.5631 - val_precision: 0.6667 - val_recall: 0.9474
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 593ms/step - accuracy: 0.4115 - auc: 0.6288 - loss: 1.3166 - precision: 0.3111 - recall: 0.8785 - val_accuracy: 0.7273 - val_auc: 0.8287 - val_loss: 3.0134 - val_precision: 0.5143 - val_recall: 0.9474
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6003 - auc: 0.8675 - loss: 0.9846 - precision: 0.4047 - recall: 0.9166 - val_accuracy: 0.7424 - val_auc: 0.9188 - val_loss: 1.9824 - val_precision: 0.5278 - val_recall: 1.0000
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5645 - auc: 0.8567 - loss: 0.9644 - precision: 0.3666 - recall: 0.9064 - val_accuracy: 0.7576 - val_auc: 0.9222 - val_loss: 1.4527 - val_precision: 0.5429 - val_recall: 1.0000
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7031 - auc: 0.8882 - loss: 0.8708 - precision: 0.4714 - recall: 0.9264 - val_accuracy: 0.7879 - val_auc: 0.9395 - val_loss: 1.2141 - val_precision: 0.5758 - val_recall: 1.0000
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7225 - auc: 0.8812 - loss: 0.8859 - precision: 0.4840 - recall: 0.9208 - val_accuracy: 0.8030 - val_auc: 0.9395 - val_loss: 1.0011 - val_precision: 0.5938 - val_recall: 1.0000
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7787 - auc: 0.8865 - loss: 0.7337 - precision: 0.5924 - recall: 0.8734 - val_accuracy: 0.8182 - val_auc: 0.9507 - val_loss: 0.8454 - val_precision: 0.6129 - val_recall: 1.0000
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8228 - auc: 0.9315 - loss: 0.6602 - precision: 0.6268 - recall: 0.9303 - val_accuracy: 0.8788 - val_auc: 0.9608 - val_loss: 0.7634 - val_precision: 0.7037 - val_recall: 1.0000
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7758 - auc: 0.9004 - loss: 0.7123 - precision: 0.5926 - recall: 0.8421 - val_accuracy: 0.8939 - val_auc: 0.9574 - val_loss: 0.7079 - val_precision: 0.7308 - val_recall: 1.0000
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8195 - auc: 0.9239 - loss: 0.6631 - precision: 0.6221 - recall: 0.9023 - val_accuracy: 0.8788 - val_auc: 0.9569 - val_loss: 0.6745 - val_precision: 0.7200 - val_recall: 0.9474
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8713 - auc: 0.9455 - loss: 0.5792 - precision: 0.7331 - recall: 0.8828 - val_accuracy: 0.8788 - val_auc: 0.9552 - val_loss: 0.6416 - val_precision: 0.7391 - val_recall: 0.8947
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8411 - auc: 0.9553 - loss: 0.5795 - precision: 0.6384 - recall: 0.9357 - val_accuracy: 0.9091 - val_auc: 0.9597 - val_loss: 0.6258 - val_precision: 0.7600 - val_recall: 1.0000
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8350 - auc: 0.9408 - loss: 0.6562 - precision: 0.6255 - recall: 0.9523 - val_accuracy: 0.8939 - val_auc: 0.9608 - val_loss: 0.5998 - val_precision: 0.7500 - val_recall: 0.9474
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8993 - auc: 0.9664 - loss: 0.5049 - precision: 0.7779 - recall: 0.9026 - val_accuracy: 0.8939 - val_auc: 0.9630 - val_loss: 0.5672 - val_precision: 0.7500 - val_recall: 0.9474
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9132 - auc: 0.9752 - loss: 0.4902 - precision: 0.7839 - recall: 0.9634 - val_accuracy: 0.8788 - val_auc: 0.9574 - val_loss: 0.5381 - val_precision: 0.7391 - val_recall: 0.8947
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9207 - auc: 0.9657 - loss: 0.4766 - precision: 0.8141 - recall: 0.9242 - val_accuracy: 0.8939 - val_auc: 0.9569 - val_loss: 0.5155 - val_precision: 0.7727 - val_recall: 0.8947
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9307 - auc: 0.9719 - loss: 0.4743 - precision: 0.8571 - recall: 0.9084 - val_accuracy: 0.8788 - val_auc: 0.9535 - val_loss: 0.5261 - val_precision: 0.7619 - val_recall: 0.8421
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9508 - auc: 0.9803 - loss: 0.4255 - precision: 0.8931 - recall: 0.9378 - val_accuracy: 0.8636 - val_auc: 0.9490 - val_loss: 0.5364 - val_precision: 0.7500 - val_recall: 0.7895
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9497 - auc: 0.9869 - loss: 0.4054 - precision: 0.9307 - recall: 0.8911 - val_accuracy: 0.8939 - val_auc: 0.9479 - val_loss: 0.5364 - val_precision: 0.7727 - val_recall: 0.8947
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step

# %%
# Summarize results
df = pd.DataFrame(results)
print(df.groupby("file")[["accuracy", "precision", "recall", "f1", "roc_auc"]].mean())

# Optional: plot AUC per file
df.groupby("file")["roc_auc"].mean().plot.bar(rot=45, figsize=(10, 5))
plt.title("Sequential Neural Network Cross-Validation Area Under Curve per File (mean over folds)")
plt.ylabel("AUC")
plt.tight_layout()
plt.show()
# Out:
#                                                     accuracy  precision  \
# file
# 221111_144114__binary_onlylines114378to117271 l...  0.800000   0.806947
# 221111_144114__binary_onlylines145900to148050 l...  0.819345   0.823010
# 221111_144114__binary_onlylines25660to28100 loe...  0.840816   0.849664
# 221111_144114__binary_onlylines47178to50517 loe...  0.877295   0.875828
# 221111_144114__binary_onlylines86841to90142 loe...  0.858073   0.867749
#
#                                                       recall        f1  \
# file
# 221111_144114__binary_onlylines114378to117271 l...  0.800000  0.799777
# 221111_144114__binary_onlylines145900to148050 l...  0.819345  0.818451
# 221111_144114__binary_onlylines25660to28100 loe...  0.840816  0.842612
# 221111_144114__binary_onlylines47178to50517 loe...  0.877295  0.875808
# 221111_144114__binary_onlylines86841to90142 loe...  0.858073  0.860072
#
#                                                      roc_auc
# file
# 221111_144114__binary_onlylines114378to117271 l...  0.886744
# 221111_144114__binary_onlylines145900to148050 l...  0.885012
# 221111_144114__binary_onlylines25660to28100 loe...  0.902745
# 221111_144114__binary_onlylines47178to50517 loe...  0.940882
# 221111_144114__binary_onlylines86841to90142 loe...  0.921635
# /tmp/ipykernel_1428/1605691262.py:9: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
# Show confusion matrix for each file (mean over folds)
from sklearn.metrics import ConfusionMatrixDisplay

for file in df["file"].unique():
    cms = [np.array(row) for row in df[df["file"] == file]["confusion_matrix"]]
    # Find the largest shape
    max_dim = max(cm.shape[0] for cm in cms)
    # Pad all confusion matrices to max_dim x max_dim
    padded = []
    for cm in cms:
        pad_width = ((0, max_dim - cm.shape[0]), (0, max_dim - cm.shape[1]))
        padded.append(np.pad(cm, pad_width, mode='constant'))
    mean_cm = np.mean(padded, axis=0)
    display_labels = [str(l) for l in range(max_dim)]
    fig, ax = plt.subplots(figsize=(4, 4))
    disp = ConfusionMatrixDisplay(mean_cm, display_labels=display_labels)
    disp.plot(ax=ax, cmap="Blues", colorbar=False)
    plt.title(f"Mean Confusion Matrix: {file}")
    plt.tight_layout()
    plt.show()

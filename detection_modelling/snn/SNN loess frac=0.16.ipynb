# %% [markdown]
# # Sequential Neural Network
# In this notebook I will train a Sequential Neural Network for detection of erosion.

# %%
# Adjust the frac parameter for loess smoothing
# to control the degree of smoothing applied to the scan data.
labeled_dir = "../../scandata/slices loess frac=0.16_labeled"

masks_path = "../stratified_k-fold_masks.npy"

DetectionNotClassification = True  # Set to True to replace all non-zero labels with 1

# %% [markdown]
# Libraries used:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.metrics import AUC

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, roc_auc_score
)

from sklearn.preprocessing import StandardScaler

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# Use GPU if available
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
print("TensorFlow version:", tf.__version__)
# Out:
# 2025-08-18 18:13:39.386969: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-18 18:13:39.564947: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755540819.642920   97714 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755540819.666301   97714 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755540819.809703   97714 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755540819.809771   97714 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755540819.809774   97714 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755540819.809776   97714 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-18 18:13:39.845242: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Num GPUs Available: 1
# TensorFlow version: 2.19.0

# %%
all_masks = np.load(masks_path, allow_pickle=True)

# List all labeled files
labeled_files = [f for f in os.listdir(labeled_dir) if f.endswith("_slices_labeled.npy")]
selected_files = labeled_files  # Use all files by default

# %%
# Load features (X) and labels (y) for each file
all_X = []
all_y = []
for labeled_file in selected_files:
    data = np.load(os.path.join(labeled_dir, labeled_file), allow_pickle=True).item()
    slices = data["slices"]  # shape: (num_slices, max_points, 3)
    labels = data["labels"]  # shape: (num_slices,)

    X = slices[:, :, 2]  # shape: (num_slices, max_points)
    if DetectionNotClassification:
        y = (labels != 0).astype(int)
    else:
        y = labels  # keep original labels for multiclass
    all_X.append(X)
    all_y.append(y)

# %%
# Cross-validation using stratified k-Fold masks
n_folds = len(all_masks[0])
results = []

for file_idx, (X, y, masks) in enumerate(zip(all_X, all_y, all_masks)):
    file_results = []
    n_classes = len(np.unique(y))
    for fold_idx, val_mask in enumerate(masks):
        train_mask = ~val_mask
        X_train, y_train = X[train_mask], y[train_mask]
        X_val, y_val = X[val_mask], y[val_mask]

        # Scale using only the training data to prevent data leakage
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train)
        X_val_scaled = scaler.transform(X_val)

        # One-hot encode labels for keras if multiclass
        if len(np.unique(y_train)) > 2:
            # Create mapping from original labels to consecutive indices
            unique_labels = sorted(np.unique(y_train))
            label_to_idx = {label: idx for idx, label in enumerate(unique_labels)}
            idx_to_label = {idx: label for label, idx in label_to_idx.items()}
            
            # Map labels to consecutive indices
            y_train_mapped = np.array([label_to_idx[label] for label in y_train])
            y_val_mapped = np.array([label_to_idx[label] for label in y_val])
            
            n_classes = len(unique_labels)
            y_train_cat = keras.utils.to_categorical(y_train_mapped, num_classes=n_classes)
            y_val_cat = keras.utils.to_categorical(y_val_mapped, num_classes=n_classes)
            loss_fn = "categorical_crossentropy"
            activation = "softmax"
        else:
            y_train_cat = y_train
            y_val_cat = y_val
            n_classes = 2
            loss_fn = "binary_crossentropy"
            activation = "sigmoid"

        # Build model
        model = keras.Sequential()
        model.add(layers.Input(shape=(X_train.shape[1],)))
        model.add(layers.Dense(64, kernel_regularizer=keras.regularizers.l2(0.001)))
        model.add(layers.BatchNormalization())
        model.add(layers.LeakyReLU(negative_slope=0.01))
        model.add(layers.Dropout(0.3)) 
        model.add(layers.Dense(32, kernel_regularizer=keras.regularizers.l2(0.001)))
        model.add(layers.BatchNormalization())
        model.add(layers.LeakyReLU(negative_slope=0.01))
        model.add(layers.Dropout(0.3))  
        model.add(layers.Dense(n_classes if n_classes > 2 else 1, activation=activation))

        model.compile(
            optimizer=keras.optimizers.Adam(learning_rate=1e-3),
            loss=loss_fn,
            metrics=["accuracy", "precision", "recall", AUC(name='auc')]
        )

        # Train model with Early Stopping and Learning Rate Scheduling; store history
        history = model.fit(
            X_train_scaled, y_train_cat,
            epochs=50,
            batch_size=64,
            verbose=1,
            validation_data=(X_val_scaled, y_val_cat),
            callbacks = [
                EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True),
              # ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
            ]
        )

        # Plot learning curves for this fold
        plt.figure(figsize=(12, 4))
        
        # Plot loss
        plt.subplot(1, 2, 1)
        plt.plot(history.history['loss'], label='Training Loss')
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.title(f'Model Loss - File {file_idx}, Fold {fold_idx}')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()
        
        # Plot AUC
        plt.subplot(1, 2, 2)
        plt.plot(history.history['auc'], label='Training AUC')
        plt.plot(history.history['val_auc'], label='Validation AUC')
        plt.title(f'Model AUC - File {file_idx}, Fold {fold_idx}')
        plt.xlabel('Epoch')
        plt.ylabel('AUC')
        plt.legend()
        
        plt.tight_layout()
        plt.show()

        # Predict
        if n_classes > 2:
            y_pred_proba = model.predict(X_val_scaled)
            y_pred_idx = np.argmax(y_pred_proba, axis=1)
            # Map back to original labels
            y_pred_class = np.array([idx_to_label[idx] for idx in y_pred_idx])
        else:
            y_pred_proba = model.predict(X_val_scaled).flatten()
            y_pred_class = (y_pred_proba > 0.5).astype(int)

        # Metrics
        avg = 'weighted'
        try:
            if n_classes > 2:
                roc_auc = roc_auc_score(y_val, y_pred_proba, multi_class='ovr', average='weighted')
            else:
                roc_auc = roc_auc_score(y_val, y_pred_proba)
        except Exception:
            roc_auc = np.nan

        metrics = {
            "accuracy": accuracy_score(y_val, y_pred_class),
            "precision": precision_score(y_val, y_pred_class, average=avg, zero_division=0),
            "recall": recall_score(y_val, y_pred_class, average=avg, zero_division=0),
            "f1": f1_score(y_val, y_pred_class, average=avg, zero_division=0),
            "roc_auc": roc_auc,
            "confusion_matrix": confusion_matrix(y_val, y_pred_class, labels=sorted(np.unique(y))).tolist(),
            "fold": fold_idx,
            "file": selected_files[file_idx],
        }
        file_results.append(metrics)
    results.extend(file_results)
# Out:
# I0000 00:00:1755540830.866146   97714 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5563 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1755540832.715704   97952 service.cc:152] XLA service 0x7df3b40057a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1755540832.715731   97952 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# 2025-08-18 18:13:52.779285: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1755540832.935321   97952 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 7s 3s/step - accuracy: 0.3438 - auc: 0.3939 - loss: 1.2277 - precision: 0.3636 - recall: 0.7407
# I0000 00:00:1755540833.958200   97952 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 592ms/step - accuracy: 0.4770 - auc: 0.6295 - loss: 1.0847 - precision: 0.4075 - recall: 0.8129 - val_accuracy: 0.6724 - val_auc: 0.7561 - val_loss: 3.1157 - val_precision: 0.5333 - val_recall: 0.7619
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9673 - auc: 0.9951 - loss: 0.4044 - precision: 0.9338 - recall: 0.9709 - val_accuracy: 0.7759 - val_auc: 0.8481 - val_loss: 0.7079 - val_precision: 0.6538 - val_recall: 0.8095
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9579 - auc: 0.9905 - loss: 0.3922 - precision: 0.9580 - recall: 0.9334 - val_accuracy: 0.7931 - val_auc: 0.8507 - val_loss: 0.7049 - val_precision: 0.6800 - val_recall: 0.8095
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9687 - auc: 0.9981 - loss: 0.3699 - precision: 0.9355 - recall: 0.9748 - val_accuracy: 0.7414 - val_auc: 0.8546 - val_loss: 0.6911 - val_precision: 0.6364 - val_recall: 0.6667
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9912 - auc: 0.9993 - loss: 0.3429 - precision: 0.9952 - recall: 0.9808 - val_accuracy: 0.7759 - val_auc: 0.8578 - val_loss: 0.6827 - val_precision: 0.6818 - val_recall: 0.7143
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9972 - auc: 0.9998 - loss: 0.3287 - precision: 0.9924 - recall: 1.0000 - val_accuracy: 0.7759 - val_auc: 0.8636 - val_loss: 0.6625 - val_precision: 0.6818 - val_recall: 0.7143
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9820 - auc: 0.9995 - loss: 0.3126 - precision: 0.9634 - recall: 0.9884 - val_accuracy: 0.7759 - val_auc: 0.8668 - val_loss: 0.6509 - val_precision: 0.6818 - val_recall: 0.7143
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9957 - auc: 1.0000 - loss: 0.2909 - precision: 1.0000 - recall: 0.9883 - val_accuracy: 0.7586 - val_auc: 0.8526 - val_loss: 0.6500 - val_precision: 0.6842 - val_recall: 0.6190
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9957 - auc: 1.0000 - loss: 0.2704 - precision: 1.0000 - recall: 0.9882 - val_accuracy: 0.7414 - val_auc: 0.8404 - val_loss: 0.6526 - val_precision: 0.6667 - val_recall: 0.5714
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9925 - auc: 1.0000 - loss: 0.2762 - precision: 1.0000 - recall: 0.9807 - val_accuracy: 0.7414 - val_auc: 0.8417 - val_loss: 0.6527 - val_precision: 0.6667 - val_recall: 0.5714
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2596 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7414 - val_auc: 0.8475 - val_loss: 0.6443 - val_precision: 0.6667 - val_recall: 0.5714
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2476 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7586 - val_auc: 0.8481 - val_loss: 0.6306 - val_precision: 0.6842 - val_recall: 0.6190
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2527 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7759 - val_auc: 0.8629 - val_loss: 0.6150 - val_precision: 0.6667 - val_recall: 0.7619
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9957 - auc: 1.0000 - loss: 0.2430 - precision: 1.0000 - recall: 0.9875 - val_accuracy: 0.7931 - val_auc: 0.8629 - val_loss: 0.6078 - val_precision: 0.6800 - val_recall: 0.8095
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9925 - auc: 1.0000 - loss: 0.2280 - precision: 1.0000 - recall: 0.9804 - val_accuracy: 0.7931 - val_auc: 0.8610 - val_loss: 0.6075 - val_precision: 0.6800 - val_recall: 0.8095
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2162 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7931 - val_auc: 0.8636 - val_loss: 0.6110 - val_precision: 0.6800 - val_recall: 0.8095
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2116 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8103 - val_auc: 0.8636 - val_loss: 0.6161 - val_precision: 0.7273 - val_recall: 0.7619
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.1992 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7759 - val_auc: 0.8604 - val_loss: 0.6198 - val_precision: 0.7000 - val_recall: 0.6667
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 691ms/step - accuracy: 0.5606 - auc: 0.6573 - loss: 0.9513 - precision: 0.4283 - recall: 0.7638 - val_accuracy: 0.7069 - val_auc: 0.8127 - val_loss: 1.8072 - val_precision: 0.5625 - val_recall: 0.8571
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.
- precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7907 - val_auc: 0.8974 - val_loss: 0.5251 - val_precision: 0.6667 - val_recall: 0.6154
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.4432 - auc: 0.6489 - loss: 1.1142 - precision: 0.3385 - recall: 0.9219 - val_accuracy: 0.5116 - val_auc: 0.7244 - val_loss: 2.7732 - val_precision: 0.3824 - val_recall: 1.0000
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.5701 - auc: 0.9138 - loss: 0.8501 - precision: 0.4022 - recall: 1.0000 - val_accuracy: 0.5116 - val_auc: 0.7038 - val_loss: 2.6767 - val_precision: 0.3824 - val_recall: 1.0000
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6382 - auc: 0.9100 - loss: 0.7980 - precision: 0.4485 - recall: 0.9384 - val_accuracy: 0.5581 - val_auc: 0.7269 - val_loss: 2.2666 - val_precision: 0.4062 - val_recall: 1.0000
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6935 - auc: 0.9293 - loss: 0.7619 - precision: 0.4746 - recall: 0.9736 - val_accuracy: 0.5581 - val_auc: 0.7269 - val_loss: 1.9231 - val_precision: 0.4062 - val_recall: 1.0000
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7585 - auc: 0.9157 - loss: 0.7596 - precision: 0.5568 - recall: 0.9841 - val_accuracy: 0.5581 - val_auc: 0.7436 - val_loss: 1.6501 - val_precision: 0.4000 - val_recall: 0.9231
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8244 - auc: 0.9678 - loss: 0.6608 - precision: 0.6229 - recall: 0.9902 - val_accuracy: 0.5814 - val_auc: 0.7603 - val_loss: 1.4557 - val_precision: 0.4138 - val_recall: 0.9231
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7885 - auc: 0.9489 - loss: 0.6631 - precision: 0.5831 - recall: 0.9679 - val_accuracy: 0.5814 - val_auc: 0.7705 - val_loss: 1.3764 - val_precision: 0.4138 - val_recall: 0.9231
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8584 - auc: 0.9707 - loss: 0.6167 - precision: 0.6806 - recall: 1.0000 - val_accuracy: 0.5814 - val_auc: 0.7769 - val_loss: 1.2935 - val_precision: 0.4138 - val_recall: 0.9231
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8274 - auc: 0.9664 - loss: 0.5901 - precision: 0.6458 - recall: 0.9902 - val_accuracy: 0.6047 - val_auc: 0.7744 - val_loss: 1.2113 - val_precision: 0.4286 - val_recall: 0.9231
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9011 - auc: 0.9867 - loss: 0.5380 - precision: 0.7542 - recall: 1.0000 - val_accuracy: 0.6744 - val_auc: 0.7821 - val_loss: 1.1151 - val_precision: 0.4800 - val_recall: 0.9231
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8680 - auc: 0.9931 - loss: 0.5369 - precision: 0.6963 - recall: 1.0000 - val_accuracy: 0.7209 - val_auc: 0.7782 - val_loss: 0.9992 - val_precision: 0.5217 - val_recall: 0.9231
# Epoch 12/50
# ...
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9471 - auc: 0.9920 - loss: 0.3984 - precision: 0.8399 - recall: 0.9956 - val_accuracy: 0.7612 - val_auc: 0.8612 - val_loss: 0.6167 - val_precision: 0.5909 - val_recall: 0.6500
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9534 - auc: 0.9957 - loss: 0.3884 - precision: 0.8618 - recall: 0.9933 - val_accuracy: 0.7761 - val_auc: 0.8548 - val_loss: 0.6403 - val_precision: 0.6190 - val_recall: 0.6500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 605ms/step - accuracy: 0.7726 - auc: 0.7752 - loss: 0.6663 - precision: 0.6466 - recall: 0.4181 - val_accuracy: 0.8030 - val_auc: 0.8421 - val_loss: 1.0806 - val_precision: 0.6250 - val_recall: 0.7895
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9442 - auc: 0.9909 - loss: 0.3455 - precision: 0.8605 - recall: 0.9669 - val_accuracy: 0.9242 - val_auc: 0.9670 - val_loss: 0.3975 - val_precision: 0.8500 - val_recall: 0.8947
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9650 - auc: 0.9937 - loss: 0.3324 - precision: 0.9089 - recall: 0.9810 - val_accuracy: 0.9091 - val_auc: 0.9636 - val_loss: 0.3977 - val_precision: 0.8824 - val_recall: 0.7895
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9706 - auc: 0.9972 - loss: 0.3153 - precision: 0.9437 - recall: 0.9513 - val_accuracy: 0.8788 - val_auc: 0.9496 - val_loss: 0.4297 - val_precision: 0.8667 - val_recall: 0.6842
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9786 - auc: 0.9961 - loss: 0.3058 - precision: 0.9463 - recall: 0.9760 - val_accuracy: 0.8939 - val_auc: 0.9591 - val_loss: 0.4143 - val_precision: 0.9286 - val_recall: 0.6842
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step

# %%
# Summarize results
df = pd.DataFrame(results)
print(df.groupby("file")[["accuracy", "precision", "recall", "f1", "roc_auc"]].mean())

# Optional: plot AUC per file
df.groupby("file")["roc_auc"].mean().plot.bar(rot=45, figsize=(10, 5))
plt.title("Sequential Neural Network Cross-Validation Area Under Curve per File (mean over folds)")
plt.ylabel("AUC")
plt.tight_layout()
plt.show()
# Out:
#                                                     accuracy  precision  \
# file
# 221111_144114__binary_onlylines114378to117271 l...  0.796552   0.801566
# 221111_144114__binary_onlylines145900to148050 l...  0.819239   0.836901
# 221111_144114__binary_onlylines25660to28100 loe...  0.812245   0.846352
# 221111_144114__binary_onlylines47178to50517 loe...  0.892175   0.894800
# 221111_144114__binary_onlylines86841to90142 loe...  0.809769   0.830788
#
#                                                       recall        f1  \
# file
# 221111_144114__binary_onlylines114378to117271 l...  0.796552  0.797069
# 221111_144114__binary_onlylines145900to148050 l...  0.819239  0.823302
# 221111_144114__binary_onlylines25660to28100 loe...  0.812245  0.816891
# 221111_144114__binary_onlylines47178to50517 loe...  0.892175  0.892225
# 221111_144114__binary_onlylines86841to90142 loe...  0.809769  0.812994
#
#                                                      roc_auc
# file
# 221111_144114__binary_onlylines114378to117271 l...  0.882625
# 221111_144114__binary_onlylines145900to148050 l...  0.890149
# 221111_144114__binary_onlylines25660to28100 loe...  0.895294
# 221111_144114__binary_onlylines47178to50517 loe...  0.944046
# 221111_144114__binary_onlylines86841to90142 loe...  0.903595
# /tmp/ipykernel_97714/1605691262.py:9: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
# Show confusion matrix for each file (mean over folds)
from sklearn.metrics import ConfusionMatrixDisplay

for file in df["file"].unique():
    cms = [np.array(row) for row in df[df["file"] == file]["confusion_matrix"]]
    # Find the largest shape
    max_dim = max(cm.shape[0] for cm in cms)
    # Pad all confusion matrices to max_dim x max_dim
    padded = []
    for cm in cms:
        pad_width = ((0, max_dim - cm.shape[0]), (0, max_dim - cm.shape[1]))
        padded.append(np.pad(cm, pad_width, mode='constant'))
    mean_cm = np.mean(padded, axis=0)
    display_labels = [str(l) for l in range(max_dim)]
    fig, ax = plt.subplots(figsize=(4, 4))
    disp = ConfusionMatrixDisplay(mean_cm, display_labels=display_labels)
    disp.plot(ax=ax, cmap="Blues", colorbar=False)
    plt.title(f"Mean Confusion Matrix: {file}")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Sequential Neural Network
# In this notebook I will train a Sequential Neural Network for detection of erosion.

# %%
# Adjust the frac parameter for loess smoothing
# to control the degree of smoothing applied to the scan data.
labeled_dir = "../../scandata/slices loess frac=0.20_labeled"

masks_path = "../stratified_k-fold_masks.npy"

DetectionNotClassification = True  # Set to True to replace all non-zero labels with 1

# %% [markdown]
# Libraries used:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.metrics import AUC

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, roc_auc_score
)

from sklearn.preprocessing import StandardScaler

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# Use GPU if available
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
print("TensorFlow version:", tf.__version__)
# Out:
# 2025-08-18 18:31:39.067753: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-18 18:31:39.077415: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755541899.087725   61440 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755541899.090703   61440 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755541899.098798   61440 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755541899.098815   61440 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755541899.098816   61440 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755541899.098816   61440 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-18 18:31:39.102596: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Num GPUs Available: 1
# TensorFlow version: 2.19.0

# %%
all_masks = np.load(masks_path, allow_pickle=True)

# List all labeled files
labeled_files = [f for f in os.listdir(labeled_dir) if f.endswith("_slices_labeled.npy")]
selected_files = labeled_files  # Use all files by default

# %%
# Load features (X) and labels (y) for each file
all_X = []
all_y = []
for labeled_file in selected_files:
    data = np.load(os.path.join(labeled_dir, labeled_file), allow_pickle=True).item()
    slices = data["slices"]  # shape: (num_slices, max_points, 3)
    labels = data["labels"]  # shape: (num_slices,)

    X = slices[:, :, 2]  # shape: (num_slices, max_points)
    if DetectionNotClassification:
        y = (labels != 0).astype(int)
    else:
        y = labels  # keep original labels for multiclass
    all_X.append(X)
    all_y.append(y)

# %%
# Cross-validation using stratified k-Fold masks
n_folds = len(all_masks[0])
results = []

for file_idx, (X, y, masks) in enumerate(zip(all_X, all_y, all_masks)):
    file_results = []
    n_classes = len(np.unique(y))
    for fold_idx, val_mask in enumerate(masks):
        train_mask = ~val_mask
        X_train, y_train = X[train_mask], y[train_mask]
        X_val, y_val = X[val_mask], y[val_mask]

        # Scale using only the training data to prevent data leakage
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train)
        X_val_scaled = scaler.transform(X_val)

        # One-hot encode labels for keras if multiclass
        if len(np.unique(y_train)) > 2:
            # Create mapping from original labels to consecutive indices
            unique_labels = sorted(np.unique(y_train))
            label_to_idx = {label: idx for idx, label in enumerate(unique_labels)}
            idx_to_label = {idx: label for label, idx in label_to_idx.items()}
            
            # Map labels to consecutive indices
            y_train_mapped = np.array([label_to_idx[label] for label in y_train])
            y_val_mapped = np.array([label_to_idx[label] for label in y_val])
            
            n_classes = len(unique_labels)
            y_train_cat = keras.utils.to_categorical(y_train_mapped, num_classes=n_classes)
            y_val_cat = keras.utils.to_categorical(y_val_mapped, num_classes=n_classes)
            loss_fn = "categorical_crossentropy"
            activation = "softmax"
        else:
            y_train_cat = y_train
            y_val_cat = y_val
            n_classes = 2
            loss_fn = "binary_crossentropy"
            activation = "sigmoid"

        # Build model
        model = keras.Sequential()
        model.add(layers.Input(shape=(X_train.shape[1],)))
        model.add(layers.Dense(64, kernel_regularizer=keras.regularizers.l2(0.001)))
        model.add(layers.BatchNormalization())
        model.add(layers.LeakyReLU(negative_slope=0.01))
        model.add(layers.Dropout(0.3)) 
        model.add(layers.Dense(32, kernel_regularizer=keras.regularizers.l2(0.001)))
        model.add(layers.BatchNormalization())
        model.add(layers.LeakyReLU(negative_slope=0.01))
        model.add(layers.Dropout(0.3))  
        model.add(layers.Dense(n_classes if n_classes > 2 else 1, activation=activation))

        model.compile(
            optimizer=keras.optimizers.Adam(learning_rate=1e-3),
            loss=loss_fn,
            metrics=["accuracy", "precision", "recall", AUC(name='auc')]
        )

        # Train model with Early Stopping and Learning Rate Scheduling; store history
        history = model.fit(
            X_train_scaled, y_train_cat,
            epochs=50,
            batch_size=64,
            verbose=1,
            validation_data=(X_val_scaled, y_val_cat),
            callbacks = [
                EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True),
              # ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
            ]
        )

        # Plot learning curves for this fold
        plt.figure(figsize=(12, 4))
        
        # Plot loss
        plt.subplot(1, 2, 1)
        plt.plot(history.history['loss'], label='Training Loss')
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.title(f'Model Loss - File {file_idx}, Fold {fold_idx}')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()
        
        # Plot AUC
        plt.subplot(1, 2, 2)
        plt.plot(history.history['auc'], label='Training AUC')
        plt.plot(history.history['val_auc'], label='Validation AUC')
        plt.title(f'Model AUC - File {file_idx}, Fold {fold_idx}')
        plt.xlabel('Epoch')
        plt.ylabel('AUC')
        plt.legend()
        
        plt.tight_layout()
        plt.show()

        # Predict
        if n_classes > 2:
            y_pred_proba = model.predict(X_val_scaled)
            y_pred_idx = np.argmax(y_pred_proba, axis=1)
            # Map back to original labels
            y_pred_class = np.array([idx_to_label[idx] for idx in y_pred_idx])
        else:
            y_pred_proba = model.predict(X_val_scaled).flatten()
            y_pred_class = (y_pred_proba > 0.5).astype(int)

        # Metrics
        avg = 'weighted'
        try:
            if n_classes > 2:
                roc_auc = roc_auc_score(y_val, y_pred_proba, multi_class='ovr', average='weighted')
            else:
                roc_auc = roc_auc_score(y_val, y_pred_proba)
        except Exception:
            roc_auc = np.nan

        metrics = {
            "accuracy": accuracy_score(y_val, y_pred_class),
            "precision": precision_score(y_val, y_pred_class, average=avg, zero_division=0),
            "recall": recall_score(y_val, y_pred_class, average=avg, zero_division=0),
            "f1": f1_score(y_val, y_pred_class, average=avg, zero_division=0),
            "roc_auc": roc_auc,
            "confusion_matrix": confusion_matrix(y_val, y_pred_class, labels=sorted(np.unique(y))).tolist(),
            "fold": fold_idx,
            "file": selected_files[file_idx],
        }
        file_results.append(metrics)
    results.extend(file_results)
# Out:
# I0000 00:00:1755541908.679548   61440 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5563 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1755541910.295364   61673 service.cc:152] XLA service 0x75a100022430 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1755541910.295399   61673 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# 2025-08-18 18:31:50.341404: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1755541910.487043   61673 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4688 - auc: 0.4688 - loss: 0.9886 - precision: 0.2812 - recall: 0.4500
# I0000 00:00:1755541911.474471   61673 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 603ms/step - accuracy: 0.5813 - auc: 0.6457 - loss: 0.8723 - precision: 0.4372 - recall: 0.6875 - val_accuracy: 0.7414 - val_auc: 0.7548 - val_loss: 2.2980 - val_precision: 0.6500 - val_recall: 0.6190
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.
- val_precision: 0.6842 - val_recall: 0.6190
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9972 - auc: 1.0000 - loss: 0.2947 - precision: 0.9926 - recall: 1.0000 - val_accuracy: 0.7586 - val_auc: 0.8282 - val_loss: 0.7657 - val_precision: 0.6842 - val_recall: 0.6190
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9957 - auc: 1.0000 - loss: 0.2828 - precision: 0.9885 - recall: 1.0000 - val_accuracy: 0.7586 - val_auc: 0.8301 - val_loss: 0.7449 - val_precision: 0.6842 - val_recall: 0.6190
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2655 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7586 - val_auc: 0.8314 - val_loss: 0.7338 - val_precision: 0.6842 - val_recall: 0.6190
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9925 - auc: 1.0000 - loss: 0.2606 - precision: 1.0000 - recall: 0.9796 - val_accuracy: 0.7586 - val_auc: 0.8237 - val_loss: 0.7468 - val_precision: 0.6842 - val_recall: 0.6190
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2508 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7586 - val_auc: 0.8134 - val_loss: 0.7494 - val_precision: 0.6842 - val_recall: 0.6190
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9957 - auc: 1.0000 - loss: 0.2363 - precision: 1.0000 - recall: 0.9884 - val_accuracy: 0.7586 - val_auc: 0.8160 - val_loss: 0.7475 - val_precision: 0.6842 - val_recall: 0.6190
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 704ms/step - accuracy: 0.7235 - auc: 0.7754 - loss: 0.7293 - precision: 0.5776 - recall: 0.6832 - val_accuracy: 0.6897 - val_auc: 0.8263 - val_loss: 1.8741 - val_precision: 0.5429 - val_recall: 0.9048
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8120 - auc: 0.9290 - loss: 0.5704 - precision: 0.6755 - recall: 0.8881 - val_accuracy: 0.7586 - val_auc: 0.8533 - val_loss: 1.2117 - val_precision: 0.6129 - val_recall: 0.9048
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8434 - auc: 0.9278 - loss: 0.5788 - precision: 0.7261 - recall: 0.8657 - val_accuracy: 0.7586 - val_auc: 0.8526 - val_loss: 1.0432 - val_precision: 0.6129 - val_recall: 0.9048
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8055 - auc: 0.9166 - loss: 0.5688 - precision: 0.7464 - recall: 0.7564 - val_accuracy: 0.7759 - val_auc: 0.8488 - val_loss: 0.9605 - val_precision: 0.6333 - val_recall: 0.9048
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8260 - auc: 0.9223 - loss: 0.5620 - precision: 0.7408 - recall: 0.7788 - val_accuracy: 0.7586 - val_auc: 0.8546 - val_loss: 0.9071 - val_precision: 0.6207 - val_recall: 0.8571
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8235 - auc: 0.9231 - loss: 0.5513 - precision: 0.7445 - recall: 0.7577 - val_accuracy: 0.7759 - val_auc: 0.8604 - val_loss: 0.8553 - val_precision: 0.6429 - val_recall: 0.8571
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8578 - auc: 0.9323 - loss: 0.5239 - precision: 0.7941 - recall: 0.7896 - val_accuracy: 0.7759 - val_auc: 0.8674 - val_loss: 0.8142 - val_precision: 0.6429 - val_recall: 0.8571
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8687 - auc: 0.9584 - loss: 0.5002 - precision: 0.8449 - recall: 0.7940 - val_accuracy: 0.7931 - val_auc: 0.8707 - val_loss: 0.7802 - val_precision: 0.6667 - val_recall: 0.8571
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9003 - auc: 0.9551 - loss: 0.4838 - precision: 0.8789 - recall: 0.8271 - val_accuracy: 0.8103 - val_auc: 0.8681 - val_loss: 0.7383 - val_precision: 0.6923 - val_recall: 0.8571
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9305 - auc: 0.9749 - loss: 0.4512 - precision: 0.9099 - recall: 0.9092 - val_accuracy: 0.8276 - val_auc: 0.8694 - val_loss: 0.7107 - val_precision: 0.7200 - val_recall: 0.8571
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9525 - auc: 0.9803 - loss: 0.4959 - precision: 0.8750 - recall: 0.9839 - val_accuracy: 0.8837 - val_auc: 0.9423 - val_loss: 0.6165 - val_precision: 0.7500 - val_recall: 0.9231
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9506 - auc: 0.9911 - loss: 0.4860 - precision: 0.8913 - recall: 0.9562 - val_accuracy: 0.8605 - val_auc: 0.9410 - val_loss: 0.6130 - val_precision: 0.7059 - val_recall: 0.9231
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9613 - auc: 0.9920 - loss: 0.4713 - precision: 0.9084 - recall: 0.9636 - val_accuracy: 0.8605 - val_auc: 0.9397 - val_loss: 0.6016 - val_precision: 0.7059 - val_recall: 0.9231
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9350 - auc: 0.9937 - loss: 0.4587 - precision: 0.8435 - recall: 0.9496 - val_accuracy: 0.8837 - val_auc: 0.9397 - val_loss: 0.5876 - val_precision: 0.7500 - val_recall: 0.9231
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9777 - auc: 0.9993 - loss: 0.4217 - precision: 0.9304 - recall: 1.0000 - val_accuracy: 0.8605 - val_auc: 0.9474 - val_loss: 0.5690 - val_precision: 0.7059 - val_recall: 0.9231
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9806 - auc: 0.9991 - loss: 0.4043 - precision: 0.9361 - recall: 1.0000 - val_accuracy: 0.8605 - val_auc: 0.9474 - val_loss: 0.5563 - val_precision: 0.7059 - val_recall: 0.9231
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9923 - auc: 0.9998 - loss: 0.4057 - precision: 0.9831 - recall: 0.9902 - val_accuracy: 0.8605 - val_auc: 0.9500 - val_loss: 0.5456 - val_precision: 0.7059 - val_recall: 0.9231
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9806 - auc: 0.9998 - loss: 0.3647 - precision: 0.9398 - recall: 1.0000 - val_accuracy: 0.8605 - val_auc: 0.9385 - val_loss: 0.5454 - val_precision: 0.7059 - val_recall: 0.9231
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9952 - auc: 1.0000 - loss: 0.3539 - precision: 0.9834 - recall: 1.0000 - val_accuracy: 0.8605 - val_auc: 0.9308 - val_loss: 0.5511 - val_precision: 0.7059 - val_recall: 0.9231
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9903 - auc: 0.9996 - loss: 0.3304 - precision: 0.9839 - recall: 0.9839 - val_accuracy: 0.8372 - val_auc: 0.9205 - val_loss: 0.5515 - val_precision: 0.6667 - val_recall: 0.9231
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9971 - auc: 1.0000 - loss: 0.3157 - precision: 0.9904 - recall: 1.0000 - val_accuracy: 0.8372 - val_auc: 0.9218 - val_loss: 0.5454 - val_precision: 0.6875 - val_recall: 0.8462
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 969ms/step - accuracy: 0.5496 - auc: 0.5388 - loss: 0.9516 - precision: 0.3303 - recall: 0.4066 - val_accuracy: 0.6744 - val_auc: 0.7205 - val_loss: 1.9313 - val_precision: 0.4706 - val_recall: 0.6154
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7555 - auc: 0.8722 - loss: 0.6622 - precision: 0.5599 - recall: 0.7788 - val_accuracy: 0.6512 - val_auc: 0.7500 - val_loss: 1.5309 - val_precision: 0.4545 - val_recall: 0.7692
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8196 - auc: 0.9230 - loss: 0.5733 - precision: 0.6465 - recall: 0.8265 - val_accuracy: 0.6279 - val_auc: 0.7641 - val_loss: 1.1656 - val_precision: 0.4348 - val_recall: 0.7692
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7827 - auc: 0.9191 - loss: 0.7204 - precision: 0.5706 - recall: 0.9692 - val_accuracy: 0.6512 - val_auc: 0.9141 - val_loss: 1.1684 - val_precision: 0.4615 - val_recall: 0.9231
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7663 - auc: 0.9524 - loss: 0.6674 - precision: 0.5707 - recall: 0.9459 - val_accuracy: 0.6744 - val_auc: 0.9141 - val_loss: 1.0869 - val_precision: 0.4800 - val_recall: 0.9231
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8119 - auc: 0.9298 - loss: 0.6456 - precision: 0.6523 - recall: 0.8722 - val_accuracy: 0.6977 - val_auc: 0.9154 - val_loss: 1.0314 - val_precision: 0.5000 - val_recall: 0.9231
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8351 - auc: 0.9671 - loss: 0.6316 - precision: 0.6432 - recall: 0.9902 - val_accuracy: 0.7209 - val_auc: 0.9231 - val_loss: 0.9745 - val_precision: 0.5217 - val_recall: 0.9231
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8865 - auc: 0.9808 - loss: 0.5832 - precision: 0.7277 - recall: 1.0000 - val_accuracy: 0.7442 - val_auc: 0.9231 - val_loss: 0.9220 - val_precision: 0.5455 - val_recall: 0.9231
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8874 - auc: 0.9764 - loss: 0.5732 - precision: 0.7393 - recall: 0.9711 - val_accuracy: 0.7209 - val_auc: 0.9205 - val_loss: 0.8773 - val_precision: 0.5238 - val_recall: 0.8462
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9205 - auc: 0.9938 - loss: 0.5327 - precision: 0.7898 - recall: 1.0000 - val_accuracy: 0.7209 - val_auc: 0.9205 - val_loss: 0.8469 - val_precision: 0.5238 - val_recall: 0.8462
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8971 - auc: 0.9836 - loss: 0.5312 - precision: 0.7525 - recall: 0.9699 - val_accuracy: 0.7209 - val_auc: 0.9205 - val_loss: 0.8382 - val_precision: 0.5238 - val_recall: 0.8462
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9477 - auc: 0.9923 - loss: 0.5016 - precision: 0.8528 - recall: 1.0000 - val_accuracy: 0.6977 - val_auc: 0.9244 - val_loss: 0.8377 - val_precision: 0.5000 - val_recall: 0.8462
# Epoch 15/50
# ...
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8029 - auc: 0.8883 - loss: 0.6621 - precision: 0.6286 - recall: 0.8529 - val_accuracy: 0.7879 - val_auc: 0.8595 - val_loss: 0.8859 - val_precision: 0.6087 - val_recall: 0.7368
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8482 - auc: 0.9182 - loss: 0.6072 - precision: 0.6898 - recall: 0.8698 - val_accuracy: 0.8030 - val_auc: 0.8847 - val_loss: 0.7578 - val_precision: 0.6364 - val_recall: 0.7368
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8508 - auc: 0.9056 - loss: 0.5847 - precision: 0.7134 - recall: 0.8422 - val_accuracy: 0.8030 - val_auc: 0.8875 - val_loss: 0.6826 - val_precision: 0.6364 - val_recall: 0.7368
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8483 - auc: 0.9318 - loss: 0.5596 - precision: 0.6972 - recall: 0.8159 - val_accuracy: 0.8030 - val_auc: 0.8981 - val_loss: 0.6236 - val_precision: 0.6364 - val_recall: 0.7368
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8804 - auc: 0.9498 - loss: 0.5174 - precision: 0.7565 - recall: 0.9011 - val_accuracy: 0.8030 - val_auc: 0.9020 - val_loss: 0.5971 - val_precision: 0.6364 - val_recall: 0.7368
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9267 - auc: 0.9738 - loss: 0.4158 - precision: 0.8702 - recall: 0.8948 - val_accuracy: 0.9091 - val_auc: 0.9703 - val_loss: 0.4024 - val_precision: 0.8095 - val_recall: 0.8947
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9264 - auc: 0.9803 - loss: 0.4074 - precision: 0.8539 - recall: 0.8869 - val_accuracy: 0.9091 - val_auc: 0.9675 - val_loss: 0.4069 - val_precision: 0.8095 - val_recall: 0.8947
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9210 - auc: 0.9804 - loss: 0.3974 - precision: 0.8496 - recall: 0.8888 - val_accuracy: 0.8939 - val_auc: 0.9619 - val_loss: 0.4231 - val_precision: 0.8000 - val_recall: 0.8421
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8965 - auc: 0.9745 - loss: 0.4038 - precision: 0.7803 - recall: 0.8995 - val_accuracy: 0.8939 - val_auc: 0.9731 - val_loss: 0.4202 - val_precision: 0.7727 - val_recall: 0.8947
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step

# %%
# Summarize results
df = pd.DataFrame(results)
print(df.groupby("file")[["accuracy", "precision", "recall", "f1", "roc_auc"]].mean())

# Optional: plot AUC per file
df.groupby("file")["roc_auc"].mean().plot.bar(rot=45, figsize=(10, 5))
plt.title("Sequential Neural Network Cross-Validation Area Under Curve per File (mean over folds)")
plt.ylabel("AUC")
plt.tight_layout()
plt.show()
# Out:
#                                                     accuracy  precision  \
# file
# 221111_144114__binary_onlylines114378to117271 l...  0.817241   0.823419
# 221111_144114__binary_onlylines145900to148050 l...  0.791543   0.828134
# 221111_144114__binary_onlylines25660to28100 loe...  0.816327   0.829643
# 221111_144114__binary_onlylines47178to50517 loe...  0.865265   0.869172
# 221111_144114__binary_onlylines86841to90142 loe...  0.837042   0.847348
#
#                                                       recall        f1  \
# file
# 221111_144114__binary_onlylines114378to117271 l...  0.817241  0.816396
# 221111_144114__binary_onlylines145900to148050 l...  0.791543  0.799242
# 221111_144114__binary_onlylines25660to28100 loe...  0.816327  0.819058
# 221111_144114__binary_onlylines47178to50517 loe...  0.865265  0.865321
# 221111_144114__binary_onlylines86841to90142 loe...  0.837042  0.839603
#
#                                                      roc_auc
# file
# 221111_144114__binary_onlylines114378to117271 l...  0.890862
# 221111_144114__binary_onlylines145900to148050 l...  0.890885
# 221111_144114__binary_onlylines25660to28100 loe...  0.902353
# 221111_144114__binary_onlylines47178to50517 loe...  0.937845
# 221111_144114__binary_onlylines86841to90142 loe...  0.927066
# /tmp/ipykernel_61440/1605691262.py:9: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
# Show confusion matrix for each file (mean over folds)
from sklearn.metrics import ConfusionMatrixDisplay

for file in df["file"].unique():
    cms = [np.array(row) for row in df[df["file"] == file]["confusion_matrix"]]
    # Find the largest shape
    max_dim = max(cm.shape[0] for cm in cms)
    # Pad all confusion matrices to max_dim x max_dim
    padded = []
    for cm in cms:
        pad_width = ((0, max_dim - cm.shape[0]), (0, max_dim - cm.shape[1]))
        padded.append(np.pad(cm, pad_width, mode='constant'))
    mean_cm = np.mean(padded, axis=0)
    display_labels = [str(l) for l in range(max_dim)]
    fig, ax = plt.subplots(figsize=(4, 4))
    disp = ConfusionMatrixDisplay(mean_cm, display_labels=display_labels)
    disp.plot(ax=ax, cmap="Blues", colorbar=False)
    plt.title(f"Mean Confusion Matrix: {file}")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Sequential Neural Network
# In this notebook I will train a Sequential Neural Network for detection of erosion.

# %%
# Adjust the frac parameter for loess smoothing
# to control the degree of smoothing applied to the scan data.
labeled_dir = "../../scandata/slices loess frac=0.14_labeled"

masks_path = "../stratified_k-fold_masks.npy"

DetectionNotClassification = True  # Set to True to replace all non-zero labels with 1

# %% [markdown]
# Libraries used:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.metrics import AUC

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, roc_auc_score
)

from sklearn.preprocessing import StandardScaler

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# Use GPU if available
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
print("TensorFlow version:", tf.__version__)
# Out:
# 2025-08-18 18:07:06.701394: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-18 18:07:06.713661: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755540426.727156   37543 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755540426.731103   37543 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755540426.742179   37543 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755540426.742191   37543 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755540426.742192   37543 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755540426.742193   37543 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-18 18:07:06.745802: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Num GPUs Available: 1
# TensorFlow version: 2.19.0

# %%
all_masks = np.load(masks_path, allow_pickle=True)

# List all labeled files
labeled_files = [f for f in os.listdir(labeled_dir) if f.endswith("_slices_labeled.npy")]
selected_files = labeled_files  # Use all files by default

# %%
# Load features (X) and labels (y) for each file
all_X = []
all_y = []
for labeled_file in selected_files:
    data = np.load(os.path.join(labeled_dir, labeled_file), allow_pickle=True).item()
    slices = data["slices"]  # shape: (num_slices, max_points, 3)
    labels = data["labels"]  # shape: (num_slices,)

    X = slices[:, :, 2]  # shape: (num_slices, max_points)
    if DetectionNotClassification:
        y = (labels != 0).astype(int)
    else:
        y = labels  # keep original labels for multiclass
    all_X.append(X)
    all_y.append(y)

# %%
# Cross-validation using stratified k-Fold masks
n_folds = len(all_masks[0])
results = []

for file_idx, (X, y, masks) in enumerate(zip(all_X, all_y, all_masks)):
    file_results = []
    n_classes = len(np.unique(y))
    for fold_idx, val_mask in enumerate(masks):
        train_mask = ~val_mask
        X_train, y_train = X[train_mask], y[train_mask]
        X_val, y_val = X[val_mask], y[val_mask]

        # Scale using only the training data to prevent data leakage
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train)
        X_val_scaled = scaler.transform(X_val)

        # One-hot encode labels for keras if multiclass
        if len(np.unique(y_train)) > 2:
            # Create mapping from original labels to consecutive indices
            unique_labels = sorted(np.unique(y_train))
            label_to_idx = {label: idx for idx, label in enumerate(unique_labels)}
            idx_to_label = {idx: label for label, idx in label_to_idx.items()}
            
            # Map labels to consecutive indices
            y_train_mapped = np.array([label_to_idx[label] for label in y_train])
            y_val_mapped = np.array([label_to_idx[label] for label in y_val])
            
            n_classes = len(unique_labels)
            y_train_cat = keras.utils.to_categorical(y_train_mapped, num_classes=n_classes)
            y_val_cat = keras.utils.to_categorical(y_val_mapped, num_classes=n_classes)
            loss_fn = "categorical_crossentropy"
            activation = "softmax"
        else:
            y_train_cat = y_train
            y_val_cat = y_val
            n_classes = 2
            loss_fn = "binary_crossentropy"
            activation = "sigmoid"

        # Build model
        model = keras.Sequential()
        model.add(layers.Input(shape=(X_train.shape[1],)))
        model.add(layers.Dense(64, kernel_regularizer=keras.regularizers.l2(0.001)))
        model.add(layers.BatchNormalization())
        model.add(layers.LeakyReLU(negative_slope=0.01))
        model.add(layers.Dropout(0.3)) 
        model.add(layers.Dense(32, kernel_regularizer=keras.regularizers.l2(0.001)))
        model.add(layers.BatchNormalization())
        model.add(layers.LeakyReLU(negative_slope=0.01))
        model.add(layers.Dropout(0.3))  
        model.add(layers.Dense(n_classes if n_classes > 2 else 1, activation=activation))

        model.compile(
            optimizer=keras.optimizers.Adam(learning_rate=1e-3),
            loss=loss_fn,
            metrics=["accuracy", "precision", "recall", AUC(name='auc')]
        )

        # Train model with Early Stopping and Learning Rate Scheduling; store history
        history = model.fit(
            X_train_scaled, y_train_cat,
            epochs=50,
            batch_size=64,
            verbose=1,
            validation_data=(X_val_scaled, y_val_cat),
            callbacks = [
                EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True),
              # ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
            ]
        )

        # Plot learning curves for this fold
        plt.figure(figsize=(12, 4))
        
        # Plot loss
        plt.subplot(1, 2, 1)
        plt.plot(history.history['loss'], label='Training Loss')
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.title(f'Model Loss - File {file_idx}, Fold {fold_idx}')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()
        
        # Plot AUC
        plt.subplot(1, 2, 2)
        plt.plot(history.history['auc'], label='Training AUC')
        plt.plot(history.history['val_auc'], label='Validation AUC')
        plt.title(f'Model AUC - File {file_idx}, Fold {fold_idx}')
        plt.xlabel('Epoch')
        plt.ylabel('AUC')
        plt.legend()
        
        plt.tight_layout()
        plt.show()

        # Predict
        if n_classes > 2:
            y_pred_proba = model.predict(X_val_scaled)
            y_pred_idx = np.argmax(y_pred_proba, axis=1)
            # Map back to original labels
            y_pred_class = np.array([idx_to_label[idx] for idx in y_pred_idx])
        else:
            y_pred_proba = model.predict(X_val_scaled).flatten()
            y_pred_class = (y_pred_proba > 0.5).astype(int)

        # Metrics
        avg = 'weighted'
        try:
            if n_classes > 2:
                roc_auc = roc_auc_score(y_val, y_pred_proba, multi_class='ovr', average='weighted')
            else:
                roc_auc = roc_auc_score(y_val, y_pred_proba)
        except Exception:
            roc_auc = np.nan

        metrics = {
            "accuracy": accuracy_score(y_val, y_pred_class),
            "precision": precision_score(y_val, y_pred_class, average=avg, zero_division=0),
            "recall": recall_score(y_val, y_pred_class, average=avg, zero_division=0),
            "f1": f1_score(y_val, y_pred_class, average=avg, zero_division=0),
            "roc_auc": roc_auc,
            "confusion_matrix": confusion_matrix(y_val, y_pred_class, labels=sorted(np.unique(y))).tolist(),
            "fold": fold_idx,
            "file": selected_files[file_idx],
        }
        file_results.append(metrics)
    results.extend(file_results)
# Out:
# I0000 00:00:1755540434.623336   37543 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5563 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1755540436.337566   37742 service.cc:152] XLA service 0x7c45a8003a30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1755540436.337610   37742 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# 2025-08-18 18:07:16.391622: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1755540436.539606   37742 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 7s 3s/step - accuracy: 0.5781 - auc: 0.4236 - loss: 1.0378 - precision: 0.3333 - recall: 0.2857
# I0000 00:00:1755540437.564457   37742 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 638ms/step - accuracy: 0.6587 - auc: 0.6433 - loss: 0.8647 - precision: 0.4953 - recall: 0.5385 - val_accuracy: 0.7069 - val_auc: 0.7580 - val_loss: 1.9839 - val_precision: 0.5909 - val_recall: 0.6190
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7758 - auc: 0.8912 - loss: 0.6087 - precision: 0.6647 - recall: 0.8339 - val_accuracy: 0.7414 - val_auc: 0.7638 - val_loss: 1.4951 - val_precision: 0.6500 - val_recall: 0.6190
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8418 - auc: 0.9367 - loss: 0.5536 - precision: 0.7339 - recall: 0.8431 - val_accuracy: 0.7586 - val_auc: 0.8031 - val_loss: 1.2324 - val_precision: 0.6842 - val_recall: 0.6190
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8593 - auc: 0.9434 - loss: 0.5281 - precision: 0.7673 - recall: 0.8499 - val_accuracy: 0.7586 - val_auc: 0.8024 - val_loss: 1.1409 - val_precision: 0.6842 - val_recall: 0.6190
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8620 - auc: 0.9394 - loss: 0.5420 - precision: 0.7834 - recall: 0.8507 - val_accuracy: 0.7586 - val_auc: 0.8044 - val_loss: 1.0824 - val_precision: 0.6842 - val_recall: 0.6190
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8756 - auc: 0.9624 - loss: 0.5020 - precision: 0.8263 - recall: 0.8251 - val_accuracy: 0.7586 - val_auc: 0.8044 - val_loss: 1.0590 - val_precision: 0.6842 - val_recall: 0.6190
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9334 - auc: 0.9777 - loss: 0.4711 - precision: 0.8858 - recall: 0.9302 - val_accuracy: 0.7586 - val_auc: 0.8037 - val_loss: 1.0345 - val_precision: 0.6842 - val_recall: 0.6190
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9443 - auc: 0.9872 - loss: 0.4247 - precision: 0.9254 - recall: 0.9236 - val_accuracy: 0.7586 - val_auc: 0.7999 - val_loss: 1.0211 - val_precision: 0.6842 - val_recall: 0.6190
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9422 - auc: 0.9874 - loss: 0.4182 - precision: 0.9229 - recall: 0.9173 - val_accuracy: 0.7759 - val_auc: 0.8018 - val_loss: 0.9941 - val_precision: 0.7222 - val_recall: 0.6190
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9479 - auc: 0.9902 - loss: 0.4146 - precision: 0.9270 - recall: 0.9286 - val_accuracy: 0.7759 - val_auc: 0.8398 - val_loss: 0.9531 - val_precision: 0.7222 - val_recall: 0.6190
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9735 - auc: 0.9976 - loss: 0.3803 - precision: 0.9708 - recall: 0.9578 - val_accuracy: 0.7759 - val_auc: 0.8385 - val_loss: 0.9210 - val_precision: 0.7222 - val_recall: 0.6190
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9685 - auc: 0.9963 - loss: 0.3827 - precision: 0.9571 - recall: 0.9574 - val_accuracy: 0.7759 - val_auc: 0.8404 - val_loss: 0.8840 - val_precision: 0.7222 - val_recall: 0.6190
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9763 - auc: 0.9982 - loss: 0.3654 - precision: 0.9920 - recall: 0.9454 - val_accuracy: 0.7759 - val_auc: 0.8430 - val_loss: 0.8624 - val_precision: 0.7222 - val_recall: 0.6190
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9778 - auc: 0.9986 - loss: 0.3378 - precision: 0.9501 - recall: 0.9876 - val_accuracy: 0.7759 - val_auc: 0.8391 - val_loss: 0.8603 - val_precision: 0.7222 - val_recall: 0.6190
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9746 - auc: 0.9990 - loss: 0.3347 - precision: 0.9867 - recall: 0.9401 - val_accuracy: 0.7759 - val_auc: 0.8353 - val_loss: 0.8565 - val_precision: 0.7222 - val_recall: 0.6190
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9945 - auc: 1.0000 - loss: 0.3096 - precision: 1.0000 - recall: 0.9848 - val_accuracy: 0.7759 - val_auc: 0.8333 - val_loss: 0.8531 - val_precision: 0.7222 - val_recall: 0.6190
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9983 - auc: 0.9999 - loss: 0.3036 - precision: 1.0000 - recall: 0.9952 - val_accuracy: 0.7759 - val_auc: 0.8269 - val_loss: 0.8474 - val_precision: 0.7222 - val_recall: 0.6190
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9912 - auc: 0.9998 - loss: 0.2838 - precision: 0.9654 - recall: 1.0000 - val_accuracy: 0.8636 - val_auc: 0.9206 - val_loss: 0.5089 - val_precision: 0.7059 - val_recall: 0.9231
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2701 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8636 - val_auc: 0.9194 - val_loss: 0.5057 - val_precision: 0.7059 - val_recall: 0.9231
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9951 - auc: 0.9999 - loss: 0.2571 - precision: 1.0000 - recall: 0.9844 - val_accuracy: 0.8409 - val_auc: 0.9169 - val_loss: 0.5033 - val_precision: 0.6875 - val_recall: 0.8462
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2510 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8409 - val_auc: 0.9181 - val_loss: 0.4997 - val_precision: 0.6875 - val_recall: 0.8462
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2293 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8409 - val_auc: 0.9194 - val_loss: 0.4958 - val_precision: 0.6875 - val_recall: 0.8462
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2379 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8409 - val_auc: 0.9231 - val_loss: 0.4924 - val_precision: 0.6875 - val_recall: 0.8462
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2332 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8409 - val_auc: 0.9256 - val_loss: 0.4874 - val_precision: 0.6875 - val_recall: 0.8462
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2288 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8182 - val_auc: 0.9243 - val_loss: 0.4810 - val_precision: 0.6667 - val_recall: 0.7692
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2246 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8409 - val_auc: 0.9293 - val_loss: 0.4743 - val_precision: 0.6875 - val_recall: 0.8462
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2089 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8409 - val_auc: 0.9305 - val_loss: 0.4718 - val_precision: 0.6875 - val_recall: 0.8462
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9971 - auc: 1.0000 - loss: 0.2080 - precision: 0.9904 - recall: 1.0000 - val_accuracy: 0.8409 - val_auc: 0.9280 - val_loss: 0.4700 - val_precision: 0.6875 - val_recall: 0.8462
# Epoch 33/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.1999 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8409 - val_auc: 0.9256 - val_loss: 0.4712 - val_precision: 0.6875 - val_recall: 0.8462
# Epoch 34/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.1982 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8409 - val_auc: 0.9268 - val_loss: 0.4716 - val_precision: 0.6875 - val_recall: 0.8462
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9951 - auc: 0.9999 - loss: 0.1940 - precision: 1.0000 - recall: 0.9842 - val_accuracy: 0.8636 - val_auc: 0.9268 - val_loss: 0.4705 - val_precision: 0.7059 - val_recall: 0.9231
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.4219 - auc: 0.5854 - loss: 1.2547 - precision: 0.3546 - recall: 0.9236 - val_accuracy: 0.3488 - val_auc: 0.7097 - val_loss: 5.6221 - val_precision: 0.3000 - val_recall: 1.0000
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5401 - auc: 0.9076 - loss: 0.8618 - precision: 0.3827 - recall: 0.9742 - val_accuracy: 0.3488 - val_auc: 0.7715 - val_loss: 4.5293 - val_precision: 0.3000 - val_recall: 1.0000
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6380 - auc: 0.9369 - loss: 0.7936 - precision: 0.4397 - recall: 1.0000 - val_accuracy: 0.4419 - val_auc: 0.7648 - val_loss: 3.5849 - val_precision: 0.3333 - val_recall: 1.0000
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7081 - auc: 0.9492 - loss: 0.7217 - precision: 0.5008 - recall: 0.9904 - val_accuracy: 0.4884 - val_auc: 0.7984 - val_loss: 3.0030 - val_precision: 0.3529 - val_recall: 1.0000
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7566 - auc: 0.9480 - loss: 0.7099 - precision: 0.5505 - recall: 0.9808 - val_accuracy: 0.5349 - val_auc: 0.8065 - val_loss: 2.5552 - val_precision: 0.3750 - val_recall: 1.0000
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7865 - auc: 0.9500 - loss: 0.6883 - precision: 0.5800 - recall: 0.9742 - val_accuracy: 0.5814 - val_auc: 0.8185 - val_loss: 2.1741 - val_precision: 0.4000 - val_recall: 1.0000
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9738 - auc: 1.0000 - loss: 0.3644 - precision: 0.9050 - recall: 1.0000 - val_accuracy: 0.6977 - val_auc: 0.9099 - val_loss: 0.8164 - val_precision: 0.4762 - val_recall: 0.8333
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9796 - auc: 1.0000 - loss: 0.3508 - precision: 0.9308 - recall: 1.0000 - val_accuracy: 0.6977 - val_auc: 0.9099 - val_loss: 0.8086 - val_precision: 0.4762 - val_recall: 0.8333
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.3247 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.6977 - val_auc: 0.9059 - val_loss: 0.8029 - val_precision: 0.4762 - val_recall: 0.8333
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.3073 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7209 - val_auc: 0.9032 - val_loss: 0.7975 - val_precision: 0.5000 - val_recall: 0.8333
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.3171 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7442 - val_auc: 0.9032 - val_loss: 0.7837 - val_precision: 0.5263 - val_recall: 0.8333
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9913 - auc: 1.0000 - loss: 0.3165 - precision: 0.9684 - recall: 1.0000 - val_accuracy: 0.7442 - val_auc: 0.9005 - val_loss: 0.7662 - val_precision: 0.5263 - val_recall: 0.8333
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9903 - auc: 0.9999 - loss: 0.2947 - precision: 0.9696 - recall: 1.0000 - val_accuracy: 0.7674 - val_auc: 0.9032 - val_loss: 0.7549 - val_precision: 0.5556 - val_recall: 0.8333
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2755 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7674 - val_auc: 0.9005 - val_loss: 0.7426 - val_precision: 0.5556 - val_recall: 0.8333
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9913 - auc: 0.9999 - loss: 0.2998 - precision: 0.9721 - recall: 1.0000 - val_accuracy: 0.7674 - val_auc: 0.8952 - val_loss: 0.7502 - val_precision: 0.5556 - val_recall: 0.8333
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9952 - auc: 1.0000 - loss: 0.2676 - precision: 0.9843 - recall: 1.0000 - val_accuracy: 0.7674 - val_auc: 0.8965 - val_loss: 0.7534 - val_precision: 0.5556 - val_recall: 0.8333
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2763 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7674 - val_auc: 0.8938 - val_loss: 0.7509 - val_precision: 0.5556 - val_recall: 0.8333
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 980ms/step - accuracy: 0.6553 - auc: 0.6257 - loss: 0.8010 - precision: 0.4358 - recall: 0.3739 - val_accuracy: 0.7674 - val_auc: 0.8628 - val_loss: 0.9344 - val_precision: 0.6000 - val_recall: 0.6923
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8313 - auc: 0.9104 - loss: 0.5737 - precision: 0.7061 - recall: 0.7103 - val_accuracy: 0.7674 - val_auc: 0.8859 - val_loss: 0.8831 - val_precision: 0.6000 - val_recall: 0.6923
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8536 - auc: 0.9296 - loss: 0.5416 - precision: 0.7995 - recall: 0.7098 - val_accuracy: 0.8372 - val_auc: 0.8821 - val_loss: 0.7398 - val_precision: 0.7500 - val_recall: 0.6923
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8351 - auc: 0.9346 - loss: 0.5253 - precision: 0.7894 - recall: 0.6543 - val_accuracy: 0.8605 - val_auc: 0.9077 - val_loss: 0.6390 - val_precision: 0.8182 - val_recall: 0.6923
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8846 - auc: 0.9530 - loss: 0.4953 - precision: 0.8096 - recall: 0.7624 - val_accuracy: 0.8605 - val_auc: 0.9192 - val_loss: 0.5816 - val_precision: 0.8182 - val_recall: 0.6923
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9880 - auc: 0.9999 - loss: 0.2971 - precision: 0.9711 - recall: 0.9869 - val_accuracy: 0.8939 - val_auc: 0.9692 - val_loss: 0.3962 - val_precision: 0.8333 - val_recall: 0.7895
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9931 - auc: 0.9999 - loss: 0.2705 - precision: 0.9857 - recall: 0.9903 - val_accuracy: 0.9091 - val_auc: 0.9698 - val_loss: 0.3969 - val_precision: 0.8824 - val_recall: 0.7895
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9839 - auc: 0.9986 - loss: 0.2816 - precision: 1.0000 - recall: 0.9479 - val_accuracy: 0.8939 - val_auc: 0.9675 - val_loss: 0.4003 - val_precision: 0.8750 - val_recall: 0.7368
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9704 - auc: 0.9959 - loss: 0.2964 - precision: 0.9579 - recall: 0.9473 - val_accuracy: 0.8788 - val_auc: 0.9664 - val_loss: 0.4053 - val_precision: 0.8667 - val_recall: 0.6842
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step

# %%
# Summarize results
df = pd.DataFrame(results)
print(df.groupby("file")[["accuracy", "precision", "recall", "f1", "roc_auc"]].mean())

# Optional: plot AUC per file
df.groupby("file")["roc_auc"].mean().plot.bar(rot=45, figsize=(10, 5))
plt.title("Sequential Neural Network Cross-Validation Area Under Curve per File (mean over folds)")
plt.ylabel("AUC")
plt.tight_layout()
plt.show()
# Out:
#                                                     accuracy  precision  \
# file
# 221111_144114__binary_onlylines114378to117271 l...  0.824138   0.831966
# 221111_144114__binary_onlylines145900to148050 l...  0.823996   0.836337
# 221111_144114__binary_onlylines25660to28100 loe...  0.816327   0.828041
# 221111_144114__binary_onlylines47178to50517 loe...  0.871235   0.875685
# 221111_144114__binary_onlylines86841to90142 loe...  0.840118   0.850349
#
#                                                       recall        f1  \
# file
# 221111_144114__binary_onlylines114378to117271 l...  0.824138  0.824520
# 221111_144114__binary_onlylines145900to148050 l...  0.823996  0.820756
# 221111_144114__binary_onlylines25660to28100 loe...  0.816327  0.818484
# 221111_144114__binary_onlylines47178to50517 loe...  0.871235  0.872257
# 221111_144114__binary_onlylines86841to90142 loe...  0.840118  0.842505
#
#                                                      roc_auc
# file
# 221111_144114__binary_onlylines114378to117271 l...  0.889060
# 221111_144114__binary_onlylines145900to148050 l...  0.894921
# 221111_144114__binary_onlylines25660to28100 loe...  0.891765
# 221111_144114__binary_onlylines47178to50517 loe...  0.921748
# 221111_144114__binary_onlylines86841to90142 loe...  0.904378
# /tmp/ipykernel_37543/1605691262.py:9: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
# Show confusion matrix for each file (mean over folds)
from sklearn.metrics import ConfusionMatrixDisplay

for file in df["file"].unique():
    cms = [np.array(row) for row in df[df["file"] == file]["confusion_matrix"]]
    # Find the largest shape
    max_dim = max(cm.shape[0] for cm in cms)
    # Pad all confusion matrices to max_dim x max_dim
    padded = []
    for cm in cms:
        pad_width = ((0, max_dim - cm.shape[0]), (0, max_dim - cm.shape[1]))
        padded.append(np.pad(cm, pad_width, mode='constant'))
    mean_cm = np.mean(padded, axis=0)
    display_labels = [str(l) for l in range(max_dim)]
    fig, ax = plt.subplots(figsize=(4, 4))
    disp = ConfusionMatrixDisplay(mean_cm, display_labels=display_labels)
    disp.plot(ax=ax, cmap="Blues", colorbar=False)
    plt.title(f"Mean Confusion Matrix: {file}")
    plt.tight_layout()
    plt.show()

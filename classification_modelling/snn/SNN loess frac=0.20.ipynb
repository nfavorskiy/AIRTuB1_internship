# %% [markdown]
# # Sequential Neural Network
# In this notebook I will train a Sequential Neural Network for classification of erosion.

# %%
# Adjust the frac parameter for loess smoothing
# to control the degree of smoothing applied to the scan data.
labeled_dir = "../../scandata/slices loess frac=0.20_labeled"

masks_path = "../stratified_k-fold_masks.npy"

DetectionNotClassification = False  # Set to True to replace all non-zero labels with 1

# %% [markdown]
# Libraries used:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.metrics import AUC

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, roc_auc_score
)

from sklearn.preprocessing import StandardScaler

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# Use GPU if available
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
print("TensorFlow version:", tf.__version__)
# Out:
# 2025-08-18 16:34:29.628706: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-18 16:34:29.822475: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755534869.880825    6757 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755534869.896226    6757 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755534870.023162    6757 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755534870.023207    6757 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755534870.023209    6757 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755534870.023210    6757 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-18 16:34:30.050836: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Num GPUs Available: 1
# TensorFlow version: 2.19.0

# %%
all_masks = np.load(masks_path, allow_pickle=True)

# List all labeled files
labeled_files = [f for f in os.listdir(labeled_dir) if f.endswith("_slices_labeled.npy")]
selected_files = labeled_files  # Use all files by default

# %%
# Load features (X) and labels (y) for each file
all_X = []
all_y = []
for labeled_file in selected_files:
    data = np.load(os.path.join(labeled_dir, labeled_file), allow_pickle=True).item()
    slices = data["slices"]  # shape: (num_slices, max_points, 3)
    labels = data["labels"]  # shape: (num_slices,)

    X = slices[:, :, 2]  # shape: (num_slices, max_points)
    if DetectionNotClassification:
        y = (labels != 0).astype(int)
    else:
        y = labels  # keep original labels for multiclass
    all_X.append(X)
    all_y.append(y)

# %%
# Cross-validation using stratified k-Fold masks
n_folds = len(all_masks[0])
results = []

for file_idx, (X, y, masks) in enumerate(zip(all_X, all_y, all_masks)):
    file_results = []
    n_classes = len(np.unique(y))
    for fold_idx, val_mask in enumerate(masks):
        train_mask = ~val_mask
        X_train, y_train = X[train_mask], y[train_mask]
        X_val, y_val = X[val_mask], y[val_mask]

        # Scale using only the training data to prevent data leakage
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train)
        X_val_scaled = scaler.transform(X_val)

        # One-hot encode labels for keras if multiclass
        if len(np.unique(y_train)) > 2:
            # Create mapping from original labels to consecutive indices
            unique_labels = sorted(np.unique(y_train))
            label_to_idx = {label: idx for idx, label in enumerate(unique_labels)}
            idx_to_label = {idx: label for label, idx in label_to_idx.items()}
            
            # Map labels to consecutive indices
            y_train_mapped = np.array([label_to_idx[label] for label in y_train])
            y_val_mapped = np.array([label_to_idx[label] for label in y_val])
            
            n_classes = len(unique_labels)
            y_train_cat = keras.utils.to_categorical(y_train_mapped, num_classes=n_classes)
            y_val_cat = keras.utils.to_categorical(y_val_mapped, num_classes=n_classes)
            loss_fn = "categorical_crossentropy"
            activation = "softmax"
        else:
            y_train_cat = y_train
            y_val_cat = y_val
            n_classes = 2
            loss_fn = "binary_crossentropy"
            activation = "sigmoid"

        # Build model
        model = keras.Sequential()
        model.add(layers.Input(shape=(X_train.shape[1],)))
        model.add(layers.Dense(64, kernel_regularizer=keras.regularizers.l2(0.001)))
        model.add(layers.BatchNormalization())
        model.add(layers.LeakyReLU(negative_slope=0.01))
        model.add(layers.Dropout(0.3)) 
        model.add(layers.Dense(32, kernel_regularizer=keras.regularizers.l2(0.001)))
        model.add(layers.BatchNormalization())
        model.add(layers.LeakyReLU(negative_slope=0.01))
        model.add(layers.Dropout(0.3))  
        model.add(layers.Dense(n_classes if n_classes > 2 else 1, activation=activation))

        model.compile(
            optimizer=keras.optimizers.Adam(learning_rate=1e-3),
            loss=loss_fn,
            metrics=["accuracy", "precision", "recall", AUC(name='auc')]
        )

        # Train model with Early Stopping and Learning Rate Scheduling; store history
        history = model.fit(
            X_train_scaled, y_train_cat,
            epochs=50,
            batch_size=64,
            verbose=1,
            validation_data=(X_val_scaled, y_val_cat),
            callbacks = [
                EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True),
              # ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
            ]
        )

        # Plot learning curves for this fold
        plt.figure(figsize=(12, 4))
        
        # Plot loss
        plt.subplot(1, 2, 1)
        plt.plot(history.history['loss'], label='Training Loss')
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.title(f'Model Loss - File {file_idx}, Fold {fold_idx}')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()
        
        # Plot AUC
        plt.subplot(1, 2, 2)
        plt.plot(history.history['auc'], label='Training AUC')
        plt.plot(history.history['val_auc'], label='Validation AUC')
        plt.title(f'Model AUC - File {file_idx}, Fold {fold_idx}')
        plt.xlabel('Epoch')
        plt.ylabel('AUC')
        plt.legend()
        
        plt.tight_layout()
        plt.show()

        # Predict
        if n_classes > 2:
            y_pred_proba = model.predict(X_val_scaled)
            y_pred_idx = np.argmax(y_pred_proba, axis=1)
            # Map back to original labels
            y_pred_class = np.array([idx_to_label[idx] for idx in y_pred_idx])
        else:
            y_pred_proba = model.predict(X_val_scaled).flatten()
            y_pred_class = (y_pred_proba > 0.5).astype(int)

        # Metrics
        avg = 'weighted'
        try:
            if n_classes > 2:
                roc_auc = roc_auc_score(y_val, y_pred_proba, multi_class='ovr', average='weighted')
            else:
                roc_auc = roc_auc_score(y_val, y_pred_proba)
        except Exception:
            roc_auc = np.nan

        metrics = {
            "accuracy": accuracy_score(y_val, y_pred_class),
            "precision": precision_score(y_val, y_pred_class, average=avg, zero_division=0),
            "recall": recall_score(y_val, y_pred_class, average=avg, zero_division=0),
            "f1": f1_score(y_val, y_pred_class, average=avg, zero_division=0),
            "roc_auc": roc_auc,
            "confusion_matrix": confusion_matrix(y_val, y_pred_class, labels=sorted(np.unique(y))).tolist(),
            "fold": fold_idx,
            "file": selected_files[file_idx],
        }
        file_results.append(metrics)
    results.extend(file_results)
# Out:
# I0000 00:00:1755534883.010878    6757 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5563 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1755534885.029255    7019 service.cc:152] XLA service 0x7061e400fc70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1755534885.029284    7019 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# 2025-08-18 16:34:45.101759: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1755534885.282167    7019 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.2812 - auc: 0.4420 - loss: 1.6254 - precision: 0.3235 - recall: 0.1719
# I0000 00:00:1755534886.892913    7019 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 838ms/step - accuracy: 0.4557 - auc: 0.6341 - loss: 1.3250 - precision: 0.5159 - recall: 0.3585 - val_accuracy: 0.7586 - val_auc: 0.8746 - val_loss: 2.3445 - val_precision: 0.7586 - val_recall: 0.7586
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6755 - auc: 0.8794 - loss: 0.8620 - precision: 0.7880 - recall: 0.6203 - val_accuracy: 0.8103 - val_auc: 0.8791 - val_loss: 1.7549 - val_precision: 0.8246 - val_recall: 0.8103
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7522 - auc: 0.9079 - loss: 0.8057 - precision: 0.7855 - recall: 0.6551 - val_accuracy: 0.8103 - val_auc: 0.8909 - val_loss: 1.4302 - val_precision: 0.8246 - val_recall: 0.8103
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8219 - auc: 0.9411 - loss: 0.7312 - precision: 0.8955 - recall: 0.7489 - val_accuracy: 0.8103 - val_auc: 0.8953 - val_loss: 1.2580 - val_precision: 0.8246 - val_recall: 0.8103
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8297 - auc: 0.9419 - loss: 0.7744 - precision: 0.8757 - recall: 0.7335 - val_accuracy: 0.8103 - val_auc: 0.9107 - val_loss: 1.1475 - val_precision: 0.8246 - val_recall: 0.8103
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8426 - auc: 0.9489 - loss: 0.6942 - precision: 0.8933 - recall: 0.7238 - val_accuracy: 0.8103 - val_auc: 0.9133 - val_loss: 1.0627 - val_precision: 0.8246 - val_recall: 0.8103
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8260 - auc: 0.9535 - loss: 0.6519 - precision: 0.8660 - recall: 0.7715 - val_accuracy: 0.8103 - val_auc: 0.9182 - val_loss: 0.9690 - val_precision: 0.8246 - val_recall: 0.8103
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8809 - auc: 0.9706 - loss: 0.6037 - precision: 0.9280 - recall: 0.8029 - val_accuracy: 0.8276 - val_auc: 0.9246 - val_loss: 0.8844 - val_precision: 0.8246 - val_recall: 0.8103
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8826 - auc: 0.9691 - loss: 0.6091 - precision: 0.9140 - recall: 0.8419 - val_accuracy: 0.8276 - val_auc: 0.9368 - val_loss: 0.8179 - val_precision: 0.8276 - val_recall: 0.8276
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9105 - auc: 0.9858 - loss: 0.5310 - precision: 0.9330 - recall: 0.8581 - val_accuracy: 0.8276 - val_auc: 0.9355 - val_loss: 0.8046 - val_precision: 0.8276 - val_recall: 0.8276
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9113 - auc: 0.9782 - loss: 0.5663 - precision: 0.9241 - recall: 0.8505 - val_accuracy: 0.8276 - val_auc: 0.9350 - val_loss: 0.8199 - val_precision: 0.8276 - val_recall: 0.8276
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9230 - auc: 0.9825 - loss: 0.5227 - precision: 0.9392 - recall: 0.8890 - val_accuracy: 0.8276 - val_auc: 0.9332 - val_loss: 0.8282 - val_precision: 0.8276 - val_recall: 0.8276
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9145 - auc: 0.9826 - loss: 0.5011 - precision: 0.9344 - recall: 0.9031 - val_accuracy: 0.8276 - val_auc: 0.9328 - val_loss: 0.8257 - val_precision: 0.8246 - val_recall: 0.8103
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 716ms/step - accuracy: 0.4995 - auc: 0.7158 - loss: 1.1635 - precision: 0.6118 - recall: 0.3754 - val_accuracy: 0.6897 - val_auc: 0.8315 - val_loss: 2.4614 - val_precision: 0.6897 - val_recall: 0.6897
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7239 - auc: 0.8931 - loss: 0.8257 - precision: 0.8082 - recall: 0.6175 - val_accuracy: 0.7241 - val_auc: 0.8505 - val_loss: 1.9135 - val_precision: 0.7241 - val_recall: 0.7241
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7675 - auc: 0.9266 - loss: 0.7355 - precision: 0.8143 - recall: 0.7036 - val_accuracy: 0.7586 - val_auc: 0.8698 - val_loss: 1.5778 - val_precision: 0.7719 - val_recall: 0.7586
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8340 - auc: 0.9381 - loss: 0.7117 - precision: 0.8825 - recall: 0.7396 - val_accuracy: 0.7414 - val_auc: 0.8844 - val_loss: 1.3658 - val_precision: 0.7414 - val_recall: 0.7414
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7900 - auc: 0.9474 - loss: 0.6667 - precision: 0.8683 - recall: 0.7369 - val_accuracy: 0.7414 - val_auc: 0.8875 - val_loss: 1.2287 - val_precision: 0.7414 - val_recall: 0.7414
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8211 - auc: 0.9556 - loss: 0.6554 - precision: 0.9034 - recall: 0.7631 - val_accuracy: 0.7414 - val_auc: 0.8972 - val_loss: 1.1176 - val_precision: 0.7544 - val_recall: 0.7414
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8508 - auc: 0.9610 - loss: 0.6254 - precision: 0.8922 - recall: 0.7605 - val_accuracy: 0.7414 - val_auc: 0.8981 - val_loss: 1.0472 - val_precision: 0.7544 - val_recall: 0.7414
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8510 - auc: 0.9694 - loss: 0.5858 - precision: 0.8951 - recall: 0.8146 - val_accuracy: 0.7414 - val_auc: 0.8990 - val_loss: 0.9807 - val_precision: 0.7500 - val_recall: 0.7241
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8500 - auc: 0.9681 - loss: 0.5825 - precision: 0.8763 - recall: 0.7906 - val_accuracy: 0.7241 - val_auc: 0.9029 - val_loss: 0.9213 - val_precision: 0.7368 - val_recall: 0.7241
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9055 - auc: 0.9798 - loss: 0.5333 - precision: 0.9153 - recall: 0.8676 - val_accuracy: 0.7241 - val_auc: 0.9099 - val_loss: 0.8675 - val_precision: 0.7368 - val_recall: 0.7241
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9091 - auc: 0.9763 - loss: 0.5451 - precision: 0.9260 - recall: 0.8644 - val_accuracy: 0.7759 - val_auc: 0.9173 - val_loss: 0.8150 - val_precision: 0.7895 - val_recall: 0.7759
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9107 - auc: 0.9887 - loss: 0.4798 - precision: 0.9252 - recall: 0.8740 - val_accuracy: 0.7759 - val_auc: 0.9209 - val_loss: 0.7879 - val_precision: 0.7895 - val_recall: 0.7759
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9157 - auc: 0.9905 - loss: 0.4726 - precision: 0.9220 - recall: 0.8913 - val_accuracy: 0.7759 - val_auc: 0.9226 - val_loss: 0.7731 - val_precision: 0.8036 - val_recall: 0.7759
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9192 - auc: 0.9890 - loss: 0.4897 - precision: 0.9336 - recall: 0.8683 - val_accuracy: 0.7586 - val_auc: 0.9241 - val_loss: 0.7713 - val_precision: 0.7857 - val_recall: 0.7586
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9495 - auc: 0.9957 - loss: 0.4419 - precision: 0.9665 - recall: 0.9450 - val_accuracy: 0.7586 - val_auc: 0.9238 - val_loss: 0.7705 - val_precision: 0.7857 - val_recall: 0.7586
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9148 - auc: 0.9883 - loss: 0.4521 - precision: 0.9278 - recall: 0.9032 - val_accuracy: 0.7759 - val_auc: 0.9211 - val_loss: 0.7816 - val_precision: 0.7857 - val_recall: 0.7586
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9583 - auc: 0.9957 - loss: 0.4013 - precision: 0.9618 - recall: 0.9420 - val_accuracy: 0.7759 - val_auc: 0.9201 - val_loss: 0.7872 - val_precision: 0.7895 - val_recall: 0.7759
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9288 - auc: 0.9936 - loss: 0.4042 - precision: 0.9476 - recall: 0.9110 - val_accuracy: 0.7759 - val_auc: 0.9216 - val_loss: 0.7732 - val_precision: 0.7857 - val_recall: 0.7586
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 745ms/step - accuracy: 0.4739 - auc: 0.6504 - loss: 1.3184 - precision: 0.4884 - recall: 0.3651 - val_accuracy: 0.6379 - val_auc: 0.7954 - val_loss: 1.9419 - val_precision: 0.6379 - val_recall: 0.6379
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7142 - auc: 0.8749 - loss: 0.8542 - precision: 0.7556 - recall: 0.6021 - val_accuracy: 0.7069 - val_auc: 0.8500 - val_loss: 1.3407 - val_precision: 0.7069 - val_recall: 0.7069
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7375 - auc: 0.8979 - loss: 0.8059 - precision: 0.8095 - recall: 0.6656 - val_accuracy: 0.7759 - val_auc: 0.8882 - val_loss: 1.1191 - val_precision: 0.7759 - val_recall: 0.7759
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7411 - auc: 0.9192 - loss: 0.7456 - precision: 0.7766 - recall: 0.6816 - val_accuracy: 0.7759 - val_auc: 0.8977 - val_loss: 0.9896 - val_precision: 0.7759 - val_recall: 0.7759
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8249 - auc: 0.9354 - loss: 0.7017 - precision: 0.8461 - recall: 0.7693 - val_accuracy: 0.7759 - val_auc: 0.9083 - val_loss: 0.9008 - val_precision: 0.7759 - val_recall: 0.7759
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8326 - auc: 0.9585 - loss: 0.6331 - precision: 0.8638 - recall: 0.8013 - val_accuracy: 0.7586 - val_auc: 0.9217 - val_loss: 0.8347 - val_precision: 0.7586 - val_recall: 0.7586
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8433 - auc: 0.9573 - loss: 0.6485 - precision: 0.8817 - recall: 0.7712 - val_accuracy: 0.7586 - val_auc: 0.9303 - val_loss: 0.7729 - val_precision: 0.7586 - val_recall: 0.7586
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8620 - auc: 0.9659 - loss: 0.6223 - precision: 0.9017 - recall: 0.8210 - val_accuracy: 0.8103 - val_auc: 0.9368 - val_loss: 0.7201 - val_precision: 0.8103 - val_recall: 0.8103
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8783 - auc: 0.9729 - loss: 0.5794 - precision: 0.9039 - recall: 0.8357 - val_accuracy: 0.7931 - val_auc: 0.9414 - val_loss: 0.6899 - val_precision: 0.7931 - val_recall: 0.7931
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9033 - auc: 0.9848 - loss: 0.5134 - precision: 0.9241 - recall: 0.8667 - val_accuracy: 0.7931 - val_auc: 0.9427 - val_loss: 0.6787 - val_precision: 0.7931 - val_recall: 0.7931
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8871 - auc: 0.9824 - loss: 0.5304 - precision: 0.8979 - recall: 0.8506 - val_accuracy: 0.8103 - val_auc: 0.9451 - val_loss: 0.6615 - val_precision: 0.8103 - val_recall: 0.8103
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9325 - auc: 0.9848 - loss: 0.5105 - precision: 0.9320 - recall: 0.9020 - val_accuracy: 0.8103 - val_auc: 0.9458 - val_loss: 0.6485 - val_precision: 0.8103 - val_recall: 0.8103
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9209 - auc: 0.9812 - loss: 0.5028 - precision: 0.9283 - recall: 0.8906 - val_accuracy: 0.7931 - val_auc: 0.9466 - val_loss: 0.6453 - val_precision: 0.7931 - val_recall: 0.7931
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9359 - auc: 0.9940 - loss: 0.4611 - precision: 0.9487 - recall: 0.9099 - val_accuracy: 0.7931 - val_auc: 0.9443 - val_loss: 0.6653 - val_precision: 0.7931 - val_recall: 0.7931
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9300 - auc: 0.9933 - loss: 0.4439 - precision: 0.9294 - recall: 0.9226 - val_accuracy: 0.7931 - val_auc: 0.9420 - val_loss: 0.6719 - val_precision: 0.7931 - val_recall: 0.7931
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9550 - auc: 0.9961 - loss: 0.4022 - precision: 0.9644 - recall: 0.9436 - val_accuracy: 0.7931 - val_auc: 0.9424 - val_loss: 0.6707 - val_precision: 0.7931 - val_recall: 0.7931
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x70635a544b80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/stepWARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x70635a544b80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 725ms/step - accuracy: 0.3199 - auc: 0.5340 - loss: 1.6412 - precision: 0.3287 - recall: 0.2581 - val_accuracy: 0.6724 - val_auc: 0.8005 - val_loss: 2.5622 - val_precision: 0.6724 - val_recall: 0.6724
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6362 - auc: 0.8192 - loss: 1.0470 - precision: 0.7043 - recall: 0.5395 - val_accuracy: 0.6552 - val_auc: 0.8464 - val_loss: 1.6147 - val_precision: 0.6667 - val_recall: 0.6552
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7083 - auc: 0.8565 - loss: 0.9195 - precision: 0.7537 - recall: 0.6321 - val_accuracy: 0.7241 - val_auc: 0.8816 - val_loss: 1.2075 - val_precision: 0.7321 - val_recall: 0.7069
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6623 - auc: 0.8610 - loss: 0.9032 - precision: 0.7043 - recall: 0.5930 - val_accuracy: 0.7759 - val_auc: 0.8993 - val_loss: 1.0116 - val_precision: 0.7719 - val_recall: 0.7586
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7699 - auc: 0.9153 - loss: 0.7794 - precision: 0.8291 - recall: 0.7097 - val_accuracy: 0.7759 - val_auc: 0.9158 - val_loss: 0.8688 - val_precision: 0.7857 - val_recall: 0.7586
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8013 - auc: 0.9499 - loss: 0.6867 - precision: 0.8483 - recall: 0.7403 - val_accuracy: 0.7586 - val_auc: 0.9302 - val_loss: 0.7821 - val_precision: 0.7818 - val_recall: 0.7414
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8241 - auc: 0.9450 - loss: 0.7250 - precision: 0.8892 - recall: 0.7203 - val_accuracy: 0.7586 - val_auc: 0.9356 - val_loss: 0.7438 - val_precision: 0.7719 - val_recall: 0.7586
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8028 - auc: 0.9321 - loss: 0.7249 - precision: 0.8308 - recall: 0.7259 - val_accuracy: 0.7586 - val_auc: 0.9386 - val_loss: 0.7173 - val_precision: 0.7679 - val_recall: 0.7414
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8403 - auc: 0.9510 - loss: 0.6729 - precision: 0.8608 - recall: 0.7683 - val_accuracy: 0.7414 - val_auc: 0.9373 - val_loss: 0.7137 - val_precision: 0.7544 - val_recall: 0.7414
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9133 - auc: 0.9811 - loss: 0.5664 - precision: 0.9200 - recall: 0.8577 - val_accuracy: 0.7414 - val_auc: 0.9363 - val_loss: 0.7040 - val_precision: 0.7544 - val_recall: 0.7414
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8948 - auc: 0.9776 - loss: 0.5860 - precision: 0.9285 - recall: 0.8246 - val_accuracy: 0.7759 - val_auc: 0.9393 - val_loss: 0.6843 - val_precision: 0.8148 - val_recall: 0.7586
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9025 - auc: 0.9804 - loss: 0.5416 - precision: 0.9269 - recall: 0.8523 - val_accuracy: 0.7931 - val_auc: 0.9432 - val_loss: 0.6693 - val_precision: 0.8148 - val_recall: 0.7586
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9424 - auc: 0.9891 - loss: 0.5005 - precision: 0.9498 - recall: 0.9159 - val_accuracy: 0.7931 - val_auc: 0.9443 - val_loss: 0.6671 - val_precision: 0.8148 - val_recall: 0.7586
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9455 - auc: 0.9893 - loss: 0.5085 - precision: 0.9437 - recall: 0.9146 - val_accuracy: 0.8103 - val_auc: 0.9436 - val_loss: 0.6660 - val_precision: 0.8182 - val_recall: 0.7759
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9321 - auc: 0.9879 - loss: 0.4931 - precision: 0.9362 - recall: 0.9058 - val_accuracy: 0.8103 - val_auc: 0.9407 - val_loss: 0.6756 - val_precision: 0.8214 - val_recall: 0.7931
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9754 - auc: 0.9980 - loss: 0.4274 - precision: 0.9840 - recall: 0.9455 - val_accuracy: 0.7931 - val_auc: 0.9340 - val_loss: 0.6947 - val_precision: 0.8214 - val_recall: 0.7931
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9706 - auc: 0.9986 - loss: 0.4304 - precision: 0.9891 - recall: 0.9576 - val_accuracy: 0.7931 - val_auc: 0.9309 - val_loss: 0.7025 - val_precision: 0.8036 - val_recall: 0.7759
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 725ms/step - accuracy: 0.4320 - auc: 0.6142 - loss: 1.3858 - precision: 0.4766 - recall: 0.3311 - val_accuracy: 0.6207 - val_auc: 0.7610 - val_loss: 4.2719 - val_precision: 0.6207 - val_recall: 0.6207
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7031 - auc: 0.8478 - loss: 0.9624 - precision: 0.7787 - recall: 0.5632 - val_accuracy: 0.6552 - val_auc: 0.7776 - val_loss: 2.8152 - val_precision: 0.6552 - val_recall: 0.6552
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6842 - auc: 0.8639 - loss: 0.8955 - precision: 0.7594 - recall: 0.5689 - val_accuracy: 0.6552 - val_auc: 0.8193 - val_loss: 2.0453 - val_precision: 0.6667 - val_recall: 0.6552
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7576 - auc: 0.8990 - loss: 0.8258 - precision: 0.8097 - recall: 0.6351 - val_accuracy: 0.6897 - val_auc: 0.8548 - val_loss: 1.6252 - val_precision: 0.6897 - val_recall: 0.6897
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7714 - auc: 0.9296 - loss: 0.7671 - precision: 0.8265 - recall: 0.7015 - val_accuracy: 0.7069 - val_auc: 0.8895 - val_loss: 1.3549 - val_precision: 0.7069 - val_recall: 0.7069
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8073 - auc: 0.9346 - loss: 0.7494 - precision: 0.8514 - recall: 0.7055 - val_accuracy: 0.7069 - val_auc: 0.8963 - val_loss: 1.1964 - val_precision: 0.7069 - val_recall: 0.7069
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8231 - auc: 0.9445 - loss: 0.7105 - precision: 0.8621 - recall: 0.7322 - val_accuracy: 0.7241 - val_auc: 0.9029 - val_loss: 1.0672 - val_precision: 0.7241 - val_recall: 0.7241
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8487 - auc: 0.9623 - loss: 0.6497 - precision: 0.8949 - recall: 0.7716 - val_accuracy: 0.7586 - val_auc: 0.9102 - val_loss: 0.9681 - val_precision: 0.7586 - val_recall: 0.7586
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8700 - auc: 0.9685 - loss: 0.6428 - precision: 0.9201 - recall: 0.7817 - val_accuracy: 0.7586 - val_auc: 0.9147 - val_loss: 0.8870 - val_precision: 0.7586 - val_recall: 0.7586
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8774 - auc: 0.9805 - loss: 0.6106 - precision: 0.9110 - recall: 0.8145 - val_accuracy: 0.7586 - val_auc: 0.9240 - val_loss: 0.8233 - val_precision: 0.7586 - val_recall: 0.7586
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9101 - auc: 0.9771 - loss: 0.5925 - precision: 0.9255 - recall: 0.8234 - val_accuracy: 0.7586 - val_auc: 0.9269 - val_loss: 0.7919 - val_precision: 0.7586 - val_recall: 0.7586
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9233 - auc: 0.9884 - loss: 0.5381 - precision: 0.9500 - recall: 0.8672 - val_accuracy: 0.7586 - val_auc: 0.9278 - val_loss: 0.7783 - val_precision: 0.7857 - val_recall: 0.7586
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9095 - auc: 0.9863 - loss: 0.5391 - precision: 0.9529 - recall: 0.8835 - val_accuracy: 0.7931 - val_auc: 0.9324 - val_loss: 0.7563 - val_precision: 0.7857 - val_recall: 0.7586
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9206 - auc: 0.9888 - loss: 0.5029 - precision: 0.9546 - recall: 0.8870 - val_accuracy: 0.7931 - val_auc: 0.9341 - val_loss: 0.7342 - val_precision: 0.7931 - val_recall: 0.7931
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9317 - auc: 0.9883 - loss: 0.4971 - precision: 0.9497 - recall: 0.9033 - val_accuracy: 0.7931 - val_auc: 0.9366 - val_loss: 0.7151 - val_precision: 0.8070 - val_recall: 0.7931
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9538 - auc: 0.9916 - loss: 0.4780 - precision: 0.9715 - recall: 0.9099 - val_accuracy: 0.7931 - val_auc: 0.9390 - val_loss: 0.6986 - val_precision: 0.8070 - val_recall: 0.7931
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9501 - auc: 0.9974 - loss: 0.4331 - precision: 0.9653 - recall: 0.9387 - val_accuracy: 0.8276 - val_auc: 0.9428 - val_loss: 0.6814 - val_precision: 0.8421 - val_recall: 0.8276
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9392 - auc: 0.9941 - loss: 0.4427 - precision: 0.9650 - recall: 0.9364 - val_accuracy: 0.8276 - val_auc: 0.9446 - val_loss: 0.6708 - val_precision: 0.8421 - val_recall: 0.8276
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9475 - auc: 0.9955 - loss: 0.4305 - precision: 0.9624 - recall: 0.9269 - val_accuracy: 0.8276 - val_auc: 0.9467 - val_loss: 0.6662 - val_precision: 0.8276 - val_recall: 0.8276
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9810 - auc: 0.9993 - loss: 0.3855 - precision: 0.9905 - recall: 0.9588 - val_accuracy: 0.8448 - val_auc: 0.9477 - val_loss: 0.6579 - val_precision: 0.8571 - val_recall: 0.8276
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9823 - auc: 0.9997 - loss: 0.3780 - precision: 0.9924 - recall: 0.9763 - val_accuracy: 0.8448 - val_auc: 0.9481 - val_loss: 0.6563 - val_precision: 0.8571 - val_recall: 0.8276
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9881 - auc: 0.9974 - loss: 0.3567 - precision: 0.9907 - recall: 0.9761 - val_accuracy: 0.8448 - val_auc: 0.9488 - val_loss: 0.6538 - val_precision: 0.8571 - val_recall: 0.8276
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9939 - auc: 0.9988 - loss: 0.3494 - precision: 0.9956 - recall: 0.9749 - val_accuracy: 0.8448 - val_auc: 0.9506 - val_loss: 0.6442 - val_precision: 0.8421 - val_recall: 0.8276
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.3157 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8276 - val_auc: 0.9526 - val_loss: 0.6421 - val_precision: 0.8421 - val_recall: 0.8276
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9945 - auc: 0.9998 - loss: 0.3200 - precision: 0.9972 - recall: 0.9735 - val_accuracy: 0.8276 - val_auc: 0.9520 - val_loss: 0.6459 - val_precision: 0.8421 - val_recall: 0.8276
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9798 - auc: 0.9996 - loss: 0.3041 - precision: 0.9884 - recall: 0.9754 - val_accuracy: 0.8276 - val_auc: 0.9489 - val_loss: 0.6498 - val_precision: 0.8421 - val_recall: 0.8276
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9925 - auc: 0.9999 - loss: 0.3080 - precision: 1.0000 - recall: 0.9898 - val_accuracy: 0.8103 - val_auc: 0.9462 - val_loss: 0.6586 - val_precision: 0.8393 - val_recall: 0.8103
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.4045 - auc: 0.6139 - loss: 1.4241 - precision: 0.4544 - recall: 0.3452 - val_accuracy: 0.6591 - val_auc: 0.8082 - val_loss: 1.7841 - val_precision: 0.6905 - val_recall: 0.6591
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6761 - auc: 0.8208 - loss: 1.0021 - precision: 0.7274 - recall: 0.5380 - val_accuracy: 0.5909 - val_auc: 0.7935 - val_loss: 2.0180 - val_precision: 0.6047 - val_recall: 0.5909
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6371 - auc: 0.8263 - loss: 0.9944 - precision: 0.7264 - recall: 0.5437 - val_accuracy: 0.5909 - val_auc: 0.8045 - val_loss: 1.8094 - val_precision: 0.6047 - val_recall: 0.5909
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7967 - auc: 0.9023 - loss: 0.8065 - precision: 0.8548 - recall: 0.7199 - val_accuracy: 0.6364 - val_auc: 0.8193 - val_loss: 1.6200 - val_precision: 0.6364 - val_recall: 0.6364
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7343 - auc: 0.8836 - loss: 0.8376 - precision: 0.7968 - recall: 0.6088 - val_accuracy: 0.7500 - val_auc: 0.8297 - val_loss: 1.4632 - val_precision: 0.7381 - val_recall: 0.7045
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8044 - auc: 0.9208 - loss: 0.7508 - precision: 0.8476 - recall: 0.6945 - val_accuracy: 0.7500 - val_auc: 0.8361 - val_loss: 1.3461 - val_precision: 0.7381 - val_recall: 0.7045
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8482 - auc: 0.9483 - loss: 0.6683 - precision: 0.8884 - recall: 0.7665 - val_accuracy: 0.7045 - val_auc: 0.8383 - val_loss: 1.2961 - val_precision: 0.7381 - val_recall: 0.7045
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8472 - auc: 0.9510 - loss: 0.6711 - precision: 0.9228 - recall: 0.7898 - val_accuracy: 0.7045 - val_auc: 0.8443 - val_loss: 1.2496 - val_precision: 0.7381 - val_recall: 0.7045
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8599 - auc: 0.9600 - loss: 0.6334 - precision: 0.9223 - recall: 0.8084 - val_accuracy: 0.7273 - val_auc: 0.8490 - val_loss: 1.2066 - val_precision: 0.7436 - val_recall: 0.6591
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8920 - auc: 0.9773 - loss: 0.5929 - precision: 0.9420 - recall: 0.8386 - val_accuracy: 0.7273 - val_auc: 0.8551 - val_loss: 1.1592 - val_precision: 0.7500 - val_recall: 0.6818
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8705 - auc: 0.9761 - loss: 0.5697 - precision: 0.9420 - recall: 0.7781 - val_accuracy: 0.7273 - val_auc: 0.8600 - val_loss: 1.1201 - val_precision: 0.7500 - val_recall: 0.6818
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9203 - auc: 0.9818 - loss: 0.5572 - precision: 0.9450 - recall: 0.8317 - val_accuracy: 0.7727 - val_auc: 0.8643 - val_loss: 1.0842 - val_precision: 0.7500 - val_recall: 0.6818
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8843 - auc: 0.9860 - loss: 0.5142 - precision: 0.9506 - recall: 0.8425 - val_accuracy: 0.7727 - val_auc: 0.8648 - val_loss: 1.0432 - val_precision: 0.7561 - val_recall: 0.7045
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9124 - auc: 0.9844 - loss: 0.5113 - precision: 0.9387 - recall: 0.8784 - val_accuracy: 0.7727 - val_auc: 0.8687 - val_loss: 1.0277 - val_precision: 0.7949 - val_recall: 0.7045
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9310 - auc: 0.9931 - loss: 0.4453 - precision: 0.9612 - recall: 0.8911 - val_accuracy: 0.7500 - val_auc: 0.8705 - val_loss: 1.0268 - val_precision: 0.8158 - val_recall: 0.7045
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9572 - auc: 0.9929 - loss: 0.4658 - precision: 0.9737 - recall: 0.8998 - val_accuracy: 0.7500 - val_auc: 0.8709 - val_loss: 1.0231 - val_precision: 0.8108 - val_recall: 0.6818
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9310 - auc: 0.9943 - loss: 0.4409 - precision: 0.9590 - recall: 0.9096 - val_accuracy: 0.7045 - val_auc: 0.8639 - val_loss: 1.0375 - val_precision: 0.7838 - val_recall: 0.6591
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9523 - auc: 0.9967 - loss: 0.4101 - precision: 0.9802 - recall: 0.9163 - val_accuracy: 0.7045 - val_auc: 0.8663 - val_loss: 1.0428 - val_precision: 0.7436 - val_recall: 0.6591
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9816 - auc: 0.9980 - loss: 0.3815 - precision: 0.9890 - recall: 0.9611 - val_accuracy: 0.7273 - val_auc: 0.8666 - val_loss: 1.0397 - val_precision: 0.7436 - val_recall: 0.6591
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.5935 - auc: 0.7724 - loss: 1.0782 - precision: 0.5832 - recall: 0.4470 - val_accuracy: 0.7209 - val_auc: 0.8338 - val_loss: 1.5306 - val_precision: 0.7209 - val_recall: 0.7209
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7536 - auc: 0.8778 - loss: 0.8550 - precision: 0.7815 - recall: 0.6732 - val_accuracy: 0.6977 - val_auc: 0.8549 - val_loss: 1.4135 - val_precision: 0.6977 - val_recall: 0.6977
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7440 - auc: 0.9048 - loss: 0.7934 - precision: 0.8162 - recall: 0.6713 - val_accuracy: 0.6977 - val_auc: 0.8636 - val_loss: 1.3652 - val_precision: 0.6977 - val_recall: 0.6977
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8002 - auc: 0.9348 - loss: 0.7222 - precision: 0.8534 - recall: 0.7167 - val_accuracy: 0.6977 - val_auc: 0.8718 - val_loss: 1.2794 - val_precision: 0.7143 - val_recall: 0.6977
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8263 - auc: 0.9492 - loss: 0.6926 - precision: 0.8480 - recall: 0.7904 - val_accuracy: 0.6977 - val_auc: 0.8833 - val_loss: 1.1405 - val_precision: 0.7143 - val_recall: 0.6977
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8302 - auc: 0.9583 - loss: 0.6538 - precision: 0.8873 - recall: 0.7681 - val_accuracy: 0.7442 - val_auc: 0.8932 - val_loss: 1.0435 - val_precision: 0.7381 - val_recall: 0.7209
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8243 - auc: 0.9665 - loss: 0.6187 - precision: 0.8782 - recall: 0.7556 - val_accuracy: 0.7442 - val_auc: 0.8968 - val_loss: 0.9899 - val_precision: 0.7442 - val_recall: 0.7442
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8865 - auc: 0.9746 - loss: 0.5741 - precision: 0.9289 - recall: 0.8642 - val_accuracy: 0.7442 - val_auc: 0.9032 - val_loss: 0.9335 - val_precision: 0.7442 - val_recall: 0.7442
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9001 - auc: 0.9770 - loss: 0.5688 - precision: 0.9306 - recall: 0.8584 - val_accuracy: 0.7442 - val_auc: 0.9089 - val_loss: 0.9029 - val_precision: 0.7442 - val_recall: 0.7442
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8816 - auc: 0.9814 - loss: 0.5556 - precision: 0.9160 - recall: 0.8535 - val_accuracy: 0.7674 - val_auc: 0.9129 - val_loss: 0.8675 - val_precision: 0.7674 - val_recall: 0.7674
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8924 - auc: 0.9826 - loss: 0.5232 - precision: 0.9301 - recall: 0.8652 - val_accuracy: 0.7674 - val_auc: 0.9181 - val_loss: 0.8187 - val_precision: 0.7674 - val_recall: 0.7674
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9408 - auc: 0.9925 - loss: 0.4845 - precision: 0.9531 - recall: 0.9272 - val_accuracy: 0.7674 - val_auc: 0.9236 - val_loss: 0.7797 - val_precision: 0.7857 - val_recall: 0.7674
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9156 - auc: 0.9865 - loss: 0.5120 - precision: 0.9282 - recall: 0.8777 - val_accuracy: 0.7907 - val_auc: 0.9297 - val_loss: 0.7360 - val_precision: 0.7907 - val_recall: 0.7907
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9002 - auc: 0.9854 - loss: 0.5085 - precision: 0.9318 - recall: 0.8740 - val_accuracy: 0.7907 - val_auc: 0.9333 - val_loss: 0.7089 - val_precision: 0.7907 - val_recall: 0.7907
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9515 - auc: 0.9932 - loss: 0.4638 - precision: 0.9630 - recall: 0.9107 - val_accuracy: 0.8140 - val_auc: 0.9346 - val_loss: 0.6992 - val_precision: 0.8140 - val_recall: 0.8140
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9729 - auc: 0.9981 - loss: 0.3999 - precision: 0.9800 - recall: 0.9535 - val_accuracy: 0.8140 - val_auc: 0.9362 - val_loss: 0.6897 - val_precision: 0.8140 - val_recall: 0.8140
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9748 - auc: 0.9991 - loss: 0.3929 - precision: 0.9880 - recall: 0.9612 - val_accuracy: 0.8140 - val_auc: 0.9360 - val_loss: 0.6846 - val_precision: 0.8095 - val_recall: 0.7907
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9816 - auc: 0.9981 - loss: 0.3995 - precision: 0.9808 - recall: 0.9427 - val_accuracy: 0.8140 - val_auc: 0.9343 - val_loss: 0.6838 - val_precision: 0.8250 - val_recall: 0.7674
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9670 - auc: 0.9946 - loss: 0.3982 - precision: 0.9714 - recall: 0.9534 - val_accuracy: 0.8140 - val_auc: 0.9385 - val_loss: 0.6735 - val_precision: 0.8333 - val_recall: 0.8140
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9661 - auc: 0.9962 - loss: 0.3822 - precision: 0.9706 - recall: 0.9573 - val_accuracy: 0.8140 - val_auc: 0.9377 - val_loss: 0.6654 - val_precision: 0.8333 - val_recall: 0.8140
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9748 - auc: 0.9986 - loss: 0.3515 - precision: 0.9748 - recall: 0.9748 - val_accuracy: 0.8372 - val_auc: 0.9390 - val_loss: 0.6610 - val_precision: 0.8333 - val_recall: 0.8140
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9787 - auc: 0.9991 - loss: 0.3525 - precision: 0.9900 - recall: 0.9583 - val_accuracy: 0.8372 - val_auc: 0.9394 - val_loss: 0.6552 - val_precision: 0.8372 - val_recall: 0.8372
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9923 - auc: 0.9989 - loss: 0.3343 - precision: 0.9970 - recall: 0.9738 - val_accuracy: 0.8372 - val_auc: 0.9381 - val_loss: 0.6463 - val_precision: 0.8372 - val_recall: 0.8372
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9884 - auc: 0.9985 - loss: 0.3310 - precision: 0.9882 - recall: 0.9796 - val_accuracy: 0.8140 - val_auc: 0.9388 - val_loss: 0.6443 - val_precision: 0.8333 - val_recall: 0.8140
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9660 - auc: 0.9967 - loss: 0.3359 - precision: 0.9656 - recall: 0.9544 - val_accuracy: 0.8140 - val_auc: 0.9390 - val_loss: 0.6394 - val_precision: 0.8537 - val_recall: 0.8140
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9971 - auc: 1.0000 - loss: 0.3021 - precision: 0.9971 - recall: 0.9923 - val_accuracy: 0.8372 - val_auc: 0.9427 - val_loss: 0.6275 - val_precision: 0.8537 - val_recall: 0.8140
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9971 - auc: 0.9999 - loss: 0.2832 - precision: 0.9971 - recall: 0.9971 - val_accuracy: 0.8372 - val_auc: 0.9444 - val_loss: 0.6189 - val_precision: 0.8571 - val_recall: 0.8372
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9971 - auc: 1.0000 - loss: 0.2783 - precision: 0.9971 - recall: 0.9923 - val_accuracy: 0.8372 - val_auc: 0.9458 - val_loss: 0.6109 - val_precision: 0.8571 - val_recall: 0.8372
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9952 - auc: 0.9995 - loss: 0.2891 - precision: 0.9951 - recall: 0.9894 - val_accuracy: 0.8372 - val_auc: 0.9454 - val_loss: 0.6146 - val_precision: 0.8571 - val_recall: 0.8372
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9835 - auc: 0.9982 - loss: 0.3038 - precision: 0.9835 - recall: 0.9835 - val_accuracy: 0.8605 - val_auc: 0.9429 - val_loss: 0.6206 - val_precision: 0.8571 - val_recall: 0.8372
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9913 - auc: 0.9997 - loss: 0.2869 - precision: 0.9913 - recall: 0.9913 - val_accuracy: 0.8605 - val_auc: 0.9438 - val_loss: 0.6212 - val_precision: 0.8571 - val_recall: 0.8372
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.5091 - auc: 0.6899 - loss: 1.2098 - precision: 0.5869 - recall: 0.3239 - val_accuracy: 0.6977 - val_auc: 0.7930 - val_loss: 1.6879 - val_precision: 0.6829 - val_recall: 0.6512
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6867 - auc: 0.8031 - loss: 1.0395 - precision: 0.7473 - recall: 0.4967 - val_accuracy: 0.7442 - val_auc: 0.8230 - val_loss: 1.4701 - val_precision: 0.7500 - val_recall: 0.6977
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7634 - auc: 0.8816 - loss: 0.9051 - precision: 0.8160 - recall: 0.5984 - val_accuracy: 0.7907 - val_auc: 0.8379 - val_loss: 1.2532 - val_precision: 0.7805 - val_recall: 0.7442
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7147 - auc: 0.8730 - loss: 0.9033 - precision: 0.8418 - recall: 0.5888 - val_accuracy: 0.7907 - val_auc: 0.8733 - val_loss: 1.0241 - val_precision: 0.7857 - val_recall: 0.7674
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7838 - auc: 0.9090 - loss: 0.8309 - precision: 0.8808 - recall: 0.6692 - val_accuracy: 0.8372 - val_auc: 0.9041 - val_loss: 0.8599 - val_precision: 0.8372 - val_recall: 0.8372
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7789 - auc: 0.8969 - loss: 0.8498 - precision: 0.8370 - recall: 0.6372 - val_accuracy: 0.8372 - val_auc: 0.9213 - val_loss: 0.7615 - val_precision: 0.8372 - val_recall: 0.8372
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8148 - auc: 0.9327 - loss: 0.7545 - precision: 0.8769 - recall: 0.7324 - val_accuracy: 0.8372 - val_auc: 0.9277 - val_loss: 0.7195 - val_precision: 0.8372 - val_recall: 0.8372
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8313 - auc: 0.9527 - loss: 0.6883 - precision: 0.9169 - recall: 0.7819 - val_accuracy: 0.8372 - val_auc: 0.9333 - val_loss: 0.6798 - val_precision: 0.8372 - val_recall: 0.8372
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8633 - auc: 0.9623 - loss: 0.6706 - precision: 0.9095 - recall: 0.7788 - val_accuracy: 0.8605 - val_auc: 0.9365 - val_loss: 0.6544 - val_precision: 0.8605 - val_recall: 0.8605
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9070 - auc: 0.9756 - loss: 0.6172 - precision: 0.9434 - recall: 0.8167 - val_accuracy: 0.8605 - val_auc: 0.9402 - val_loss: 0.6473 - val_precision: 0.8571 - val_recall: 0.8372
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9176 - auc: 0.9834 - loss: 0.5670 - precision: 0.9603 - recall: 0.8206 - val_accuracy: 0.8605 - val_auc: 0.9408 - val_loss: 0.6454 - val_precision: 0.8571 - val_recall: 0.8372
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8681 - auc: 0.9712 - loss: 0.5990 - precision: 0.9247 - recall: 0.8235 - val_accuracy: 0.8605 - val_auc: 0.9394 - val_loss: 0.6468 - val_precision: 0.8571 - val_recall: 0.8372
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9245 - auc: 0.9917 - loss: 0.5237 - precision: 0.9571 - recall: 0.8652 - val_accuracy: 0.8837 - val_auc: 0.9385 - val_loss: 0.6439 - val_precision: 0.8780 - val_recall: 0.8372
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8602 - auc: 0.9790 - loss: 0.5559 - precision: 0.9028 - recall: 0.8214 - val_accuracy: 0.8837 - val_auc: 0.9371 - val_loss: 0.6378 - val_precision: 0.8810 - val_recall: 0.8605
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9176 - auc: 0.9884 - loss: 0.4911 - precision: 0.9583 - recall: 0.8914 - val_accuracy: 0.8837 - val_auc: 0.9393 - val_loss: 0.6244 - val_precision: 0.8837 - val_recall: 0.8837
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9166 - auc: 0.9875 - loss: 0.5170 - precision: 0.9492 - recall: 0.8506 - val_accuracy: 0.8837 - val_auc: 0.9475 - val_loss: 0.6045 - val_precision: 0.8810 - val_recall: 0.8605
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9835 - auc: 0.9987 - loss: 0.4504 - precision: 0.9876 - recall: 0.9252 - val_accuracy: 0.8837 - val_auc: 0.9500 - val_loss: 0.5969 - val_precision: 0.8810 - val_recall: 0.8605
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9641 - auc: 0.9982 - loss: 0.4150 - precision: 0.9741 - recall: 0.9477 - val_accuracy: 0.8605 - val_auc: 0.9529 - val_loss: 0.5924 - val_precision: 0.9024 - val_recall: 0.8605
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9748 - auc: 0.9967 - loss: 0.4005 - precision: 0.9880 - recall: 0.9573 - val_accuracy: 0.8605 - val_auc: 0.9520 - val_loss: 0.5940 - val_precision: 0.8780 - val_recall: 0.8372
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9777 - auc: 0.9978 - loss: 0.3957 - precision: 0.9919 - recall: 0.9438 - val_accuracy: 0.8605 - val_auc: 0.9498 - val_loss: 0.5947 - val_precision: 0.8780 - val_recall: 0.8372
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9670 - auc: 0.9982 - loss: 0.3807 - precision: 0.9778 - recall: 0.9398 - val_accuracy: 0.8605 - val_auc: 0.9498 - val_loss: 0.5997 - val_precision: 0.8750 - val_recall: 0.8140
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.3431 - auc: 0.5408 - loss: 1.4297 - precision: 0.3932 - recall: 0.2199 - val_accuracy: 0.5116 - val_auc: 0.6929 - val_loss: 2.3473 - val_precision: 0.5000 - val_recall: 0.4884
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5935 - auc: 0.7718 - loss: 1.0495 - precision: 0.6826 - recall: 0.4229 - val_accuracy: 0.5581 - val_auc: 0.7347 - val_loss: 1.9414 - val_precision: 0.5714 - val_recall: 0.5581
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5934 - auc: 0.7940 - loss: 1.0339 - precision: 0.7128 - recall: 0.3954 - val_accuracy: 0.5581 - val_auc: 0.7469 - val_loss: 1.8313 - val_precision: 0.5581 - val_recall: 0.5581
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7276 - auc: 0.8747 - loss: 0.9154 - precision: 0.7925 - recall: 0.5296 - val_accuracy: 0.5581 - val_auc: 0.7766 - val_loss: 1.7526 - val_precision: 0.5714 - val_recall: 0.5581
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6944 - auc: 0.8588 - loss: 0.9267 - precision: 0.7627 - recall: 0.5498 - val_accuracy: 0.5581 - val_auc: 0.7885 - val_loss: 1.6104 - val_precision: 0.5714 - val_recall: 0.5581
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7354 - auc: 0.8742 - loss: 0.8833 - precision: 0.8038 - recall: 0.5928 - val_accuracy: 0.5814 - val_auc: 0.8018 - val_loss: 1.4839 - val_precision: 0.5854 - val_recall: 0.5581
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7731 - auc: 0.8962 - loss: 0.8527 - precision: 0.8372 - recall: 0.6092 - val_accuracy: 0.6047 - val_auc: 0.8087 - val_loss: 1.3820 - val_precision: 0.6098 - val_recall: 0.5814
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8187 - auc: 0.9340 - loss: 0.7784 - precision: 0.8979 - recall: 0.6732 - val_accuracy: 0.6279 - val_auc: 0.8154 - val_loss: 1.2629 - val_precision: 0.6250 - val_recall: 0.5814
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8400 - auc: 0.9597 - loss: 0.7156 - precision: 0.9315 - recall: 0.7421 - val_accuracy: 0.6279 - val_auc: 0.8208 - val_loss: 1.1900 - val_precision: 0.6429 - val_recall: 0.6279
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8060 - auc: 0.9435 - loss: 0.7370 - precision: 0.8983 - recall: 0.7274 - val_accuracy: 0.6279 - val_auc: 0.8256 - val_loss: 1.1537 - val_precision: 0.6341 - val_recall: 0.6047
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8255 - auc: 0.9473 - loss: 0.7199 - precision: 0.8924 - recall: 0.7479 - val_accuracy: 0.6047 - val_auc: 0.8303 - val_loss: 1.1229 - val_precision: 0.6341 - val_recall: 0.6047
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8944 - auc: 0.9744 - loss: 0.6631 - precision: 0.9432 - recall: 0.8041 - val_accuracy: 0.6047 - val_auc: 0.8367 - val_loss: 1.0902 - val_precision: 0.6341 - val_recall: 0.6047
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8895 - auc: 0.9710 - loss: 0.6383 - precision: 0.9153 - recall: 0.7779 - val_accuracy: 0.6047 - val_auc: 0.8400 - val_loss: 1.0461 - val_precision: 0.6341 - val_recall: 0.6047
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8991 - auc: 0.9818 - loss: 0.6216 - precision: 0.9489 - recall: 0.7924 - val_accuracy: 0.6047 - val_auc: 0.8483 - val_loss: 0.9864 - val_precision: 0.6500 - val_recall: 0.6047
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9146 - auc: 0.9847 - loss: 0.5929 - precision: 0.9601 - recall: 0.8399 - val_accuracy: 0.6744 - val_auc: 0.8598 - val_loss: 0.9156 - val_precision: 0.6750 - val_recall: 0.6279
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9214 - auc: 0.9891 - loss: 0.5652 - precision: 0.9563 - recall: 0.8710 - val_accuracy: 0.6512 - val_auc: 0.8705 - val_loss: 0.8628 - val_precision: 0.6923 - val_recall: 0.6279
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9398 - auc: 0.9923 - loss: 0.5394 - precision: 0.9827 - recall: 0.8651 - val_accuracy: 0.6744 - val_auc: 0.8863 - val_loss: 0.8165 - val_precision: 0.6923 - val_recall: 0.6279
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9340 - auc: 0.9841 - loss: 0.5524 - precision: 0.9593 - recall: 0.8486 - val_accuracy: 0.6977 - val_auc: 0.9028 - val_loss: 0.7799 - val_precision: 0.7568 - val_recall: 0.6512
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9573 - auc: 0.9956 - loss: 0.4842 - precision: 0.9786 - recall: 0.8846 - val_accuracy: 0.7674 - val_auc: 0.9137 - val_loss: 0.7541 - val_precision: 0.7838 - val_recall: 0.6744
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9787 - auc: 0.9981 - loss: 0.4718 - precision: 0.9904 - recall: 0.8952 - val_accuracy: 0.7674 - val_auc: 0.9220 - val_loss: 0.7263 - val_precision: 0.7805 - val_recall: 0.7442
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9699 - auc: 0.9972 - loss: 0.4655 - precision: 0.9827 - recall: 0.9389 - val_accuracy: 0.7674 - val_auc: 0.9248 - val_loss: 0.7130 - val_precision: 0.7857 - val_recall: 0.7674
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9699 - auc: 0.9961 - loss: 0.4644 - precision: 0.9853 - recall: 0.9174 - val_accuracy: 0.7907 - val_auc: 0.9258 - val_loss: 0.7131 - val_precision: 0.7750 - val_recall: 0.7209
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9632 - auc: 0.9957 - loss: 0.4361 - precision: 0.9698 - recall: 0.9321 - val_accuracy: 0.7674 - val_auc: 0.9248 - val_loss: 0.7188 - val_precision: 0.7895 - val_recall: 0.6977
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9719 - auc: 0.9991 - loss: 0.4314 - precision: 0.9939 - recall: 0.9291 - val_accuracy: 0.7674 - val_auc: 0.9225 - val_loss: 0.7219 - val_precision: 0.7838 - val_recall: 0.6744
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.3111 - auc: 0.4855 - loss: 1.7549 - precision: 0.2884 - recall: 0.2133 - val_accuracy: 0.6512 - val_auc: 0.8171 - val_loss: 2.5584 - val_precision: 0.6512 - val_recall: 0.6512
# Epoch 2/50
# ...
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9059 - auc: 0.9839 - loss: 0.5051 - precision: 0.9307 - recall: 0.8737 - val_accuracy: 0.8636 - val_auc: 0.9724 - val_loss: 0.4999 - val_precision: 0.8750 - val_recall: 0.8485
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9299 - auc: 0.9829 - loss: 0.5029 - precision: 0.9387 - recall: 0.8797 - val_accuracy: 0.8788 - val_auc: 0.9714 - val_loss: 0.5060 - val_precision: 0.8710 - val_recall: 0.8182
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9367 - auc: 0.9924 - loss: 0.4613 - precision: 0.9639 - recall: 0.8986 - val_accuracy: 0.8485 - val_auc: 0.9716 - val_loss: 0.5058 - val_precision: 0.8571 - val_recall: 0.8182
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 678ms/step - accuracy: 0.3535 - auc: 0.5283 - loss: 1.5489 - precision: 0.3662 - recall: 0.2448 - val_accuracy: 0.5606 - val_auc: 0.6823 - val_loss: 4.5284 - val_precision: 0.5606 - val_recall: 0.5606
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5514 - auc: 0.7464 - loss: 1.1668 - precision: 0.6439 - recall: 0.4503 - val_accuracy: 0.6061 - val_auc: 0.7486 - val_loss: 2.9113 - val_precision: 0.6190 - val_recall: 0.5909
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6933 - auc: 0.8346 - loss: 1.0097 - precision: 0.7906 - recall: 0.5810 - val_accuracy: 0.6667 - val_auc: 0.8048 - val_loss: 2.0088 - val_precision: 0.6615 - val_recall: 0.6515
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7097 - auc: 0.8717 - loss: 0.9129 - precision: 0.8152 - recall: 0.5871 - val_accuracy: 0.7273 - val_auc: 0.8380 - val_loss: 1.5879 - val_precision: 0.7500 - val_recall: 0.7273
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7547 - auc: 0.8789 - loss: 0.8932 - precision: 0.8392 - recall: 0.6307 - val_accuracy: 0.6818 - val_auc: 0.8431 - val_loss: 1.3508 - val_precision: 0.6818 - val_recall: 0.6818
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7858 - auc: 0.9135 - loss: 0.8053 - precision: 0.8305 - recall: 0.6752 - val_accuracy: 0.6818 - val_auc: 0.8628 - val_loss: 1.1295 - val_precision: 0.7258 - val_recall: 0.6818
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8091 - auc: 0.9128 - loss: 0.8085 - precision: 0.8540 - recall: 0.7336 - val_accuracy: 0.7576 - val_auc: 0.8802 - val_loss: 0.9885 - val_precision: 0.7895 - val_recall: 0.6818
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8174 - auc: 0.9366 - loss: 0.7376 - precision: 0.8909 - recall: 0.6971 - val_accuracy: 0.8182 - val_auc: 0.8933 - val_loss: 0.9124 - val_precision: 0.8621 - val_recall: 0.7576
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8609 - auc: 0.9505 - loss: 0.7050 - precision: 0.9117 - recall: 0.7489 - val_accuracy: 0.7879 - val_auc: 0.9030 - val_loss: 0.8634 - val_precision: 0.8448 - val_recall: 0.7424
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8737 - auc: 0.9677 - loss: 0.6216 - precision: 0.9274 - recall: 0.8027 - val_accuracy: 0.8030 - val_auc: 0.9030 - val_loss: 0.8542 - val_precision: 0.8305 - val_recall: 0.7424
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8667 - auc: 0.9599 - loss: 0.6313 - precision: 0.9197 - recall: 0.8010 - val_accuracy: 0.7727 - val_auc: 0.9004 - val_loss: 0.8617 - val_precision: 0.7966 - val_recall: 0.7121
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8593 - auc: 0.9715 - loss: 0.5940 - precision: 0.8886 - recall: 0.8131 - val_accuracy: 0.7727 - val_auc: 0.9000 - val_loss: 0.8541 - val_precision: 0.8000 - val_recall: 0.7273
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8881 - auc: 0.9724 - loss: 0.5714 - precision: 0.9204 - recall: 0.8444 - val_accuracy: 0.7879 - val_auc: 0.9062 - val_loss: 0.8211 - val_precision: 0.8333 - val_recall: 0.7576
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8262 - auc: 0.9625 - loss: 0.6072 - precision: 0.8939 - recall: 0.7727 - val_accuracy: 0.8182 - val_auc: 0.9175 - val_loss: 0.7675 - val_precision: 0.8475 - val_recall: 0.7576
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8987 - auc: 0.9784 - loss: 0.5460 - precision: 0.9371 - recall: 0.8586 - val_accuracy: 0.8333 - val_auc: 0.9274 - val_loss: 0.7185 - val_precision: 0.8793 - val_recall: 0.7727
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8992 - auc: 0.9874 - loss: 0.4981 - precision: 0.9422 - recall: 0.8671 - val_accuracy: 0.8182 - val_auc: 0.9396 - val_loss: 0.6675 - val_precision: 0.8929 - val_recall: 0.7576
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9230 - auc: 0.9908 - loss: 0.4746 - precision: 0.9645 - recall: 0.8973 - val_accuracy: 0.8182 - val_auc: 0.9467 - val_loss: 0.6453 - val_precision: 0.8909 - val_recall: 0.7424
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9118 - auc: 0.9875 - loss: 0.4826 - precision: 0.9410 - recall: 0.8596 - val_accuracy: 0.8182 - val_auc: 0.9428 - val_loss: 0.6611 - val_precision: 0.8704 - val_recall: 0.7121
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9192 - auc: 0.9885 - loss: 0.4798 - precision: 0.9442 - recall: 0.8776 - val_accuracy: 0.8485 - val_auc: 0.9401 - val_loss: 0.6596 - val_precision: 0.8644 - val_recall: 0.7727
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9302 - auc: 0.9897 - loss: 0.4404 - precision: 0.9534 - recall: 0.8939 - val_accuracy: 0.8333 - val_auc: 0.9351 - val_loss: 0.6649 - val_precision: 0.8571 - val_recall: 0.8182
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 733ms/step - accuracy: 0.4469 - auc: 0.6193 - loss: 1.3703 - precision: 0.4270 - recall: 0.3053 - val_accuracy: 0.5455 - val_auc: 0.6936 - val_loss: 5.9570 - val_precision: 0.5455 - val_recall: 0.5455
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6180 - auc: 0.7789 - loss: 1.0968 - precision: 0.6620 - recall: 0.4885 - val_accuracy: 0.6212 - val_auc: 0.7234 - val_loss: 3.8308 - val_precision: 0.6212 - val_recall: 0.6212
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7293 - auc: 0.8481 - loss: 0.9340 - precision: 0.7476 - recall: 0.5953 - val_accuracy: 0.5758 - val_auc: 0.7148 - val_loss: 3.1683 - val_precision: 0.5758 - val_recall: 0.5758
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7721 - auc: 0.8913 - loss: 0.8569 - precision: 0.8117 - recall: 0.6824 - val_accuracy: 0.5909 - val_auc: 0.7370 - val_loss: 2.4837 - val_precision: 0.5846 - val_recall: 0.5758
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7809 - auc: 0.9006 - loss: 0.8137 - precision: 0.8007 - recall: 0.6877 - val_accuracy: 0.6364 - val_auc: 0.7605 - val_loss: 2.0819 - val_precision: 0.6308 - val_recall: 0.6212
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8000 - auc: 0.9180 - loss: 0.7642 - precision: 0.8502 - recall: 0.7302 - val_accuracy: 0.6364 - val_auc: 0.7903 - val_loss: 1.7460 - val_precision: 0.6308 - val_recall: 0.6212
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8299 - auc: 0.9439 - loss: 0.7055 - precision: 0.8602 - recall: 0.7698 - val_accuracy: 0.6364 - val_auc: 0.8127 - val_loss: 1.4919 - val_precision: 0.6462 - val_recall: 0.6364
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8373 - auc: 0.9586 - loss: 0.6595 - precision: 0.8958 - recall: 0.8063 - val_accuracy: 0.6667 - val_auc: 0.8281 - val_loss: 1.3153 - val_precision: 0.6875 - val_recall: 0.6667
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8481 - auc: 0.9573 - loss: 0.6412 - precision: 0.8781 - recall: 0.7954 - val_accuracy: 0.6818 - val_auc: 0.8509 - val_loss: 1.1802 - val_precision: 0.6875 - val_recall: 0.6667
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8760 - auc: 0.9692 - loss: 0.6063 - precision: 0.9252 - recall: 0.8346 - val_accuracy: 0.6970 - val_auc: 0.8660 - val_loss: 1.0614 - val_precision: 0.7077 - val_recall: 0.6970
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8524 - auc: 0.9656 - loss: 0.6212 - precision: 0.8864 - recall: 0.7922 - val_accuracy: 0.7727 - val_auc: 0.8760 - val_loss: 1.0134 - val_precision: 0.7812 - val_recall: 0.7576
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9190 - auc: 0.9830 - loss: 0.5538 - precision: 0.9367 - recall: 0.8661 - val_accuracy: 0.8030 - val_auc: 0.8826 - val_loss: 0.9945 - val_precision: 0.7969 - val_recall: 0.7727
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8856 - auc: 0.9712 - loss: 0.5683 - precision: 0.9095 - recall: 0.8704 - val_accuracy: 0.7576 - val_auc: 0.8828 - val_loss: 0.9754 - val_precision: 0.7937 - val_recall: 0.7576
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9018 - auc: 0.9793 - loss: 0.5299 - precision: 0.9319 - recall: 0.8949 - val_accuracy: 0.7424 - val_auc: 0.8778 - val_loss: 0.9600 - val_precision: 0.7385 - val_recall: 0.7273
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9177 - auc: 0.9894 - loss: 0.4679 - precision: 0.9368 - recall: 0.8926 - val_accuracy: 0.7424 - val_auc: 0.8728 - val_loss: 0.9652 - val_precision: 0.7385 - val_recall: 0.7273
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9323 - auc: 0.9844 - loss: 0.4841 - precision: 0.9540 - recall: 0.8806 - val_accuracy: 0.7273 - val_auc: 0.8756 - val_loss: 0.9579 - val_precision: 0.7500 - val_recall: 0.7273
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9110 - auc: 0.9878 - loss: 0.4733 - precision: 0.9312 - recall: 0.8746 - val_accuracy: 0.7424 - val_auc: 0.8824 - val_loss: 0.9232 - val_precision: 0.7538 - val_recall: 0.7424
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9355 - auc: 0.9886 - loss: 0.4621 - precision: 0.9553 - recall: 0.9051 - val_accuracy: 0.7576 - val_auc: 0.8911 - val_loss: 0.8697 - val_precision: 0.7812 - val_recall: 0.7576
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9425 - auc: 0.9906 - loss: 0.4460 - precision: 0.9574 - recall: 0.9236 - val_accuracy: 0.7576 - val_auc: 0.8996 - val_loss: 0.8240 - val_precision: 0.7812 - val_recall: 0.7576
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9299 - auc: 0.9913 - loss: 0.4205 - precision: 0.9417 - recall: 0.9130 - val_accuracy: 0.7273 - val_auc: 0.9069 - val_loss: 0.7748 - val_precision: 0.7385 - val_recall: 0.7273
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9508 - auc: 0.9948 - loss: 0.4209 - precision: 0.9723 - recall: 0.9190 - val_accuracy: 0.7121 - val_auc: 0.9137 - val_loss: 0.7440 - val_precision: 0.7581 - val_recall: 0.7121
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9195 - auc: 0.9895 - loss: 0.4426 - precision: 0.9416 - recall: 0.8881 - val_accuracy: 0.8030 - val_auc: 0.9207 - val_loss: 0.7216 - val_precision: 0.7937 - val_recall: 0.7576
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9676 - auc: 0.9981 - loss: 0.3772 - precision: 0.9810 - recall: 0.9423 - val_accuracy: 0.8182 - val_auc: 0.9137 - val_loss: 0.7503 - val_precision: 0.8281 - val_recall: 0.8030
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9580 - auc: 0.9915 - loss: 0.4000 - precision: 0.9627 - recall: 0.9404 - val_accuracy: 0.8182 - val_auc: 0.9179 - val_loss: 0.7299 - val_precision: 0.8182 - val_recall: 0.8182
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9464 - auc: 0.9921 - loss: 0.3895 - precision: 0.9552 - recall: 0.9399 - val_accuracy: 0.8182 - val_auc: 0.9197 - val_loss: 0.7168 - val_precision: 0.8182 - val_recall: 0.8182
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9517 - auc: 0.9955 - loss: 0.3770 - precision: 0.9658 - recall: 0.9269 - val_accuracy: 0.8030 - val_auc: 0.9175 - val_loss: 0.7294 - val_precision: 0.8000 - val_recall: 0.7879
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9665 - auc: 0.9982 - loss: 0.3367 - precision: 0.9780 - recall: 0.9539 - val_accuracy: 0.7879 - val_auc: 0.9097 - val_loss: 0.7770 - val_precision: 0.8125 - val_recall: 0.7879
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9727 - auc: 0.9982 - loss: 0.3291 - precision: 0.9768 - recall: 0.9616 - val_accuracy: 0.7727 - val_auc: 0.9048 - val_loss: 0.7980 - val_precision: 0.7969 - val_recall: 0.7727
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 710ms/step - accuracy: 0.5293 - auc: 0.6923 - loss: 1.2893 - precision: 0.5654 - recall: 0.4502 - val_accuracy: 0.7576 - val_auc: 0.8683 - val_loss: 1.5098 - val_precision: 0.7576 - val_recall: 0.7576
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6864 - auc: 0.8532 - loss: 0.9001 - precision: 0.7622 - recall: 0.6151 - val_accuracy: 0.7879 - val_auc: 0.9259 - val_loss: 0.9514 - val_precision: 0.8125 - val_recall: 0.7879
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7384 - auc: 0.8629 - loss: 0.8944 - precision: 0.7810 - recall: 0.6504 - val_accuracy: 0.7879 - val_auc: 0.9385 - val_loss: 0.7804 - val_precision: 0.8125 - val_recall: 0.7879
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7084 - auc: 0.8824 - loss: 0.8401 - precision: 0.7685 - recall: 0.6225 - val_accuracy: 0.7879 - val_auc: 0.9427 - val_loss: 0.7388 - val_precision: 0.8125 - val_recall: 0.7879
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7799 - auc: 0.9147 - loss: 0.7591 - precision: 0.8222 - recall: 0.7127 - val_accuracy: 0.7879 - val_auc: 0.9493 - val_loss: 0.6602 - val_precision: 0.8095 - val_recall: 0.7727
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7967 - auc: 0.9209 - loss: 0.7466 - precision: 0.8147 - recall: 0.6965 - val_accuracy: 0.8333 - val_auc: 0.9582 - val_loss: 0.5929 - val_precision: 0.8548 - val_recall: 0.8030
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7816 - auc: 0.9342 - loss: 0.7071 - precision: 0.8280 - recall: 0.7196 - val_accuracy: 0.8333 - val_auc: 0.9661 - val_loss: 0.5497 - val_precision: 0.8871 - val_recall: 0.8333
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8238 - auc: 0.9534 - loss: 0.6331 - precision: 0.8475 - recall: 0.7446 - val_accuracy: 0.8788 - val_auc: 0.9706 - val_loss: 0.5136 - val_precision: 0.8889 - val_recall: 0.8485
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8185 - auc: 0.9459 - loss: 0.6561 - precision: 0.8541 - recall: 0.7119 - val_accuracy: 0.8788 - val_auc: 0.9709 - val_loss: 0.5051 - val_precision: 0.8750 - val_recall: 0.8485
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8526 - auc: 0.9562 - loss: 0.6139 - precision: 0.8699 - recall: 0.7985 - val_accuracy: 0.8788 - val_auc: 0.9757 - val_loss: 0.4803 - val_precision: 0.9048 - val_recall: 0.8636
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8581 - auc: 0.9567 - loss: 0.6135 - precision: 0.8793 - recall: 0.8030 - val_accuracy: 0.9091 - val_auc: 0.9812 - val_loss: 0.4556 - val_precision: 0.9194 - val_recall: 0.8636
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8506 - auc: 0.9586 - loss: 0.5981 - precision: 0.8765 - recall: 0.7884 - val_accuracy: 0.9091 - val_auc: 0.9823 - val_loss: 0.4494 - val_precision: 0.9077 - val_recall: 0.8939
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8235 - auc: 0.9576 - loss: 0.5962 - precision: 0.8623 - recall: 0.7645 - val_accuracy: 0.9091 - val_auc: 0.9790 - val_loss: 0.4657 - val_precision: 0.9062 - val_recall: 0.8788
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8578 - auc: 0.9725 - loss: 0.5507 - precision: 0.8954 - recall: 0.8080 - val_accuracy: 0.8939 - val_auc: 0.9743 - val_loss: 0.4895 - val_precision: 0.9077 - val_recall: 0.8939
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8442 - auc: 0.9591 - loss: 0.5965 - precision: 0.8801 - recall: 0.7717 - val_accuracy: 0.8939 - val_auc: 0.9749 - val_loss: 0.4859 - val_precision: 0.8939 - val_recall: 0.8939
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step

# %%
# Summarize results
df = pd.DataFrame(results)
print(df.groupby("file")[["accuracy", "precision", "recall", "f1", "roc_auc"]].mean())

# Optional: plot AUC per file
df.groupby("file")["roc_auc"].mean().plot.bar(rot=45, figsize=(10, 5))
plt.title("Sequential Neural Network Cross-Validation Area Under Curve per File (mean over folds)")
plt.ylabel("AUC")
plt.tight_layout()
plt.show()
# Out:
#                                                     accuracy  precision  \
# file
# 221111_144114__binary_onlylines114378to117271 l...  0.803448   0.817364
# 221111_144114__binary_onlylines145900to148050 l...  0.805814   0.817863
# 221111_144114__binary_onlylines25660to28100 loe...  0.804082   0.821619
# 221111_144114__binary_onlylines47178to50517 loe...  0.862144   0.867619
# 221111_144114__binary_onlylines86841to90142 loe...  0.860968   0.868333
#
#                                                       recall        f1  \
# file
# 221111_144114__binary_onlylines114378to117271 l...  0.803448  0.805203
# 221111_144114__binary_onlylines145900to148050 l...  0.805814  0.802259
# 221111_144114__binary_onlylines25660to28100 loe...  0.804082  0.805125
# 221111_144114__binary_onlylines47178to50517 loe...  0.862144  0.857009
# 221111_144114__binary_onlylines86841to90142 loe...  0.860968  0.861138
#
#                                                      roc_auc
# file
# 221111_144114__binary_onlylines114378to117271 l...  0.919950
# 221111_144114__binary_onlylines145900to148050 l...  0.888288
# 221111_144114__binary_onlylines25660to28100 loe...  0.907839
# 221111_144114__binary_onlylines47178to50517 loe...  0.941717
# 221111_144114__binary_onlylines86841to90142 loe...  0.936610
# /tmp/ipykernel_6757/1605691262.py:9: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
# Show confusion matrix for each file (mean over folds)
from sklearn.metrics import ConfusionMatrixDisplay

for file in df["file"].unique():
    cms = [np.array(row) for row in df[df["file"] == file]["confusion_matrix"]]
    # Find the largest shape
    max_dim = max(cm.shape[0] for cm in cms)
    # Pad all confusion matrices to max_dim x max_dim
    padded = []
    for cm in cms:
        pad_width = ((0, max_dim - cm.shape[0]), (0, max_dim - cm.shape[1]))
        padded.append(np.pad(cm, pad_width, mode='constant'))
    mean_cm = np.mean(padded, axis=0)
    display_labels = [str(l) for l in range(max_dim)]
    fig, ax = plt.subplots(figsize=(4, 4))
    disp = ConfusionMatrixDisplay(mean_cm, display_labels=display_labels)
    disp.plot(ax=ax, cmap="Blues", colorbar=False)
    plt.title(f"Mean Confusion Matrix: {file}")
    plt.tight_layout()
    plt.show()

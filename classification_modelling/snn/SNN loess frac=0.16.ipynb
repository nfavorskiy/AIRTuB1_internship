# %% [markdown]
# # Sequential Neural Network
# In this notebook I will train a Sequential Neural Network for classification of erosion.

# %%
# Adjust the frac parameter for loess smoothing
# to control the degree of smoothing applied to the scan data.
labeled_dir = "../../scandata/slices loess frac=0.16_labeled"

masks_path = "../stratified_k-fold_masks.npy"

DetectionNotClassification = False  # Set to True to replace all non-zero labels with 1

# %% [markdown]
# Libraries used:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.metrics import AUC

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, roc_auc_score
)

from sklearn.preprocessing import StandardScaler

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# Use GPU if available
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
print("TensorFlow version:", tf.__version__)
# Out:
# 2025-08-18 16:22:14.301666: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-18 16:22:14.563702: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755534134.646477   78916 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755534134.671743   78916 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755534134.822943   78916 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755534134.822984   78916 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755534134.822985   78916 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755534134.822986   78916 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-18 16:22:14.831424: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Num GPUs Available: 1
# TensorFlow version: 2.19.0

# %%
all_masks = np.load(masks_path, allow_pickle=True)

# List all labeled files
labeled_files = [f for f in os.listdir(labeled_dir) if f.endswith("_slices_labeled.npy")]
selected_files = labeled_files  # Use all files by default

# %%
# Load features (X) and labels (y) for each file
all_X = []
all_y = []
for labeled_file in selected_files:
    data = np.load(os.path.join(labeled_dir, labeled_file), allow_pickle=True).item()
    slices = data["slices"]  # shape: (num_slices, max_points, 3)
    labels = data["labels"]  # shape: (num_slices,)

    X = slices[:, :, 2]  # shape: (num_slices, max_points)
    if DetectionNotClassification:
        y = (labels != 0).astype(int)
    else:
        y = labels  # keep original labels for multiclass
    all_X.append(X)
    all_y.append(y)

# %%
# Cross-validation using stratified k-Fold masks
n_folds = len(all_masks[0])
results = []

for file_idx, (X, y, masks) in enumerate(zip(all_X, all_y, all_masks)):
    file_results = []
    n_classes = len(np.unique(y))
    for fold_idx, val_mask in enumerate(masks):
        train_mask = ~val_mask
        X_train, y_train = X[train_mask], y[train_mask]
        X_val, y_val = X[val_mask], y[val_mask]

        # Scale using only the training data to prevent data leakage
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train)
        X_val_scaled = scaler.transform(X_val)

        # One-hot encode labels for keras if multiclass
        if len(np.unique(y_train)) > 2:
            # Create mapping from original labels to consecutive indices
            unique_labels = sorted(np.unique(y_train))
            label_to_idx = {label: idx for idx, label in enumerate(unique_labels)}
            idx_to_label = {idx: label for label, idx in label_to_idx.items()}
            
            # Map labels to consecutive indices
            y_train_mapped = np.array([label_to_idx[label] for label in y_train])
            y_val_mapped = np.array([label_to_idx[label] for label in y_val])
            
            n_classes = len(unique_labels)
            y_train_cat = keras.utils.to_categorical(y_train_mapped, num_classes=n_classes)
            y_val_cat = keras.utils.to_categorical(y_val_mapped, num_classes=n_classes)
            loss_fn = "categorical_crossentropy"
            activation = "softmax"
        else:
            y_train_cat = y_train
            y_val_cat = y_val
            n_classes = 2
            loss_fn = "binary_crossentropy"
            activation = "sigmoid"

        # Build model
        model = keras.Sequential()
        model.add(layers.Input(shape=(X_train.shape[1],)))
        model.add(layers.Dense(64, kernel_regularizer=keras.regularizers.l2(0.001)))
        model.add(layers.BatchNormalization())
        model.add(layers.LeakyReLU(negative_slope=0.01))
        model.add(layers.Dropout(0.3)) 
        model.add(layers.Dense(32, kernel_regularizer=keras.regularizers.l2(0.001)))
        model.add(layers.BatchNormalization())
        model.add(layers.LeakyReLU(negative_slope=0.01))
        model.add(layers.Dropout(0.3))  
        model.add(layers.Dense(n_classes if n_classes > 2 else 1, activation=activation))

        model.compile(
            optimizer=keras.optimizers.Adam(learning_rate=1e-3),
            loss=loss_fn,
            metrics=["accuracy", "precision", "recall", AUC(name='auc')]
        )

        # Train model with Early Stopping and Learning Rate Scheduling; store history
        history = model.fit(
            X_train_scaled, y_train_cat,
            epochs=50,
            batch_size=64,
            verbose=1,
            validation_data=(X_val_scaled, y_val_cat),
            callbacks = [
                EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True),
              # ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
            ]
        )

        # Plot learning curves for this fold
        plt.figure(figsize=(12, 4))
        
        # Plot loss
        plt.subplot(1, 2, 1)
        plt.plot(history.history['loss'], label='Training Loss')
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.title(f'Model Loss - File {file_idx}, Fold {fold_idx}')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()
        
        # Plot AUC
        plt.subplot(1, 2, 2)
        plt.plot(history.history['auc'], label='Training AUC')
        plt.plot(history.history['val_auc'], label='Validation AUC')
        plt.title(f'Model AUC - File {file_idx}, Fold {fold_idx}')
        plt.xlabel('Epoch')
        plt.ylabel('AUC')
        plt.legend()
        
        plt.tight_layout()
        plt.show()

        # Predict
        if n_classes > 2:
            y_pred_proba = model.predict(X_val_scaled)
            y_pred_idx = np.argmax(y_pred_proba, axis=1)
            # Map back to original labels
            y_pred_class = np.array([idx_to_label[idx] for idx in y_pred_idx])
        else:
            y_pred_proba = model.predict(X_val_scaled).flatten()
            y_pred_class = (y_pred_proba > 0.5).astype(int)

        # Metrics
        avg = 'weighted'
        try:
            if n_classes > 2:
                roc_auc = roc_auc_score(y_val, y_pred_proba, multi_class='ovr', average='weighted')
            else:
                roc_auc = roc_auc_score(y_val, y_pred_proba)
        except Exception:
            roc_auc = np.nan

        metrics = {
            "accuracy": accuracy_score(y_val, y_pred_class),
            "precision": precision_score(y_val, y_pred_class, average=avg, zero_division=0),
            "recall": recall_score(y_val, y_pred_class, average=avg, zero_division=0),
            "f1": f1_score(y_val, y_pred_class, average=avg, zero_division=0),
            "roc_auc": roc_auc,
            "confusion_matrix": confusion_matrix(y_val, y_pred_class, labels=sorted(np.unique(y))).tolist(),
            "fold": fold_idx,
            "file": selected_files[file_idx],
        }
        file_results.append(metrics)
    results.extend(file_results)
# Out:
# I0000 00:00:1755534144.334592   78916 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5563 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1755534146.204575   79150 service.cc:152] XLA service 0x7cad78010ed0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1755534146.204629   79150 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# 2025-08-18 16:22:26.256481: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1755534146.397055   79150 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 8s 3s/step - accuracy: 0.3125 - auc: 0.5167 - loss: 1.6767 - precision: 0.3333 - recall: 0.2500
# I0000 00:00:1755534147.968116   79150 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 764ms/step - accuracy: 0.4150 - auc: 0.6243 - loss: 1.4333 - precision: 0.4448 - recall: 0.3406 - val_accuracy: 0.6379 - val_auc: 0.8236 - val_loss: 2.3930 - val_precision: 0.6379 - val_recall: 0.6379
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6259 - auc: 0.8250 - loss: 0.9684 - precision: 0.6911 - recall: 0.5260 - val_accuracy: 0.7586 - val_auc: 0.8848 - val_loss: 1.4576 - val_precision: 0.7586 - val_recall: 0.7586
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6885 - auc: 0.8746 - loss: 0.8656 - precision: 0.7632 - recall: 0.5561 - val_accuracy: 0.7759 - val_auc: 0.9205 - val_loss: 1.1593 - val_precision: 0.8036 - val_recall: 0.7759
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7182 - auc: 0.8867 - loss: 0.8745 - precision: 0.8526 - recall: 0.6152 - val_accuracy: 0.7931 - val_auc: 0.9238 - val_loss: 1.0263 - val_precision: 0.8036 - val_recall: 0.7759
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8333 - auc: 0.9466 - loss: 0.7112 - precision: 0.8864 - recall: 0.7218 - val_accuracy: 0.8276 - val_auc: 0.9270 - val_loss: 0.9390 - val_precision: 0.8421 - val_recall: 0.8276
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8041 - auc: 0.9323 - loss: 0.7564 - precision: 0.8572 - recall: 0.6857 - val_accuracy: 0.8276 - val_auc: 0.9303 - val_loss: 0.8654 - val_precision: 0.8421 - val_recall: 0.8276
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8480 - auc: 0.9569 - loss: 0.6818 - precision: 0.9418 - recall: 0.7389 - val_accuracy: 0.8276 - val_auc: 0.9311 - val_loss: 0.8087 - val_precision: 0.8276 - val_recall: 0.8276
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8770 - auc: 0.9709 - loss: 0.6306 - precision: 0.9288 - recall: 0.7830 - val_accuracy: 0.8276 - val_auc: 0.9315 - val_loss: 0.7834 - val_precision: 0.8276 - val_recall: 0.8276
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8646 - auc: 0.9677 - loss: 0.6367 - precision: 0.9090 - recall: 0.8037 - val_accuracy: 0.8276 - val_auc: 0.9313 - val_loss: 0.7693 - val_precision: 0.8276 - val_recall: 0.8276
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8937 - auc: 0.9820 - loss: 0.5755 - precision: 0.9270 - recall: 0.8391 - val_accuracy: 0.8276 - val_auc: 0.9290 - val_loss: 0.7535 - val_precision: 0.8421 - val_recall: 0.8276
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9167 - auc: 0.9796 - loss: 0.5693 - precision: 0.9199 - recall: 0.8376 - val_accuracy: 0.8276 - val_auc: 0.9287 - val_loss: 0.7381 - val_precision: 0.8421 - val_recall: 0.8276
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9307 - auc: 0.9920 - loss: 0.5038 - precision: 0.9588 - recall: 0.8939 - val_accuracy: 0.8448 - val_auc: 0.9350 - val_loss: 0.7203 - val_precision: 0.8421 - val_recall: 0.8276
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9501 - auc: 0.9935 - loss: 0.4935 - precision: 0.9628 - recall: 0.9081 - val_accuracy: 0.8448 - val_auc: 0.9355 - val_loss: 0.7138 - val_precision: 0.8421 - val_recall: 0.8276
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9458 - auc: 0.9962 - loss: 0.4785 - precision: 0.9700 - recall: 0.8921 - val_accuracy: 0.8448 - val_auc: 0.9340 - val_loss: 0.7122 - val_precision: 0.8421 - val_recall: 0.8276
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9594 - auc: 0.9972 - loss: 0.4323 - precision: 0.9709 - recall: 0.9420 - val_accuracy: 0.8448 - val_auc: 0.9341 - val_loss: 0.7080 - val_precision: 0.8421 - val_recall: 0.8276
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9552 - auc: 0.9956 - loss: 0.4514 - precision: 0.9668 - recall: 0.9287 - val_accuracy: 0.8448 - val_auc: 0.9365 - val_loss: 0.6908 - val_precision: 0.8421 - val_recall: 0.8276
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9622 - auc: 0.9971 - loss: 0.4156 - precision: 0.9758 - recall: 0.9372 - val_accuracy: 0.8448 - val_auc: 0.9431 - val_loss: 0.6672 - val_precision: 0.8421 - val_recall: 0.8276
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9912 - auc: 0.9988 - loss: 0.4079 - precision: 0.9971 - recall: 0.9443 - val_accuracy: 0.8276 - val_auc: 0.9472 - val_loss: 0.6511 - val_precision: 0.8421 - val_recall: 0.8276
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9867 - auc: 0.9994 - loss: 0.3782 - precision: 0.9910 - recall: 0.9734 - val_accuracy: 0.8276 - val_auc: 0.9478 - val_loss: 0.6456 - val_precision: 0.8421 - val_recall: 0.8276
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9811 - auc: 0.9994 - loss: 0.3752 - precision: 0.9878 - recall: 0.9546 - val_accuracy: 0.8448 - val_auc: 0.9495 - val_loss: 0.6402 - val_precision: 0.8421 - val_recall: 0.8276
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9955 - auc: 0.9999 - loss: 0.3707 - precision: 0.9982 - recall: 0.9763 - val_accuracy: 0.8621 - val_auc: 0.9493 - val_loss: 0.6378 - val_precision: 0.8596 - val_recall: 0.8448
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9825 - auc: 0.9996 - loss: 0.3456 - precision: 0.9972 - recall: 0.9798 - val_accuracy: 0.8621 - val_auc: 0.9477 - val_loss: 0.6409 - val_precision: 0.8596 - val_recall: 0.8448
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9857 - auc: 0.9994 - loss: 0.3440 - precision: 0.9882 - recall: 0.9768 - val_accuracy: 0.8621 - val_auc: 0.9451 - val_loss: 0.6465 - val_precision: 0.8621 - val_recall: 0.8621
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9719 - auc: 0.9992 - loss: 0.3322 - precision: 0.9880 - recall: 0.9719 - val_accuracy: 0.8621 - val_auc: 0.9423 - val_loss: 0.6526 - val_precision: 0.8621 - val_recall: 0.8621
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 718ms/step - accuracy: 0.4216 - auc: 0.5607 - loss: 1.5812 - precision: 0.4648 - recall: 0.3698 - val_accuracy: 0.5517 - val_auc: 0.7015 - val_loss: 4.8708 - val_precision: 0.5517 - val_recall: 0.5517
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6177 - auc: 0.8020 - loss: 1.0108 - precision: 0.6642 - recall: 0.4953 - val_accuracy: 0.5690 - val_auc: 0.7541 - val_loss: 3.4906 - val_precision: 0.5690 - val_recall: 0.5690
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6930 - auc: 0.8678 - loss: 0.8956 - precision: 0.7716 - recall: 0.5871 - val_accuracy: 0.6207 - val_auc: 0.7699 - val_loss: 2.7117 - val_precision: 0.6207 - val_recall: 0.6207
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7458 - auc: 0.9116 - loss: 0.7989 - precision: 0.8118 - recall: 0.6517 - val_accuracy: 0.6552 - val_auc: 0.7849 - val_loss: 2.3490 - val_precision: 0.6552 - val_recall: 0.6552
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8029 - auc: 0.9399 - loss: 0.7291 - precision: 0.8707 - recall: 0.7369 - val_accuracy: 0.6552 - val_auc: 0.7966 - val_loss: 2.0863 - val_precision: 0.6667 - val_recall: 0.6552
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8064 - auc: 0.9390 - loss: 0.7225 - precision: 0.8617 - recall: 0.7054 - val_accuracy: 0.6897 - val_auc: 0.8017 - val_loss: 1.8758 - val_precision: 0.6909 - val_recall: 0.6552
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8627 - auc: 0.9668 - loss: 0.6454 - precision: 0.9144 - recall: 0.7661 - val_accuracy: 0.7241 - val_auc: 0.8181 - val_loss: 1.7174 - val_precision: 0.7222 - val_recall: 0.6724
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8562 - auc: 0.9690 - loss: 0.6450 - precision: 0.9144 - recall: 0.7561 - val_accuracy: 0.7414 - val_auc: 0.8277 - val_loss: 1.5749 - val_precision: 0.7455 - val_recall: 0.7069
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8875 - auc: 0.9730 - loss: 0.5910 - precision: 0.9342 - recall: 0.8376 - val_accuracy: 0.7241 - val_auc: 0.8288 - val_loss: 1.4458 - val_precision: 0.7273 - val_recall: 0.6897
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9232 - auc: 0.9862 - loss: 0.5624 - precision: 0.9564 - recall: 0.8302 - val_accuracy: 0.7414 - val_auc: 0.8332 - val_loss: 1.3477 - val_precision: 0.7547 - val_recall: 0.6897
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9416 - auc: 0.9862 - loss: 0.5464 - precision: 0.9510 - recall: 0.8524 - val_accuracy: 0.7586 - val_auc: 0.8453 - val_loss: 1.2651 - val_precision: 0.7547 - val_recall: 0.6897
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9429 - auc: 0.9902 - loss: 0.5159 - precision: 0.9678 - recall: 0.8904 - val_accuracy: 0.7414 - val_auc: 0.8463 - val_loss: 1.2004 - val_precision: 0.7636 - val_recall: 0.7241
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9126 - auc: 0.9894 - loss: 0.5097 - precision: 0.9700 - recall: 0.8609 - val_accuracy: 0.7241 - val_auc: 0.8508 - val_loss: 1.1577 - val_precision: 0.7500 - val_recall: 0.7241
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9628 - auc: 0.9955 - loss: 0.4605 - precision: 0.9642 - recall: 0.9257 - val_accuracy: 0.7241 - val_auc: 0.8530 - val_loss: 1.1206 - val_precision: 0.7321 - val_recall: 0.7069
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9857 - auc: 0.9990 - loss: 0.4207 - precision: 0.9925 - recall: 0.9358 - val_accuracy: 0.7241 - val_auc: 0.8567 - val_loss: 1.0862 - val_precision: 0.7321 - val_recall: 0.7069
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9889 - auc: 0.9990 - loss: 0.4131 - precision: 0.9915 - recall: 0.9595 - val_accuracy: 0.7241 - val_auc: 0.8605 - val_loss: 1.0500 - val_precision: 0.7321 - val_recall: 0.7069
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9763 - auc: 0.9988 - loss: 0.4045 - precision: 0.9903 - recall: 0.9425 - val_accuracy: 0.7414 - val_auc: 0.8659 - val_loss: 1.0276 - val_precision: 0.7593 - val_recall: 0.7069
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9827 - auc: 0.9990 - loss: 0.3934 - precision: 0.9923 - recall: 0.9579 - val_accuracy: 0.7586 - val_auc: 0.8691 - val_loss: 1.0063 - val_precision: 0.7547 - val_recall: 0.6897
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9929 - auc: 0.9998 - loss: 0.3547 - precision: 0.9972 - recall: 0.9858 - val_accuracy: 0.7586 - val_auc: 0.8718 - val_loss: 0.9891 - val_precision: 0.7455 - val_recall: 0.7069
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9837 - auc: 0.9993 - loss: 0.3555 - precision: 0.9877 - recall: 0.9596 - val_accuracy: 0.7586 - val_auc: 0.8736 - val_loss: 0.9818 - val_precision: 0.7500 - val_recall: 0.7241
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9764 - auc: 0.9983 - loss: 0.3515 - precision: 0.9806 - recall: 0.9721 - val_accuracy: 0.7414 - val_auc: 0.8714 - val_loss: 0.9858 - val_precision: 0.7500 - val_recall: 0.7241
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9796 - auc: 0.9994 - loss: 0.3459 - precision: 0.9794 - recall: 0.9721 - val_accuracy: 0.7586 - val_auc: 0.8708 - val_loss: 0.9819 - val_precision: 0.7544 - val_recall: 0.7414
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9855 - auc: 0.9996 - loss: 0.3425 - precision: 0.9928 - recall: 0.9709 - val_accuracy: 0.7586 - val_auc: 0.8725 - val_loss: 0.9628 - val_precision: 0.7544 - val_recall: 0.7414
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9808 - auc: 0.9995 - loss: 0.3293 - precision: 0.9881 - recall: 0.9764 - val_accuracy: 0.7414 - val_auc: 0.8758 - val_loss: 0.9503 - val_precision: 0.7544 - val_recall: 0.7414
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9851 - auc: 0.9998 - loss: 0.3249 - precision: 1.0000 - recall: 0.9603 - val_accuracy: 0.7414 - val_auc: 0.8783 - val_loss: 0.9334 - val_precision: 0.7414 - val_recall: 0.7414
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9898 - auc: 0.9997 - loss: 0.3085 - precision: 0.9972 - recall: 0.9898 - val_accuracy: 0.7414 - val_auc: 0.8841 - val_loss: 0.9163 - val_precision: 0.7414 - val_recall: 0.7414
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9955 - auc: 1.0000 - loss: 0.2797 - precision: 0.9983 - recall: 0.9927 - val_accuracy: 0.7241 - val_auc: 0.8863 - val_loss: 0.9082 - val_precision: 0.7368 - val_recall: 0.7241
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9837 - auc: 0.9999 - loss: 0.2798 - precision: 0.9911 - recall: 0.9837 - val_accuracy: 0.7241 - val_auc: 0.8875 - val_loss: 0.9076 - val_precision: 0.7241 - val_recall: 0.7241
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9983 - auc: 1.0000 - loss: 0.2701 - precision: 1.0000 - recall: 0.9908 - val_accuracy: 0.7414 - val_auc: 0.8863 - val_loss: 0.9063 - val_precision: 0.7544 - val_recall: 0.7414
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9939 - auc: 1.0000 - loss: 0.2595 - precision: 0.9983 - recall: 0.9939 - val_accuracy: 0.7586 - val_auc: 0.8892 - val_loss: 0.8877 - val_precision: 0.7544 - val_recall: 0.7414
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9925 - auc: 0.9999 - loss: 0.2559 - precision: 1.0000 - recall: 0.9898 - val_accuracy: 0.7586 - val_auc: 0.8957 - val_loss: 0.8634 - val_precision: 0.7544 - val_recall: 0.7414
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9957 - auc: 1.0000 - loss: 0.2430 - precision: 0.9957 - recall: 0.9929 - val_accuracy: 0.7586 - val_auc: 0.8974 - val_loss: 0.8597 - val_precision: 0.7679 - val_recall: 0.7414
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9983 - auc: 0.9996 - loss: 0.2614 - precision: 0.9983 - recall: 0.9881 - val_accuracy: 0.7586 - val_auc: 0.9001 - val_loss: 0.8595 - val_precision: 0.7778 - val_recall: 0.7241
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2280 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7586 - val_auc: 0.9006 - val_loss: 0.8573 - val_precision: 0.7679 - val_recall: 0.7414
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9966 - auc: 1.0000 - loss: 0.2331 - precision: 0.9983 - recall: 0.9938 - val_accuracy: 0.7586 - val_auc: 0.9016 - val_loss: 0.8602 - val_precision: 0.7679 - val_recall: 0.7414
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9939 - auc: 1.0000 - loss: 0.2374 - precision: 1.0000 - recall: 0.9922 - val_accuracy: 0.7586 - val_auc: 0.9026 - val_loss: 0.8505 - val_precision: 0.7679 - val_recall: 0.7414
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2279 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7759 - val_auc: 0.9058 - val_loss: 0.8277 - val_precision: 0.7857 - val_recall: 0.7586
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9957 - auc: 1.0000 - loss: 0.2193 - precision: 0.9957 - recall: 0.9957 - val_accuracy: 0.7759 - val_auc: 0.9086 - val_loss: 0.8107 - val_precision: 0.7857 - val_recall: 0.7586
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9908 - auc: 0.9998 - loss: 0.2405 - precision: 0.9908 - recall: 0.9908 - val_accuracy: 0.7414 - val_auc: 0.9107 - val_loss: 0.8057 - val_precision: 0.7679 - val_recall: 0.7414
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2049 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7414 - val_auc: 0.9158 - val_loss: 0.7964 - val_precision: 0.7414 - val_recall: 0.7414
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9972 - auc: 1.0000 - loss: 0.2148 - precision: 1.0000 - recall: 0.9972 - val_accuracy: 0.7414 - val_auc: 0.9139 - val_loss: 0.7989 - val_precision: 0.7414 - val_recall: 0.7414
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.1985 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7414 - val_auc: 0.9127 - val_loss: 0.7967 - val_precision: 0.7414 - val_recall: 0.7414
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9983 - auc: 1.0000 - loss: 0.1965 - precision: 0.9983 - recall: 0.9983 - val_accuracy: 0.7414 - val_auc: 0.9133 - val_loss: 0.8017 - val_precision: 0.7679 - val_recall: 0.7414
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 736ms/step - accuracy: 0.4327 - auc: 0.6314 - loss: 1.2867 - precision: 0.4538 - recall: 0.3001 - val_accuracy: 0.6207 - val_auc: 0.8266 - val_loss: 2.1845 - val_precision: 0.6207 - val_recall: 0.6207
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6804 - auc: 0.8450 - loss: 0.9337 - precision: 0.7517 - recall: 0.5982 - val_accuracy: 0.6724 - val_auc: 0.8542 - val_loss: 1.6233 - val_precision: 0.6667 - val_recall: 0.6552
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7555 - auc: 0.9039 - loss: 0.8163 - precision: 0.8349 - recall: 0.6462 - val_accuracy: 0.7241 - val_auc: 0.8757 - val_loss: 1.2784 - val_precision: 0.7241 - val_recall: 0.7241
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7952 - auc: 0.9219 - loss: 0.7717 - precision: 0.8430 - recall: 0.6758 - val_accuracy: 0.7759 - val_auc: 0.8989 - val_loss: 1.0818 - val_precision: 0.7759 - val_recall: 0.7759
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7846 - auc: 0.9336 - loss: 0.7400 - precision: 0.8386 - recall: 0.7054 - val_accuracy: 0.7586 - val_auc: 0.9053 - val_loss: 0.9553 - val_precision: 0.7586 - val_recall: 0.7586
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8130 - auc: 0.9391 - loss: 0.7273 - precision: 0.8551 - recall: 0.7433 - val_accuracy: 0.7759 - val_auc: 0.9191 - val_loss: 0.8677 - val_precision: 0.7759 - val_recall: 0.7759
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8397 - auc: 0.9667 - loss: 0.6603 - precision: 0.9064 - recall: 0.7732 - val_accuracy: 0.7759 - val_auc: 0.9270 - val_loss: 0.8021 - val_precision: 0.7759 - val_recall: 0.7759
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8873 - auc: 0.9677 - loss: 0.6557 - precision: 0.9110 - recall: 0.7680 - val_accuracy: 0.7931 - val_auc: 0.9333 - val_loss: 0.7624 - val_precision: 0.7931 - val_recall: 0.7931
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8431 - auc: 0.9666 - loss: 0.6324 - precision: 0.8797 - recall: 0.8005 - val_accuracy: 0.7931 - val_auc: 0.9357 - val_loss: 0.7366 - val_precision: 0.7931 - val_recall: 0.7931
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9008 - auc: 0.9839 - loss: 0.5798 - precision: 0.9267 - recall: 0.8442 - val_accuracy: 0.7931 - val_auc: 0.9354 - val_loss: 0.7243 - val_precision: 0.8070 - val_recall: 0.7931
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9115 - auc: 0.9885 - loss: 0.5343 - precision: 0.9578 - recall: 0.8449 - val_accuracy: 0.8276 - val_auc: 0.9376 - val_loss: 0.7081 - val_precision: 0.8246 - val_recall: 0.8103
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9293 - auc: 0.9886 - loss: 0.5329 - precision: 0.9367 - recall: 0.8533 - val_accuracy: 0.8276 - val_auc: 0.9402 - val_loss: 0.6935 - val_precision: 0.8421 - val_recall: 0.8276
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9628 - auc: 0.9962 - loss: 0.4675 - precision: 0.9730 - recall: 0.9234 - val_accuracy: 0.8276 - val_auc: 0.9408 - val_loss: 0.6852 - val_precision: 0.8393 - val_recall: 0.8103
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9629 - auc: 0.9950 - loss: 0.4795 - precision: 0.9715 - recall: 0.9205 - val_accuracy: 0.8276 - val_auc: 0.9388 - val_loss: 0.6830 - val_precision: 0.8393 - val_recall: 0.8103
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9541 - auc: 0.9957 - loss: 0.4665 - precision: 0.9856 - recall: 0.9351 - val_accuracy: 0.8103 - val_auc: 0.9385 - val_loss: 0.6732 - val_precision: 0.8545 - val_recall: 0.8103
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9798 - auc: 0.9994 - loss: 0.4077 - precision: 0.9884 - recall: 0.9735 - val_accuracy: 0.8276 - val_auc: 0.9409 - val_loss: 0.6635 - val_precision: 0.8393 - val_recall: 0.8103
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9789 - auc: 0.9991 - loss: 0.3932 - precision: 0.9887 - recall: 0.9569 - val_accuracy: 0.8103 - val_auc: 0.9424 - val_loss: 0.6614 - val_precision: 0.8364 - val_recall: 0.7931
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9780 - auc: 0.9992 - loss: 0.3768 - precision: 0.9879 - recall: 0.9645 - val_accuracy: 0.8103 - val_auc: 0.9390 - val_loss: 0.6791 - val_precision: 0.8214 - val_recall: 0.7931
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9925 - auc: 0.9999 - loss: 0.3577 - precision: 1.0000 - recall: 0.9790 - val_accuracy: 0.8103 - val_auc: 0.9304 - val_loss: 0.7008 - val_precision: 0.8364 - val_recall: 0.7931
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.3335 - precision: 1.0000 - recall: 0.9882 - val_accuracy: 0.8103 - val_auc: 0.9307 - val_loss: 0.7052 - val_precision: 0.8214 - val_recall: 0.7931
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7cae6d7b27a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/stepWARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7cae6d7b27a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 707ms/step - accuracy: 0.5298 - auc: 0.7191 - loss: 1.1809 - precision: 0.5507 - recall: 0.4072 - val_accuracy: 0.6034 - val_auc: 0.8207 - val_loss: 1.9670 - val_precision: 0.6140 - val_recall: 0.6034
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6894 - auc: 0.8542 - loss: 0.9029 - precision: 0.7660 - recall: 0.5973 - val_accuracy: 0.7241 - val_auc: 0.8773 - val_loss: 1.3371 - val_precision: 0.7321 - val_recall: 0.7069
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8033 - auc: 0.9106 - loss: 0.7804 - precision: 0.8304 - recall: 0.6861 - val_accuracy: 0.7586 - val_auc: 0.9130 - val_loss: 0.9928 - val_precision: 0.7636 - val_recall: 0.7241
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8061 - auc: 0.9308 - loss: 0.7335 - precision: 0.8469 - recall: 0.7270 - val_accuracy: 0.7931 - val_auc: 0.9282 - val_loss: 0.8388 - val_precision: 0.8000 - val_recall: 0.7586
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7712 - auc: 0.9291 - loss: 0.7470 - precision: 0.8639 - recall: 0.7168 - val_accuracy: 0.7931 - val_auc: 0.9315 - val_loss: 0.7583 - val_precision: 0.8182 - val_recall: 0.7759
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8345 - auc: 0.9582 - loss: 0.6508 - precision: 0.8969 - recall: 0.8049 - val_accuracy: 0.7931 - val_auc: 0.9408 - val_loss: 0.7127 - val_precision: 0.8364 - val_recall: 0.7931
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8691 - auc: 0.9676 - loss: 0.6167 - precision: 0.8983 - recall: 0.8215 - val_accuracy: 0.8103 - val_auc: 0.9493 - val_loss: 0.6865 - val_precision: 0.8214 - val_recall: 0.7931
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8412 - auc: 0.9623 - loss: 0.6352 - precision: 0.9070 - recall: 0.8324 - val_accuracy: 0.8448 - val_auc: 0.9505 - val_loss: 0.6722 - val_precision: 0.8596 - val_recall: 0.8448
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8975 - auc: 0.9866 - loss: 0.5624 - precision: 0.9412 - recall: 0.8315 - val_accuracy: 0.8448 - val_auc: 0.9513 - val_loss: 0.6528 - val_precision: 0.8596 - val_recall: 0.8448
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8951 - auc: 0.9844 - loss: 0.5378 - precision: 0.9205 - recall: 0.8607 - val_accuracy: 0.8448 - val_auc: 0.9547 - val_loss: 0.6362 - val_precision: 0.8421 - val_recall: 0.8276
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9344 - auc: 0.9909 - loss: 0.5097 - precision: 0.9553 - recall: 0.9036 - val_accuracy: 0.8276 - val_auc: 0.9556 - val_loss: 0.6300 - val_precision: 0.8421 - val_recall: 0.8276
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9524 - auc: 0.9942 - loss: 0.4704 - precision: 0.9655 - recall: 0.9247 - val_accuracy: 0.8276 - val_auc: 0.9545 - val_loss: 0.6289 - val_precision: 0.8571 - val_recall: 0.8276
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9384 - auc: 0.9941 - loss: 0.4629 - precision: 0.9665 - recall: 0.9060 - val_accuracy: 0.8621 - val_auc: 0.9574 - val_loss: 0.6161 - val_precision: 0.8929 - val_recall: 0.8621
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9688 - auc: 0.9980 - loss: 0.4373 - precision: 0.9827 - recall: 0.9262 - val_accuracy: 0.8621 - val_auc: 0.9603 - val_loss: 0.6017 - val_precision: 0.8889 - val_recall: 0.8276
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9735 - auc: 0.9979 - loss: 0.4143 - precision: 0.9850 - recall: 0.9652 - val_accuracy: 0.8621 - val_auc: 0.9612 - val_loss: 0.5891 - val_precision: 0.8889 - val_recall: 0.8276
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9621 - auc: 0.9962 - loss: 0.4073 - precision: 0.9670 - recall: 0.9498 - val_accuracy: 0.8621 - val_auc: 0.9637 - val_loss: 0.5733 - val_precision: 0.8868 - val_recall: 0.8103
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9761 - auc: 0.9968 - loss: 0.3889 - precision: 0.9861 - recall: 0.9545 - val_accuracy: 0.8621 - val_auc: 0.9637 - val_loss: 0.5731 - val_precision: 0.8727 - val_recall: 0.8276
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9600 - auc: 0.9985 - loss: 0.3571 - precision: 0.9712 - recall: 0.9526 - val_accuracy: 0.8448 - val_auc: 0.9631 - val_loss: 0.5782 - val_precision: 0.8727 - val_recall: 0.8276
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9929 - auc: 0.9999 - loss: 0.3401 - precision: 0.9956 - recall: 0.9855 - val_accuracy: 0.8793 - val_auc: 0.9645 - val_loss: 0.5725 - val_precision: 0.8704 - val_recall: 0.8103
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9972 - auc: 1.0000 - loss: 0.3362 - precision: 0.9972 - recall: 0.9972 - val_accuracy: 0.8621 - val_auc: 0.9651 - val_loss: 0.5679 - val_precision: 0.8596 - val_recall: 0.8448
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9972 - auc: 1.0000 - loss: 0.3232 - precision: 0.9972 - recall: 0.9901 - val_accuracy: 0.8621 - val_auc: 0.9657 - val_loss: 0.5636 - val_precision: 0.8596 - val_recall: 0.8448
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - auc: 0.9999 - loss: 0.3285 - precision: 1.0000 - recall: 0.9747 - val_accuracy: 0.8448 - val_auc: 0.9644 - val_loss: 0.5643 - val_precision: 0.8596 - val_recall: 0.8448
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9925 - auc: 0.9999 - loss: 0.3008 - precision: 1.0000 - recall: 0.9898 - val_accuracy: 0.8621 - val_auc: 0.9664 - val_loss: 0.5627 - val_precision: 0.8727 - val_recall: 0.8276
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9922 - auc: 0.9998 - loss: 0.2892 - precision: 0.9938 - recall: 0.9806 - val_accuracy: 0.8448 - val_auc: 0.9672 - val_loss: 0.5592 - val_precision: 0.8750 - val_recall: 0.8448
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9870 - auc: 0.9994 - loss: 0.2958 - precision: 0.9913 - recall: 0.9842 - val_accuracy: 0.8448 - val_auc: 0.9670 - val_loss: 0.5596 - val_precision: 0.8571 - val_recall: 0.8276
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9972 - auc: 0.9999 - loss: 0.3024 - precision: 0.9972 - recall: 0.9799 - val_accuracy: 0.8276 - val_auc: 0.9668 - val_loss: 0.5548 - val_precision: 0.8545 - val_recall: 0.8103
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2748 - precision: 1.0000 - recall: 0.9929 - val_accuracy: 0.8276 - val_auc: 0.9647 - val_loss: 0.5583 - val_precision: 0.8246 - val_recall: 0.8103
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9925 - auc: 1.0000 - loss: 0.2654 - precision: 1.0000 - recall: 0.9882 - val_accuracy: 0.8103 - val_auc: 0.9643 - val_loss: 0.5625 - val_precision: 0.8103 - val_recall: 0.8103
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9972 - auc: 0.9999 - loss: 0.2625 - precision: 0.9972 - recall: 0.9898 - val_accuracy: 0.8103 - val_auc: 0.9634 - val_loss: 0.5649 - val_precision: 0.8103 - val_recall: 0.8103
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 710ms/step - accuracy: 0.3690 - auc: 0.5545 - loss: 1.4862 - precision: 0.3684 - recall: 0.2731 - val_accuracy: 0.6207 - val_auc: 0.7444 - val_loss: 5.4056 - val_precision: 0.6207 - val_recall: 0.6207
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.5561 - auc: 0.7658 - loss: 1.1304 - precision: 0.6711 - recall: 0.4917 - val_accuracy: 0.6552 - val_auc: 0.7745 - val_loss: 3.9680 - val_precision: 0.6552 - val_recall: 0.6552
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5990 - auc: 0.7927 - loss: 1.0483 - precision: 0.7137 - recall: 0.4917 - val_accuracy: 0.6897 - val_auc: 0.7953 - val_loss: 2.9494 - val_precision: 0.7018 - val_recall: 0.6897
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7033 - auc: 0.8754 - loss: 0.8902 - precision: 0.8153 - recall: 0.6050 - val_accuracy: 0.6897 - val_auc: 0.8167 - val_loss: 2.3693 - val_precision: 0.7091 - val_recall: 0.6724
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7117 - auc: 0.8647 - loss: 0.9246 - precision: 0.8084 - recall: 0.5507 - val_accuracy: 0.6724 - val_auc: 0.8383 - val_loss: 1.9769 - val_precision: 0.7222 - val_recall: 0.6724
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7323 - auc: 0.9028 - loss: 0.8354 - precision: 0.8258 - recall: 0.6035 - val_accuracy: 0.7069 - val_auc: 0.8533 - val_loss: 1.7154 - val_precision: 0.7222 - val_recall: 0.6724
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7718 - auc: 0.9206 - loss: 0.7927 - precision: 0.8821 - recall: 0.6366 - val_accuracy: 0.7241 - val_auc: 0.8622 - val_loss: 1.5465 - val_precision: 0.7455 - val_recall: 0.7069
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8077 - auc: 0.9458 - loss: 0.7334 - precision: 0.8773 - recall: 0.6797 - val_accuracy: 0.7414 - val_auc: 0.8674 - val_loss: 1.4349 - val_precision: 0.7455 - val_recall: 0.7069
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8624 - auc: 0.9577 - loss: 0.7067 - precision: 0.9333 - recall: 0.7163 - val_accuracy: 0.7586 - val_auc: 0.8743 - val_loss: 1.3419 - val_precision: 0.7593 - val_recall: 0.7069
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8660 - auc: 0.9643 - loss: 0.6717 - precision: 0.9282 - recall: 0.7630 - val_accuracy: 0.7586 - val_auc: 0.8822 - val_loss: 1.2666 - val_precision: 0.8148 - val_recall: 0.7586
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8845 - auc: 0.9692 - loss: 0.6637 - precision: 0.9410 - recall: 0.7505 - val_accuracy: 0.7759 - val_auc: 0.8870 - val_loss: 1.2103 - val_precision: 0.8113 - val_recall: 0.7414
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8494 - auc: 0.9574 - loss: 0.6905 - precision: 0.9166 - recall: 0.7789 - val_accuracy: 0.7759 - val_auc: 0.8890 - val_loss: 1.1692 - val_precision: 0.8113 - val_recall: 0.7414
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8850 - auc: 0.9834 - loss: 0.6018 - precision: 0.9492 - recall: 0.8087 - val_accuracy: 0.7931 - val_auc: 0.8986 - val_loss: 1.1020 - val_precision: 0.8148 - val_recall: 0.7586
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9003 - auc: 0.9848 - loss: 0.5773 - precision: 0.9491 - recall: 0.8494 - val_accuracy: 0.7931 - val_auc: 0.9039 - val_loss: 1.0451 - val_precision: 0.8182 - val_recall: 0.7759
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8878 - auc: 0.9788 - loss: 0.5848 - precision: 0.9311 - recall: 0.8045 - val_accuracy: 0.7931 - val_auc: 0.9066 - val_loss: 1.0102 - val_precision: 0.8182 - val_recall: 0.7759
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9242 - auc: 0.9917 - loss: 0.5348 - precision: 0.9576 - recall: 0.8522 - val_accuracy: 0.7931 - val_auc: 0.9083 - val_loss: 0.9855 - val_precision: 0.8333 - val_recall: 0.7759
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9118 - auc: 0.9853 - loss: 0.5367 - precision: 0.9527 - recall: 0.8595 - val_accuracy: 0.7931 - val_auc: 0.9065 - val_loss: 0.9761 - val_precision: 0.8333 - val_recall: 0.7759
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9507 - auc: 0.9964 - loss: 0.4829 - precision: 0.9912 - recall: 0.8880 - val_accuracy: 0.7931 - val_auc: 0.9054 - val_loss: 0.9653 - val_precision: 0.8333 - val_recall: 0.7759
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9318 - auc: 0.9908 - loss: 0.4769 - precision: 0.9588 - recall: 0.9027 - val_accuracy: 0.7931 - val_auc: 0.9084 - val_loss: 0.9439 - val_precision: 0.8431 - val_recall: 0.7414
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9654 - auc: 0.9972 - loss: 0.4576 - precision: 0.9757 - recall: 0.9141 - val_accuracy: 0.7931 - val_auc: 0.9130 - val_loss: 0.9230 - val_precision: 0.8462 - val_recall: 0.7586
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9739 - auc: 0.9972 - loss: 0.4379 - precision: 0.9800 - recall: 0.9349 - val_accuracy: 0.7931 - val_auc: 0.9150 - val_loss: 0.9020 - val_precision: 0.8491 - val_recall: 0.7759
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9580 - auc: 0.9966 - loss: 0.4498 - precision: 0.9801 - recall: 0.8774 - val_accuracy: 0.7931 - val_auc: 0.9159 - val_loss: 0.8854 - val_precision: 0.8333 - val_recall: 0.7759
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9707 - auc: 0.9992 - loss: 0.3971 - precision: 0.9803 - recall: 0.9645 - val_accuracy: 0.7931 - val_auc: 0.9154 - val_loss: 0.8693 - val_precision: 0.8182 - val_recall: 0.7759
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9676 - auc: 0.9978 - loss: 0.4021 - precision: 0.9861 - recall: 0.9578 - val_accuracy: 0.7931 - val_auc: 0.9158 - val_loss: 0.8565 - val_precision: 0.8182 - val_recall: 0.7759
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9808 - auc: 0.9991 - loss: 0.3758 - precision: 0.9923 - recall: 0.9622 - val_accuracy: 0.7931 - val_auc: 0.9171 - val_loss: 0.8413 - val_precision: 0.8333 - val_recall: 0.7759
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9834 - auc: 0.9987 - loss: 0.3682 - precision: 0.9905 - recall: 0.9640 - val_accuracy: 0.8103 - val_auc: 0.9197 - val_loss: 0.8240 - val_precision: 0.8491 - val_recall: 0.7759
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9780 - auc: 0.9983 - loss: 0.3796 - precision: 0.9767 - recall: 0.9288 - val_accuracy: 0.8103 - val_auc: 0.9206 - val_loss: 0.8137 - val_precision: 0.8333 - val_recall: 0.7759
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9925 - auc: 0.9998 - loss: 0.3383 - precision: 1.0000 - recall: 0.9742 - val_accuracy: 0.8103 - val_auc: 0.9222 - val_loss: 0.8039 - val_precision: 0.8364 - val_recall: 0.7931
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9957 - auc: 1.0000 - loss: 0.3424 - precision: 1.0000 - recall: 0.9855 - val_accuracy: 0.8103 - val_auc: 0.9229 - val_loss: 0.7952 - val_precision: 0.8364 - val_recall: 0.7931
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9957 - auc: 1.0000 - loss: 0.2960 - precision: 1.0000 - recall: 0.9874 - val_accuracy: 0.7931 - val_auc: 0.9244 - val_loss: 0.7834 - val_precision: 0.8364 - val_recall: 0.7931
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9870 - auc: 0.9995 - loss: 0.3233 - precision: 0.9896 - recall: 0.9751 - val_accuracy: 0.8103 - val_auc: 0.9261 - val_loss: 0.7688 - val_precision: 0.8519 - val_recall: 0.7931
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9929 - auc: 0.9999 - loss: 0.3001 - precision: 1.0000 - recall: 0.9827 - val_accuracy: 0.8448 - val_auc: 0.9290 - val_loss: 0.7540 - val_precision: 0.8679 - val_recall: 0.7931
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9895 - auc: 0.9999 - loss: 0.2885 - precision: 0.9954 - recall: 0.9808 - val_accuracy: 0.8621 - val_auc: 0.9287 - val_loss: 0.7426 - val_precision: 0.8679 - val_recall: 0.7931
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9972 - auc: 0.9999 - loss: 0.2937 - precision: 0.9972 - recall: 0.9870 - val_accuracy: 0.8621 - val_auc: 0.9296 - val_loss: 0.7335 - val_precision: 0.8704 - val_recall: 0.8103
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9891 - auc: 0.9999 - loss: 0.2828 - precision: 0.9983 - recall: 0.9891 - val_accuracy: 0.8448 - val_auc: 0.9310 - val_loss: 0.7242 - val_precision: 0.8704 - val_recall: 0.8103
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9908 - auc: 0.9998 - loss: 0.2805 - precision: 1.0000 - recall: 0.9891 - val_accuracy: 0.8448 - val_auc: 0.9319 - val_loss: 0.7189 - val_precision: 0.8545 - val_recall: 0.8103
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9733 - auc: 0.9990 - loss: 0.2862 - precision: 0.9806 - recall: 0.9716 - val_accuracy: 0.7931 - val_auc: 0.9296 - val_loss: 0.7105 - val_precision: 0.8364 - val_recall: 0.7931
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9869 - auc: 0.9998 - loss: 0.2594 - precision: 0.9954 - recall: 0.9841 - val_accuracy: 0.7931 - val_auc: 0.9285 - val_loss: 0.7043 - val_precision: 0.8182 - val_recall: 0.7759
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9945 - auc: 1.0000 - loss: 0.2353 - precision: 1.0000 - recall: 0.9945 - val_accuracy: 0.7759 - val_auc: 0.9290 - val_loss: 0.6924 - val_precision: 0.8182 - val_recall: 0.7759
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2351 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7931 - val_auc: 0.9294 - val_loss: 0.6754 - val_precision: 0.8182 - val_recall: 0.7759
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2435 - precision: 1.0000 - recall: 0.9925 - val_accuracy: 0.7931 - val_auc: 0.9310 - val_loss: 0.6565 - val_precision: 0.8364 - val_recall: 0.7931
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9939 - auc: 0.9999 - loss: 0.2359 - precision: 1.0000 - recall: 0.9922 - val_accuracy: 0.8103 - val_auc: 0.9340 - val_loss: 0.6420 - val_precision: 0.8519 - val_recall: 0.7931
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2348 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8276 - val_auc: 0.9347 - val_loss: 0.6439 - val_precision: 0.8364 - val_recall: 0.7931
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2104 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8276 - val_auc: 0.9354 - val_loss: 0.6405 - val_precision: 0.8364 - val_recall: 0.7931
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2064 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.8276 - val_auc: 0.9371 - val_loss: 0.6328 - val_precision: 0.8679 - val_recall: 0.7931
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.2075 - precision: 1.0000 - recall: 0.9898 - val_accuracy: 0.8621 - val_auc: 0.9371 - val_loss: 0.6243 - val_precision: 0.8727 - val_recall: 0.8276
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9925 - auc: 0.9999 - loss: 0.2078 - precision: 0.9925 - recall: 0.9925 - val_accuracy: 0.8621 - val_auc: 0.9369 - val_loss: 0.6240 - val_precision: 0.8727 - val_recall: 0.8276
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9945 - auc: 0.9998 - loss: 0.2122 - precision: 0.9972 - recall: 0.9901 - val_accuracy: 0.8448 - val_auc: 0.9365 - val_loss: 0.6198 - val_precision: 0.8727 - val_recall: 0.8276
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.1918 - precision: 1.0000 - recall: 0.9972 - val_accuracy: 0.8448 - val_auc: 0.9364 - val_loss: 0.6182 - val_precision: 0.8727 - val_recall: 0.8276
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9839 - auc: 0.9998 - loss: 0.2030 - precision: 0.9925 - recall: 0.9784 - val_accuracy: 0.8276 - val_auc: 0.9344 - val_loss: 0.6260 - val_precision: 0.8421 - val_recall: 0.8276
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.5300 - auc: 0.6972 - loss: 1.1954 - precision: 0.5181 - recall: 0.3587 - val_accuracy: 0.6136 - val_auc: 0.7756 - val_loss: 2.8197 - val_precision: 0.6136 - val_recall: 0.6136
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7218 - auc: 0.8484 - loss: 0.9237 - precision: 0.7595 - recall: 0.6450 - val_accuracy: 0.5909 - val_auc: 0.7890 - val_loss: 2.6640 - val_precision: 0.5909 - val_recall: 0.5909
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7889 - auc: 0.9113 - loss: 0.7685 - precision: 0.8062 - recall: 0.7228 - val_accuracy: 0.6136 - val_auc: 0.7958 - val_loss: 2.2568 - val_precision: 0.6136 - val_recall: 0.6136
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7198 - auc: 0.8948 - loss: 0.8238 - precision: 0.7874 - recall: 0.6205 - val_accuracy: 0.6136 - val_auc: 0.7927 - val_loss: 1.9126 - val_precision: 0.6190 - val_recall: 0.5909
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7986 - auc: 0.9361 - loss: 0.7089 - precision: 0.8436 - recall: 0.7393 - val_accuracy: 0.6364 - val_auc: 0.7912 - val_loss: 1.6542 - val_precision: 0.6429 - val_recall: 0.6136
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8657 - auc: 0.9647 - loss: 0.6444 - precision: 0.8964 - recall: 0.7918 - val_accuracy: 0.6136 - val_auc: 0.7969 - val_loss: 1.4528 - val_precision: 0.6429 - val_recall: 0.6136
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8910 - auc: 0.9677 - loss: 0.6048 - precision: 0.9299 - recall: 0.8132 - val_accuracy: 0.6136 - val_auc: 0.8239 - val_loss: 1.3003 - val_precision: 0.6429 - val_recall: 0.6136
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8463 - auc: 0.9631 - loss: 0.6278 - precision: 0.8974 - recall: 0.8346 - val_accuracy: 0.6136 - val_auc: 0.8438 - val_loss: 1.1816 - val_precision: 0.6585 - val_recall: 0.6136
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9125 - auc: 0.9744 - loss: 0.5845 - precision: 0.9260 - recall: 0.8745 - val_accuracy: 0.6591 - val_auc: 0.8658 - val_loss: 1.0998 - val_precision: 0.6829 - val_recall: 0.6364
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9261 - auc: 0.9904 - loss: 0.5266 - precision: 0.9444 - recall: 0.8920 - val_accuracy: 0.7045 - val_auc: 0.8742 - val_loss: 1.0471 - val_precision: 0.6905 - val_recall: 0.6591
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9241 - auc: 0.9870 - loss: 0.5141 - precision: 0.9242 - recall: 0.8891 - val_accuracy: 0.7045 - val_auc: 0.8789 - val_loss: 1.0073 - val_precision: 0.6905 - val_recall: 0.6591
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9183 - auc: 0.9905 - loss: 0.4835 - precision: 0.9462 - recall: 0.8725 - val_accuracy: 0.6818 - val_auc: 0.8824 - val_loss: 0.9772 - val_precision: 0.6905 - val_recall: 0.6591
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9435 - auc: 0.9960 - loss: 0.4542 - precision: 0.9712 - recall: 0.9192 - val_accuracy: 0.6818 - val_auc: 0.8842 - val_loss: 0.9573 - val_precision: 0.6905 - val_recall: 0.6591
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9474 - auc: 0.9965 - loss: 0.4537 - precision: 0.9729 - recall: 0.9124 - val_accuracy: 0.6818 - val_auc: 0.8830 - val_loss: 0.9415 - val_precision: 0.6905 - val_recall: 0.6591
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9484 - auc: 0.9913 - loss: 0.4589 - precision: 0.9698 - recall: 0.9076 - val_accuracy: 0.6818 - val_auc: 0.8833 - val_loss: 0.9464 - val_precision: 0.6905 - val_recall: 0.6591
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9747 - auc: 0.9974 - loss: 0.4010 - precision: 0.9769 - recall: 0.9455 - val_accuracy: 0.6818 - val_auc: 0.8804 - val_loss: 0.9510 - val_precision: 0.6905 - val_recall: 0.6591
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9611 - auc: 0.9981 - loss: 0.3882 - precision: 0.9750 - recall: 0.9475 - val_accuracy: 0.7045 - val_auc: 0.8794 - val_loss: 0.9556 - val_precision: 0.6905 - val_recall: 0.6591
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.3993 - auc: 0.5685 - loss: 1.4439 - precision: 0.4282 - recall: 0.2897 - val_accuracy: 0.6047 - val_auc: 0.7650 - val_loss: 3.0836 - val_precision: 0.6047 - val_recall: 0.6047
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6024 - auc: 0.7834 - loss: 1.0760 - precision: 0.6624 - recall: 0.4520 - val_accuracy: 0.6047 - val_auc: 0.7949 - val_loss: 2.9515 - val_precision: 0.6047 - val_recall: 0.6047
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7238 - auc: 0.8674 - loss: 0.8701 - precision: 0.7792 - recall: 0.6094 - val_accuracy: 0.6047 - val_auc: 0.7992 - val_loss: 2.6000 - val_precision: 0.6047 - val_recall: 0.6047
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6964 - auc: 0.8692 - loss: 0.8867 - precision: 0.7859 - recall: 0.6227 - val_accuracy: 0.6047 - val_auc: 0.7968 - val_loss: 2.2580 - val_precision: 0.6047 - val_recall: 0.6047
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7362 - auc: 0.8964 - loss: 0.8340 - precision: 0.7998 - recall: 0.6586 - val_accuracy: 0.6047 - val_auc: 0.8095 - val_loss: 1.9616 - val_precision: 0.6047 - val_recall: 0.6047
# Epoch 6/50
# ...
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6576 - auc: 0.8117 - loss: 1.0558 - precision: 0.7133 - recall: 0.5540 - val_accuracy: 0.7273 - val_auc: 0.8417 - val_loss: 1.2642 - val_precision: 0.7273 - val_recall: 0.7273
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6971 - auc: 0.8372 - loss: 0.9966 - precision: 0.7382 - recall: 0.6216 - val_accuracy: 0.7576 - val_auc: 0.8545 - val_loss: 1.1504 - val_precision: 0.7656 - val_recall: 0.7424
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7408 - auc: 0.8749 - loss: 0.9090 - precision: 0.8138 - recall: 0.6146 - val_accuracy: 0.7879 - val_auc: 0.8674 - val_loss: 1.0220 - val_precision: 0.8125 - val_recall: 0.7879
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7953 - auc: 0.8920 - loss: 0.8464 - precision: 0.8538 - recall: 0.7151 - val_accuracy: 0.8182 - val_auc: 0.8852 - val_loss: 0.9043 - val_precision: 0.8281 - val_recall: 0.8030
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7845 - auc: 0.8978 - loss: 0.8357 - precision: 0.8186 - recall: 0.6778 - val_accuracy: 0.8182 - val_auc: 0.9034 - val_loss: 0.8178 - val_precision: 0.8500 - val_recall: 0.7727
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7884 - auc: 0.9271 - loss: 0.7481 - precision: 0.8652 - recall: 0.7333 - val_accuracy: 0.7727 - val_auc: 0.9146 - val_loss: 0.7531 - val_precision: 0.8065 - val_recall: 0.7576
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8075 - auc: 0.9235 - loss: 0.7507 - precision: 0.8604 - recall: 0.7433 - val_accuracy: 0.8030 - val_auc: 0.9282 - val_loss: 0.6920 - val_precision: 0.8125 - val_recall: 0.7879
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8378 - auc: 0.9465 - loss: 0.6876 - precision: 0.8663 - recall: 0.7492 - val_accuracy: 0.8333 - val_auc: 0.9370 - val_loss: 0.6596 - val_precision: 0.8308 - val_recall: 0.8182
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8669 - auc: 0.9701 - loss: 0.5992 - precision: 0.9099 - recall: 0.8116 - val_accuracy: 0.8182 - val_auc: 0.9422 - val_loss: 0.6537 - val_precision: 0.8154 - val_recall: 0.8030
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8790 - auc: 0.9741 - loss: 0.5814 - precision: 0.9247 - recall: 0.8114 - val_accuracy: 0.8182 - val_auc: 0.9400 - val_loss: 0.6541 - val_precision: 0.8281 - val_recall: 0.8030
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9025 - auc: 0.9783 - loss: 0.5567 - precision: 0.9323 - recall: 0.8621 - val_accuracy: 0.8030 - val_auc: 0.9370 - val_loss: 0.6330 - val_precision: 0.8387 - val_recall: 0.7879
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8938 - auc: 0.9751 - loss: 0.5705 - precision: 0.9479 - recall: 0.8427 - val_accuracy: 0.8485 - val_auc: 0.9424 - val_loss: 0.6061 - val_precision: 0.8710 - val_recall: 0.8182
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9310 - auc: 0.9818 - loss: 0.5233 - precision: 0.9485 - recall: 0.8887 - val_accuracy: 0.8636 - val_auc: 0.9497 - val_loss: 0.5845 - val_precision: 0.9000 - val_recall: 0.8182
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9270 - auc: 0.9894 - loss: 0.4807 - precision: 0.9546 - recall: 0.8922 - val_accuracy: 0.8788 - val_auc: 0.9502 - val_loss: 0.5782 - val_precision: 0.8730 - val_recall: 0.8333
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9181 - auc: 0.9852 - loss: 0.4949 - precision: 0.9368 - recall: 0.8915 - val_accuracy: 0.8788 - val_auc: 0.9481 - val_loss: 0.5828 - val_precision: 0.9167 - val_recall: 0.8333
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9052 - auc: 0.9833 - loss: 0.5207 - precision: 0.9459 - recall: 0.8460 - val_accuracy: 0.9091 - val_auc: 0.9517 - val_loss: 0.5663 - val_precision: 0.9062 - val_recall: 0.8788
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9213 - auc: 0.9861 - loss: 0.4849 - precision: 0.9359 - recall: 0.8886 - val_accuracy: 0.8788 - val_auc: 0.9566 - val_loss: 0.5503 - val_precision: 0.8750 - val_recall: 0.8485
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9169 - auc: 0.9863 - loss: 0.4967 - precision: 0.9451 - recall: 0.8829 - val_accuracy: 0.8788 - val_auc: 0.9568 - val_loss: 0.5599 - val_precision: 0.8871 - val_recall: 0.8333
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9264 - auc: 0.9926 - loss: 0.4528 - precision: 0.9553 - recall: 0.9041 - val_accuracy: 0.8788 - val_auc: 0.9563 - val_loss: 0.5645 - val_precision: 0.8730 - val_recall: 0.8333
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9409 - auc: 0.9936 - loss: 0.4353 - precision: 0.9628 - recall: 0.9182 - val_accuracy: 0.8485 - val_auc: 0.9587 - val_loss: 0.5559 - val_precision: 0.8730 - val_recall: 0.8333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 689ms/step - accuracy: 0.4271 - auc: 0.6305 - loss: 1.3436 - precision: 0.4559 - recall: 0.3401 - val_accuracy: 0.6212 - val_auc: 0.8097 - val_loss: 1.9673 - val_precision: 0.6406 - val_recall: 0.6212
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6381 - auc: 0.8114 - loss: 0.9793 - precision: 0.7081 - recall: 0.5449 - val_accuracy: 0.7273 - val_auc: 0.8578 - val_loss: 1.2945 - val_precision: 0.7231 - val_recall: 0.7121
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6405 - auc: 0.8547 - loss: 0.8891 - precision: 0.7156 - recall: 0.5615 - val_accuracy: 0.7424 - val_auc: 0.8941 - val_loss: 1.0089 - val_precision: 0.7538 - val_recall: 0.7424
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7204 - auc: 0.8847 - loss: 0.8307 - precision: 0.7701 - recall: 0.6555 - val_accuracy: 0.7576 - val_auc: 0.9129 - val_loss: 0.8646 - val_precision: 0.7692 - val_recall: 0.7576
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7852 - auc: 0.9246 - loss: 0.7360 - precision: 0.8254 - recall: 0.7207 - val_accuracy: 0.7879 - val_auc: 0.9230 - val_loss: 0.7713 - val_precision: 0.8125 - val_recall: 0.7879
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8203 - auc: 0.9542 - loss: 0.6544 - precision: 0.8884 - recall: 0.7646 - val_accuracy: 0.8182 - val_auc: 0.9345 - val_loss: 0.7160 - val_precision: 0.8361 - val_recall: 0.7727
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8173 - auc: 0.9502 - loss: 0.6578 - precision: 0.8861 - recall: 0.7723 - val_accuracy: 0.7576 - val_auc: 0.9379 - val_loss: 0.6824 - val_precision: 0.8305 - val_recall: 0.7424
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8470 - auc: 0.9562 - loss: 0.6278 - precision: 0.8971 - recall: 0.7794 - val_accuracy: 0.7424 - val_auc: 0.9347 - val_loss: 0.6839 - val_precision: 0.7742 - val_recall: 0.7273
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8541 - auc: 0.9610 - loss: 0.6307 - precision: 0.8763 - recall: 0.7641 - val_accuracy: 0.7273 - val_auc: 0.9260 - val_loss: 0.7375 - val_precision: 0.7500 - val_recall: 0.7273
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8582 - auc: 0.9639 - loss: 0.6110 - precision: 0.8999 - recall: 0.7898 - val_accuracy: 0.7273 - val_auc: 0.9255 - val_loss: 0.7429 - val_precision: 0.7500 - val_recall: 0.7273
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 667ms/step - accuracy: 0.4971 - auc: 0.6731 - loss: 1.3135 - precision: 0.5703 - recall: 0.4453 - val_accuracy: 0.5909 - val_auc: 0.7538 - val_loss: 3.3961 - val_precision: 0.6000 - val_recall: 0.5909
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6501 - auc: 0.7975 - loss: 1.0360 - precision: 0.7003 - recall: 0.5284 - val_accuracy: 0.6515 - val_auc: 0.8144 - val_loss: 1.9516 - val_precision: 0.6774 - val_recall: 0.6364
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6558 - auc: 0.8291 - loss: 0.9544 - precision: 0.6938 - recall: 0.5573 - val_accuracy: 0.6970 - val_auc: 0.8211 - val_loss: 1.5380 - val_precision: 0.6923 - val_recall: 0.6818
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7139 - auc: 0.8657 - loss: 0.8889 - precision: 0.7704 - recall: 0.6286 - val_accuracy: 0.7273 - val_auc: 0.8332 - val_loss: 1.3269 - val_precision: 0.7344 - val_recall: 0.7121
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8320 - auc: 0.9387 - loss: 0.7160 - precision: 0.8728 - recall: 0.7417 - val_accuracy: 0.7424 - val_auc: 0.8470 - val_loss: 1.2663 - val_precision: 0.7538 - val_recall: 0.7424
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8072 - auc: 0.9112 - loss: 0.7909 - precision: 0.8234 - recall: 0.7179 - val_accuracy: 0.7424 - val_auc: 0.8506 - val_loss: 1.1738 - val_precision: 0.7619 - val_recall: 0.7273
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8058 - auc: 0.9249 - loss: 0.7417 - precision: 0.8253 - recall: 0.7128 - val_accuracy: 0.7121 - val_auc: 0.8567 - val_loss: 1.1389 - val_precision: 0.7460 - val_recall: 0.7121
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8581 - auc: 0.9546 - loss: 0.6561 - precision: 0.8882 - recall: 0.7469 - val_accuracy: 0.7424 - val_auc: 0.8534 - val_loss: 1.1287 - val_precision: 0.7581 - val_recall: 0.7121
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8479 - auc: 0.9323 - loss: 0.7007 - precision: 0.8873 - recall: 0.8073 - val_accuracy: 0.7424 - val_auc: 0.8585 - val_loss: 1.0652 - val_precision: 0.7500 - val_recall: 0.7273
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8470 - auc: 0.9427 - loss: 0.6655 - precision: 0.8676 - recall: 0.8217 - val_accuracy: 0.7424 - val_auc: 0.8702 - val_loss: 0.9841 - val_precision: 0.7424 - val_recall: 0.7424
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8815 - auc: 0.9745 - loss: 0.5776 - precision: 0.9251 - recall: 0.8344 - val_accuracy: 0.7424 - val_auc: 0.8799 - val_loss: 0.9161 - val_precision: 0.7656 - val_recall: 0.7424
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8801 - auc: 0.9689 - loss: 0.5717 - precision: 0.9014 - recall: 0.8321 - val_accuracy: 0.7424 - val_auc: 0.8932 - val_loss: 0.8665 - val_precision: 0.7619 - val_recall: 0.7273
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9180 - auc: 0.9802 - loss: 0.5400 - precision: 0.9393 - recall: 0.8521 - val_accuracy: 0.7727 - val_auc: 0.8992 - val_loss: 0.8377 - val_precision: 0.7778 - val_recall: 0.7424
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8948 - auc: 0.9749 - loss: 0.5420 - precision: 0.9203 - recall: 0.8581 - val_accuracy: 0.7727 - val_auc: 0.8998 - val_loss: 0.8346 - val_precision: 0.7778 - val_recall: 0.7424
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9000 - auc: 0.9787 - loss: 0.5212 - precision: 0.9256 - recall: 0.8759 - val_accuracy: 0.7879 - val_auc: 0.9053 - val_loss: 0.8195 - val_precision: 0.7812 - val_recall: 0.7576
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9478 - auc: 0.9940 - loss: 0.4383 - precision: 0.9605 - recall: 0.9062 - val_accuracy: 0.7879 - val_auc: 0.9054 - val_loss: 0.8189 - val_precision: 0.7846 - val_recall: 0.7727
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9419 - auc: 0.9890 - loss: 0.4429 - precision: 0.9434 - recall: 0.9157 - val_accuracy: 0.7879 - val_auc: 0.9084 - val_loss: 0.8130 - val_precision: 0.7937 - val_recall: 0.7576
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9178 - auc: 0.9865 - loss: 0.4565 - precision: 0.9319 - recall: 0.8761 - val_accuracy: 0.7576 - val_auc: 0.9100 - val_loss: 0.8034 - val_precision: 0.7692 - val_recall: 0.7576
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9458 - auc: 0.9950 - loss: 0.4038 - precision: 0.9700 - recall: 0.9301 - val_accuracy: 0.7727 - val_auc: 0.9175 - val_loss: 0.7763 - val_precision: 0.7692 - val_recall: 0.7576
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9468 - auc: 0.9911 - loss: 0.4135 - precision: 0.9572 - recall: 0.9192 - val_accuracy: 0.7727 - val_auc: 0.9226 - val_loss: 0.7526 - val_precision: 0.7846 - val_recall: 0.7727
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9643 - auc: 0.9944 - loss: 0.3821 - precision: 0.9750 - recall: 0.9506 - val_accuracy: 0.7879 - val_auc: 0.9192 - val_loss: 0.7663 - val_precision: 0.7812 - val_recall: 0.7576
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9474 - auc: 0.9946 - loss: 0.3984 - precision: 0.9575 - recall: 0.9281 - val_accuracy: 0.8030 - val_auc: 0.9049 - val_loss: 0.8073 - val_precision: 0.8030 - val_recall: 0.8030
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9483 - auc: 0.9957 - loss: 0.3686 - precision: 0.9542 - recall: 0.9376 - val_accuracy: 0.8030 - val_auc: 0.8977 - val_loss: 0.8249 - val_precision: 0.8030 - val_recall: 0.8030
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 648ms/step - accuracy: 0.4523 - auc: 0.6480 - loss: 1.2857 - precision: 0.5068 - recall: 0.3642 - val_accuracy: 0.7424 - val_auc: 0.8277 - val_loss: 2.4073 - val_precision: 0.7385 - val_recall: 0.7273
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6920 - auc: 0.8395 - loss: 0.9708 - precision: 0.7599 - recall: 0.5543 - val_accuracy: 0.7424 - val_auc: 0.8380 - val_loss: 1.6830 - val_precision: 0.7424 - val_recall: 0.7424
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6538 - auc: 0.8260 - loss: 1.0081 - precision: 0.7237 - recall: 0.5658 - val_accuracy: 0.7424 - val_auc: 0.8945 - val_loss: 1.1352 - val_precision: 0.7424 - val_recall: 0.7424
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7783 - auc: 0.8984 - loss: 0.8488 - precision: 0.8287 - recall: 0.6581 - val_accuracy: 0.7576 - val_auc: 0.9222 - val_loss: 0.8919 - val_precision: 0.7812 - val_recall: 0.7576
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7777 - auc: 0.9155 - loss: 0.7883 - precision: 0.8206 - recall: 0.6768 - val_accuracy: 0.8182 - val_auc: 0.9372 - val_loss: 0.7607 - val_precision: 0.8154 - val_recall: 0.8030
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8632 - auc: 0.9360 - loss: 0.7354 - precision: 0.8769 - recall: 0.7892 - val_accuracy: 0.8485 - val_auc: 0.9440 - val_loss: 0.6955 - val_precision: 0.8594 - val_recall: 0.8333
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8115 - auc: 0.9368 - loss: 0.7192 - precision: 0.8753 - recall: 0.7420 - val_accuracy: 0.8485 - val_auc: 0.9474 - val_loss: 0.6640 - val_precision: 0.8462 - val_recall: 0.8333
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8464 - auc: 0.9489 - loss: 0.6755 - precision: 0.8983 - recall: 0.7750 - val_accuracy: 0.8939 - val_auc: 0.9531 - val_loss: 0.6223 - val_precision: 0.8923 - val_recall: 0.8788
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8443 - auc: 0.9571 - loss: 0.6488 - precision: 0.9017 - recall: 0.7796 - val_accuracy: 0.8939 - val_auc: 0.9553 - val_loss: 0.5941 - val_precision: 0.9062 - val_recall: 0.8788
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8730 - auc: 0.9714 - loss: 0.5890 - precision: 0.9001 - recall: 0.8327 - val_accuracy: 0.8636 - val_auc: 0.9562 - val_loss: 0.5911 - val_precision: 0.8769 - val_recall: 0.8636
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8688 - auc: 0.9777 - loss: 0.5660 - precision: 0.9041 - recall: 0.8326 - val_accuracy: 0.8788 - val_auc: 0.9522 - val_loss: 0.6067 - val_precision: 0.8750 - val_recall: 0.8485
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8923 - auc: 0.9846 - loss: 0.5182 - precision: 0.9527 - recall: 0.8519 - val_accuracy: 0.8788 - val_auc: 0.9525 - val_loss: 0.6007 - val_precision: 0.8871 - val_recall: 0.8333
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8867 - auc: 0.9750 - loss: 0.5649 - precision: 0.9297 - recall: 0.8481 - val_accuracy: 0.8636 - val_auc: 0.9533 - val_loss: 0.5973 - val_precision: 0.8889 - val_recall: 0.8485
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step

# %%
# Summarize results
df = pd.DataFrame(results)
print(df.groupby("file")[["accuracy", "precision", "recall", "f1", "roc_auc"]].mean())

# Optional: plot AUC per file
df.groupby("file")["roc_auc"].mean().plot.bar(rot=45, figsize=(10, 5))
plt.title("Sequential Neural Network Cross-Validation Area Under Curve per File (mean over folds)")
plt.ylabel("AUC")
plt.tight_layout()
plt.show()
# Out:
#                                                     accuracy  precision  \
# file
# 221111_144114__binary_onlylines114378to117271 l...  0.817241   0.817830
# 221111_144114__binary_onlylines145900to148050 l...  0.796829   0.831915
# 221111_144114__binary_onlylines25660to28100 loe...  0.824490   0.843662
# 221111_144114__binary_onlylines47178to50517 loe...  0.847128   0.859118
# 221111_144114__binary_onlylines86841to90142 loe...  0.812754   0.824734
#
#                                                       recall        f1  \
# file
# 221111_144114__binary_onlylines114378to117271 l...  0.817241  0.814790
# 221111_144114__binary_onlylines145900to148050 l...  0.796829  0.805720
# 221111_144114__binary_onlylines25660to28100 loe...  0.824490  0.819285
# 221111_144114__binary_onlylines47178to50517 loe...  0.847128  0.844143
# 221111_144114__binary_onlylines86841to90142 loe...  0.812754  0.809961
#
#                                                      roc_auc
# file
# 221111_144114__binary_onlylines114378to117271 l...  0.919016
# 221111_144114__binary_onlylines145900to148050 l...  0.901850
# 221111_144114__binary_onlylines25660to28100 loe...  0.907357
# 221111_144114__binary_onlylines47178to50517 loe...  0.926897
# 221111_144114__binary_onlylines86841to90142 loe...  0.915139
# /tmp/ipykernel_78916/1605691262.py:9: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
# Show confusion matrix for each file (mean over folds)
from sklearn.metrics import ConfusionMatrixDisplay

for file in df["file"].unique():
    cms = [np.array(row) for row in df[df["file"] == file]["confusion_matrix"]]
    # Find the largest shape
    max_dim = max(cm.shape[0] for cm in cms)
    # Pad all confusion matrices to max_dim x max_dim
    padded = []
    for cm in cms:
        pad_width = ((0, max_dim - cm.shape[0]), (0, max_dim - cm.shape[1]))
        padded.append(np.pad(cm, pad_width, mode='constant'))
    mean_cm = np.mean(padded, axis=0)
    display_labels = [str(l) for l in range(max_dim)]
    fig, ax = plt.subplots(figsize=(4, 4))
    disp = ConfusionMatrixDisplay(mean_cm, display_labels=display_labels)
    disp.plot(ax=ax, cmap="Blues", colorbar=False)
    plt.title(f"Mean Confusion Matrix: {file}")
    plt.tight_layout()
    plt.show()
